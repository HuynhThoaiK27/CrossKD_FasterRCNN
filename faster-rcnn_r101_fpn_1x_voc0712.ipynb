# %% [markdown]
# <a href="https://www.kaggle.com/code/thoihunhvn/crosskd?scriptVersionId=276006604" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cài đặt

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113

# !pip install -U openmim

# !mim install "mmengine==0.7.3"

# !mim install "mmcv==2.0.0rc4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch==1.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (1837.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 466.7 kB/s eta 0:00:00
# Collecting torchvision==0.13.1
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.13.1%2Bcu113-cp310-cp310-linux_x86_64.whl (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 81.3 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 94.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==1.12.1) (4.12.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (2024.8.30)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# Successfully installed torch-1.12.1+cu113 torchaudio-0.12.1+cu113 torchvision-0.13.1+cu113
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /opt/conda/lib/python3.10/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /opt/conda/lib/python3.10/site-packages (from openmim) (24.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from openmim) (13.7.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (3.6)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (3.20.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (4.66.4)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 6.6 MB/s eta 0:00:00
# done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 18.0 MB/s eta 0:00:00
# done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.3 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.3-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.5/314.5 kB 17.3 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.5 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 16.6 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 29.5 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 4.9 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 43.0 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 6.5 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core
# done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=f4a7d4cdd6b9372aeef52123e9ae9ae55c72f4163aa5c714b7da80f41b48d03c
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
# done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535317 sha256=0e08dd99a179d889578ab5116ba7c98a3555d59a09bb56d8a3be946ca85be0e8
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
# Successfully built oss2 aliyun-python-sdk-core
# Installing collected packages: pytz, tqdm, setuptools, requests, packaging, ordered-set, jmespath, filelock, rich, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.1
#     Uninstalling filelock-3.15.1:
#       Successfully uninstalled filelock-3.15.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.0.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# boto3 1.26.100 requires botocore<1.30.0,>=1.29.100, but you have botocore 1.35.23 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# datasets 3.0.1 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.0.1 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-server 2.27.2 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.3 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmengine==0.7.3
#   Downloading mmengine-0.7.3-py3-none-any.whl.metadata (18 kB)
# Collecting addict (from mmengine==0.7.3)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (1.26.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (6.0.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (2.4.0)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (2.18.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine==0.7.3) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine==0.7.3) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine==0.7.3) (1.16.0)
# Downloading mmengine-0.7.3-py3-none-any.whl (372 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.1/372.1 kB 7.7 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict, mmengine
# Successfully installed addict-2.4.0 mmengine-0.7.3
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmcv==2.0.0rc4
#   Downloading https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/mmcv-2.0.0rc4-cp310-cp310-manylinux1_x86_64.whl (44.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 MB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (4.10.0.84)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (3.7.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv==2.0.0rc4) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0rc4

# %%
# !git clone --branch faster-rcnn https://github.com/jbwang1997/CrossKD.git
# %cd CrossKD
# Out:
# Cloning into 'CrossKD'...
# remote: Enumerating objects: 34364, done.
# remote: Counting objects: 100% (1727/1727), done.
# remote: Compressing objects: 100% (278/278), done.
# remote: Total 34364 (delta 1583), reused 1449 (delta 1449), pack-reused 32637 (from 2)
# Receiving objects: 100% (34364/34364), 32.16 MiB | 34.02 MiB/s, done.
# Resolving deltas: 100% (26898/26898), done.
# /kaggle/working/CrossKD

# %%
# !pip install -v -e .
# "-v" means verbose, or more output
# "-e" means installing a project in editable mode,
# thus any local modifications made to the code will take effect without reinstallation.

# !pip install yapf==0.32.0
# Out:
# Using pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/CrossKD
#   Running command python setup.py egg_info
#   /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#   ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#   Your build configuration is incomplete and previously worked by accident!
#   setuptools_scm requires setuptools>=61
#
#   Suggested workaround if applicable:
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-5wtfwxfp/mmdet.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-5wtfwxfp/mmdet.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmdet/VERSION'
#   warning: no files found matching 'mmdet/.mim/model-index.yml'
#   warning: no files found matching 'mmdet/.mim/demo/*/*'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
#   writing manifest file '/tmp/pip-pip-egg-info-5wtfwxfp/mmdet.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.26.4)
# Collecting pycocotools (from mmdet==3.0.0rc6)
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/61/d7/32996d713921c504875a4cebf241c182aa37e58daab5c3c4737f539ac0d4/pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.14.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.16.0)
# Collecting terminaltables (from mmdet==3.0.0rc6)
#   Obtaining dependency information for terminaltables from https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl.metadata
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (2.9.0.post0)
# Downloading pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.0/455.0 kB 8.7 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, pycocotools, mmdet
#   Running setup.py develop for mmdet
#     Running command python setup.py develop
#     /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#     ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#     Your build configuration is incomplete and previously worked by accident!
#     setuptools_scm requires setuptools>=61
#
#     Suggested workaround if applicable:
#      - migrating from the deprecated setup_requires mechanism to pep517/518
#        and using a pyproject.toml to declare build dependencies
#        which are reliably pre-installed before running the build tools
#
#       warnings.warn(
#     running develop
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     creating mmdet.egg-info
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     warning: no files found matching 'mmdet/VERSION'
#     warning: no files found matching 'mmdet/.mim/demo/*/*'
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     running build_ext
# Successfully installed mmdet-3.0.0rc6 pycocotools-2.0.10 terminaltables-3.1.10
# Collecting yapf==0.32.0
#   Downloading yapf-0.32.0-py2.py3-none-any.whl.metadata (34 kB)
# Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: yapf
#   Attempting uninstall: yapf
#     Found existing installation: yapf 0.40.2
#     Uninstalling yapf-0.40.2:
#       Successfully uninstalled yapf-0.40.2
# Successfully installed yapf-0.32.0

# %% [markdown]
# # Thực hiện các bước di chuyển và cài đặt cấu hình

# %%
# !ls configs/
# Out:
# _base_		  dino		       legacy_1.x	    rpn
# albu_example	  double_heads	       libra_rcnn	    rtmdet
# atss		  dyhead	       lvis		    sabl
# autoassign	  dynamic_rcnn	       mask2former	    scnet
# boxinst		  efficientnet	       mask_rcnn	    scratch
# carafe		  empirical_attention  maskformer	    seesaw_loss
# cascade_rcnn	  fast_rcnn	       misc		    selfsup_pretrain
# cascade_rpn	  faster_rcnn	       ms_rcnn		    simple_copy_paste
# centernet	  fcos		       nas_fcos		    soft_teacher
# centripetalnet	  foveabox	       nas_fpn		    solo
# cityscapes	  fpg		       objects365	    solov2
# common		  free_anchor	       openimages	    sparse_rcnn
# condinst	  fsaf		       paa		    ssd
# conditional_detr  gcnet		       pafpn		    strong_baselines
# convnext	  gfl		       panoptic_fpn	    swin
# cornernet	  ghm		       pascal_voc	    timm_example
# crosskd		  gn		       pisa		    tood
# crowddet	  gn+ws		       point_rend	    tridentnet
# dab_detr	  grid_rcnn	       pvt		    vfnet
# dcn		  groie		       queryinst	    wider_face
# dcnv2		  guided_anchoring     regnet		    yolact
# ddod		  hrnet		       reppoints	    yolo
# deepfashion	  htc		       res2net		    yolof
# deformable_detr   instaboost	       resnest		    yolox
# detectors	  lad		       resnet_strikes_back
# detr		  ld		       retinanet

# %%
# !cp /kaggle/input/voc-fasterrcnn/voc0712_faster_rcnn.py configs/_base_/datasets/voc0712.py

# %%
# !cp /kaggle/input/faster-rcnn-voc/faster-rcnn_r50_fpn_1x_voc0712.py configs/faster_rcnn/

# %%
# !cp /kaggle/input/schedule-1x/schedule_1x.py configs/_base_/schedules/schedule_1x.py

# %%
# !cp /kaggle/input/base-configfasterrcnn/faster-rcnn_r50_fpn.py configs/_base_/models/faster-rcnn_r50_fpn.py

# %%
# !ls configs/faster_rcnn/
# Out:
# README.md
# faster-rcnn_r101-caffe_fpn_1x_coco.py
# faster-rcnn_r101-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r101_fpn_1x_coco.py
# faster-rcnn_r101_fpn_2x_coco.py
# faster-rcnn_r101_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r101_fpn_ms-3x_coco.py
# faster-rcnn_r18_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50-caffe-c4_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-3x_coco.py
# faster-rcnn_r50-caffe_c4-1x_coco.py
# faster-rcnn_r50-caffe_fpn_1x_coco.py
# faster-rcnn_r50-caffe_fpn_90k_coco.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person-bicycle-car.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-2x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-90k_coco.py
# faster-rcnn_r50-tnr-pre_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_voc0712.py
# faster-rcnn_r50_fpn_2x_coco.py
# faster-rcnn_r50_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50_fpn_amp-1x_coco.py
# faster-rcnn_r50_fpn_bounded-iou_1x_coco.py
# faster-rcnn_r50_fpn_ciou_1x_coco.py
# faster-rcnn_r50_fpn_fcos-rpn_1x_coco.py
# faster-rcnn_r50_fpn_giou_1x_coco.py
# faster-rcnn_r50_fpn_iou_1x_coco.py
# faster-rcnn_r50_fpn_ms-3x_coco.py
# faster-rcnn_r50_fpn_ohem_1x_coco.py
# faster-rcnn_r50_fpn_soft-nms_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_2x_coco.py
# faster-rcnn_x101-32x4d_fpn_ms-3x_coco.py
# faster-rcnn_x101-32x8d_fpn_ms-3x_coco.py
# faster-rcnn_x101-64x4d_fpn_1x_coco.py
# faster-rcnn_x101-64x4d_fpn_2x_coco.py
# faster-rcnn_x101-64x4d_fpn_ms-3x_coco.py
# metafile.yml

# %%
# !cat configs/faster_rcnn/faster-rcnn_r50_fpn_1x_voc0712.py
# Out:
# _base_ = [
#     '../_base_/models/faster-rcnn_r50_fpn.py',
#     '../_base_/datasets/voc0712.py',
#     '../_base_/schedules/schedule_1x.py', '../_base_/default_runtime.py'
# ]

# %%
# !cat configs/_base_/schedules/schedule_1x.py
# Out:
# # training schedule for 1x
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
#
# # learning rate
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
#
# # optimizer
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001))
#
# # Default setting for scaling LR automatically
# #   - `enable` means enable scaling LR automatically
# #       or not by default.
# #   - `base_batch_size` = (8 GPUs) x (2 samples per GPU).
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
# !cat configs/_base_/models/faster-rcnn_r50_fpn.py
# Out:
# # model settings
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[.0, .0, .0, .0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0., 0., 0., 0.],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     # model training and testing settings
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)
#         # soft-nms is also supported for rcnn testing
#         # e.g., nms=dict(type='soft_nms', iou_threshold=0.5, min_score=0.05)
#     ))

# %%
# !python tools/train.py configs/faster_rcnn/faster-rcnn_r50_fpn_1x_voc0712.py --work-dir /kaggle/working/w
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/11 13:20:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 1966946887
#     GPU 0,1: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu113
#     OpenCV: 4.10.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/11 13:20:04 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'VOCDataset'
# data_root = '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit'
# file_client_args = dict(backend='disk')
# train_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='RepeatDataset',
#         times=3,
#         dataset=dict(
#             type='ConcatDataset',
#             ignore_keys=['dataset_type'],
#             datasets=[
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2007/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2007/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ]),
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2012/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2012/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ])
#             ])))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# val_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# test_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# launcher = 'none'
# work_dir = '/kaggle/working/w'
#
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 11/11 13:20:10 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/11 13:20:10 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 11/11 13:20:11 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/11 13:20:11 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/11 13:21:28 - mmengine - INFO - load model from: torchvision://resnet50
# 11/11 13:21:28 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 252MB/s]
# 11/11 13:21:29 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 11/11 13:21:29 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/w.
# 11/11 13:22:05 - mmengine - INFO - Epoch(train) [1][  50/6164]  lr: 1.9820e-03  eta: 4:53:02  time: 0.7146  data_time: 0.0124  memory: 4334  loss: 1.1094  loss_rpn_cls: 0.3832  loss_rpn_bbox: 0.0185  loss_cls: 0.6349  acc: 94.9707  loss_bbox: 0.0729
# 11/11 13:22:41 - mmengine - INFO - Epoch(train) [1][ 100/6164]  lr: 3.9840e-03  eta: 4:53:45  time: 0.7210  data_time: 0.0091  memory: 4334  loss: 0.4895  loss_rpn_cls: 0.0575  loss_rpn_bbox: 0.0176  loss_cls: 0.2581  acc: 96.9727  loss_bbox: 0.1564
# 11/11 13:23:19 - mmengine - INFO - Epoch(train) [1][ 150/6164]  lr: 5.9860e-03  eta: 4:58:55  time: 0.7601  data_time: 0.0088  memory: 4334  loss: 0.5031  loss_rpn_cls: 0.0536  loss_rpn_bbox: 0.0199  loss_cls: 0.2555  acc: 94.7266  loss_bbox: 0.1741
# 11/11 13:23:59 - mmengine - INFO - Epoch(train) [1][ 200/6164]  lr: 7.9880e-03  eta: 5:06:41  time: 0.8140  data_time: 0.0088  memory: 4334  loss: 0.4795  loss_rpn_cls: 0.0434  loss_rpn_bbox: 0.0185  loss_cls: 0.2457  acc: 95.9473  loss_bbox: 0.1719
# 11/11 13:24:38 - mmengine - INFO - Epoch(train) [1][ 250/6164]  lr: 9.9900e-03  eta: 5:08:26  time: 0.7818  data_time: 0.0092  memory: 4334  loss: 0.4862  loss_rpn_cls: 0.0369  loss_rpn_bbox: 0.0186  loss_cls: 0.2416  acc: 95.0684  loss_bbox: 0.1891
# 11/11 13:25:18 - mmengine - INFO - Epoch(train) [1][ 300/6164]  lr: 1.1992e-02  eta: 5:09:56  time: 0.7897  data_time: 0.0091  memory: 4334  loss: 0.5640  loss_rpn_cls: 0.0420  loss_rpn_bbox: 0.0234  loss_cls: 0.2884  acc: 96.5820  loss_bbox: 0.2102
# 11/11 13:25:58 - mmengine - INFO - Epoch(train) [1][ 350/6164]  lr: 1.3994e-02  eta: 5:10:56  time: 0.7919  data_time: 0.0094  memory: 4334  loss: 0.5629  loss_rpn_cls: 0.0483  loss_rpn_bbox: 0.0229  loss_cls: 0.2842  acc: 95.1660  loss_bbox: 0.2076
# 11/11 13:26:37 - mmengine - INFO - Epoch(train) [1][ 400/6164]  lr: 1.5996e-02  eta: 5:10:54  time: 0.7796  data_time: 0.0088  memory: 4334  loss: 0.5400  loss_rpn_cls: 0.0401  loss_rpn_bbox: 0.0222  loss_cls: 0.2757  acc: 95.5566  loss_bbox: 0.2020
# 11/11 13:27:16 - mmengine - INFO - Epoch(train) [1][ 450/6164]  lr: 1.7998e-02  eta: 5:10:59  time: 0.7851  data_time: 0.0090  memory: 4334  loss: 0.4660  loss_rpn_cls: 0.0318  loss_rpn_bbox: 0.0188  loss_cls: 0.2361  acc: 95.1172  loss_bbox: 0.1794
# 11/11 13:27:55 - mmengine - INFO - Epoch(train) [1][ 500/6164]  lr: 2.0000e-02  eta: 5:11:06  time: 0.7899  data_time: 0.0086  memory: 4334  loss: 0.5330  loss_rpn_cls: 0.0421  loss_rpn_bbox: 0.0232  loss_cls: 0.2694  acc: 96.8262  loss_bbox: 0.1983
# 11/11 13:28:35 - mmengine - INFO - Epoch(train) [1][ 550/6164]  lr: 2.0000e-02  eta: 5:11:24  time: 0.7984  data_time: 0.0088  memory: 4334  loss: 0.5408  loss_rpn_cls: 0.0408  loss_rpn_bbox: 0.0199  loss_cls: 0.2760  acc: 94.9219  loss_bbox: 0.2040
# 11/11 13:29:15 - mmengine - INFO - Epoch(train) [1][ 600/6164]  lr: 2.0000e-02  eta: 5:11:09  time: 0.7872  data_time: 0.0083  memory: 4334  loss: 0.4646  loss_rpn_cls: 0.0291  loss_rpn_bbox: 0.0155  loss_cls: 0.2420  acc: 94.1895  loss_bbox: 0.1780
# 11/11 13:29:54 - mmengine - INFO - Epoch(train) [1][ 650/6164]  lr: 2.0000e-02  eta: 5:10:46  time: 0.7846  data_time: 0.0090  memory: 4334  loss: 0.5207  loss_rpn_cls: 0.0288  loss_rpn_bbox: 0.0186  loss_cls: 0.2657  acc: 96.4355  loss_bbox: 0.2076
# 11/11 13:30:33 - mmengine - INFO - Epoch(train) [1][ 700/6164]  lr: 2.0000e-02  eta: 5:10:23  time: 0.7857  data_time: 0.0089  memory: 4334  loss: 0.5086  loss_rpn_cls: 0.0288  loss_rpn_bbox: 0.0171  loss_cls: 0.2627  acc: 92.6270  loss_bbox: 0.2001
# 11/11 13:31:13 - mmengine - INFO - Epoch(train) [1][ 750/6164]  lr: 2.0000e-02  eta: 5:10:27  time: 0.8044  data_time: 0.0095  memory: 4334  loss: 0.4520  loss_rpn_cls: 0.0289  loss_rpn_bbox: 0.0175  loss_cls: 0.2325  acc: 94.6289  loss_bbox: 0.1730
# 11/11 13:31:53 - mmengine - INFO - Epoch(train) [1][ 800/6164]  lr: 2.0000e-02  eta: 5:10:14  time: 0.7966  data_time: 0.0089  memory: 4334  loss: 0.4530  loss_rpn_cls: 0.0270  loss_rpn_bbox: 0.0169  loss_cls: 0.2280  acc: 94.9707  loss_bbox: 0.1811
# 11/11 13:32:33 - mmengine - INFO - Epoch(train) [1][ 850/6164]  lr: 2.0000e-02  eta: 5:10:02  time: 0.7993  data_time: 0.0091  memory: 4334  loss: 0.4788  loss_rpn_cls: 0.0277  loss_rpn_bbox: 0.0199  loss_cls: 0.2356  acc: 93.3105  loss_bbox: 0.1956
# 11/11 13:33:13 - mmengine - INFO - Epoch(train) [1][ 900/6164]  lr: 2.0000e-02  eta: 5:09:36  time: 0.7919  data_time: 0.0087  memory: 4334  loss: 0.4765  loss_rpn_cls: 0.0320  loss_rpn_bbox: 0.0189  loss_cls: 0.2447  acc: 85.4004  loss_bbox: 0.1809
# 11/11 13:33:53 - mmengine - INFO - Epoch(train) [1][ 950/6164]  lr: 2.0000e-02  eta: 5:09:20  time: 0.8005  data_time: 0.0083  memory: 4334  loss: 0.4759  loss_rpn_cls: 0.0301  loss_rpn_bbox: 0.0163  loss_cls: 0.2426  acc: 92.8223  loss_bbox: 0.1869
# 11/11 13:34:32 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 13:34:32 - mmengine - INFO - Epoch(train) [1][1000/6164]  lr: 2.0000e-02  eta: 5:08:49  time: 0.7892  data_time: 0.0087  memory: 4334  loss: 0.4641  loss_rpn_cls: 0.0318  loss_rpn_bbox: 0.0188  loss_cls: 0.2336  acc: 94.8730  loss_bbox: 0.1799
# 11/11 13:35:12 - mmengine - INFO - Epoch(train) [1][1050/6164]  lr: 2.0000e-02  eta: 5:08:19  time: 0.7914  data_time: 0.0093  memory: 4334  loss: 0.4524  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0178  loss_cls: 0.2313  acc: 90.6738  loss_bbox: 0.1775
# 11/11 13:35:51 - mmengine - INFO - Epoch(train) [1][1100/6164]  lr: 2.0000e-02  eta: 5:07:50  time: 0.7937  data_time: 0.0091  memory: 4334  loss: 0.4176  loss_rpn_cls: 0.0257  loss_rpn_bbox: 0.0195  loss_cls: 0.2035  acc: 96.0449  loss_bbox: 0.1690
# 11/11 13:36:32 - mmengine - INFO - Epoch(train) [1][1150/6164]  lr: 2.0000e-02  eta: 5:07:29  time: 0.8017  data_time: 0.0090  memory: 4334  loss: 0.4562  loss_rpn_cls: 0.0257  loss_rpn_bbox: 0.0194  loss_cls: 0.2235  acc: 95.5078  loss_bbox: 0.1876
# 11/11 13:37:11 - mmengine - INFO - Epoch(train) [1][1200/6164]  lr: 2.0000e-02  eta: 5:06:45  time: 0.7799  data_time: 0.0092  memory: 4334  loss: 0.4018  loss_rpn_cls: 0.0242  loss_rpn_bbox: 0.0157  loss_cls: 0.2031  acc: 96.6797  loss_bbox: 0.1588
# 11/11 13:37:50 - mmengine - INFO - Epoch(train) [1][1250/6164]  lr: 2.0000e-02  eta: 5:06:02  time: 0.7812  data_time: 0.0088  memory: 4334  loss: 0.4225  loss_rpn_cls: 0.0278  loss_rpn_bbox: 0.0170  loss_cls: 0.2075  acc: 95.9473  loss_bbox: 0.1702
# 11/11 13:38:29 - mmengine - INFO - Epoch(train) [1][1300/6164]  lr: 2.0000e-02  eta: 5:05:34  time: 0.7965  data_time: 0.0085  memory: 4334  loss: 0.4328  loss_rpn_cls: 0.0255  loss_rpn_bbox: 0.0193  loss_cls: 0.2123  acc: 95.8984  loss_bbox: 0.1757
# 11/11 13:39:09 - mmengine - INFO - Epoch(train) [1][1350/6164]  lr: 2.0000e-02  eta: 5:04:56  time: 0.7865  data_time: 0.0090  memory: 4334  loss: 0.4690  loss_rpn_cls: 0.0255  loss_rpn_bbox: 0.0191  loss_cls: 0.2272  acc: 95.5078  loss_bbox: 0.1972
# 11/11 13:39:48 - mmengine - INFO - Epoch(train) [1][1400/6164]  lr: 2.0000e-02  eta: 5:04:19  time: 0.7876  data_time: 0.0089  memory: 4334  loss: 0.4255  loss_rpn_cls: 0.0299  loss_rpn_bbox: 0.0179  loss_cls: 0.2073  acc: 97.3145  loss_bbox: 0.1704
# 11/11 13:40:28 - mmengine - INFO - Epoch(train) [1][1450/6164]  lr: 2.0000e-02  eta: 5:03:42  time: 0.7884  data_time: 0.0086  memory: 4334  loss: 0.5032  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0191  loss_cls: 0.2598  acc: 92.9688  loss_bbox: 0.1986
# 11/11 13:41:08 - mmengine - INFO - Epoch(train) [1][1500/6164]  lr: 2.0000e-02  eta: 5:03:21  time: 0.8083  data_time: 0.0087  memory: 4334  loss: 0.4347  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0173  loss_cls: 0.2118  acc: 97.6074  loss_bbox: 0.1798
# 11/11 13:41:48 - mmengine - INFO - Epoch(train) [1][1550/6164]  lr: 2.0000e-02  eta: 5:02:45  time: 0.7914  data_time: 0.0087  memory: 4334  loss: 0.4331  loss_rpn_cls: 0.0232  loss_rpn_bbox: 0.0175  loss_cls: 0.2141  acc: 95.0195  loss_bbox: 0.1782
# 11/11 13:42:27 - mmengine - INFO - Epoch(train) [1][1600/6164]  lr: 2.0000e-02  eta: 5:02:06  time: 0.7861  data_time: 0.0094  memory: 4334  loss: 0.4479  loss_rpn_cls: 0.0231  loss_rpn_bbox: 0.0159  loss_cls: 0.2223  acc: 89.7949  loss_bbox: 0.1866
# 11/11 13:43:06 - mmengine - INFO - Epoch(train) [1][1650/6164]  lr: 2.0000e-02  eta: 5:01:28  time: 0.7887  data_time: 0.0088  memory: 4334  loss: 0.4452  loss_rpn_cls: 0.0226  loss_rpn_bbox: 0.0164  loss_cls: 0.2256  acc: 91.4551  loss_bbox: 0.1807
# 11/11 13:43:46 - mmengine - INFO - Epoch(train) [1][1700/6164]  lr: 2.0000e-02  eta: 5:00:49  time: 0.7858  data_time: 0.0092  memory: 4334  loss: 0.4179  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0156  loss_cls: 0.2008  acc: 95.0195  loss_bbox: 0.1758
# 11/11 13:44:25 - mmengine - INFO - Epoch(train) [1][1750/6164]  lr: 2.0000e-02  eta: 5:00:12  time: 0.7898  data_time: 0.0092  memory: 4334  loss: 0.3927  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0138  loss_cls: 0.1930  acc: 95.6543  loss_bbox: 0.1640
# 11/11 13:45:04 - mmengine - INFO - Epoch(train) [1][1800/6164]  lr: 2.0000e-02  eta: 4:59:32  time: 0.7859  data_time: 0.0093  memory: 4334  loss: 0.3960  loss_rpn_cls: 0.0222  loss_rpn_bbox: 0.0154  loss_cls: 0.1936  acc: 94.9219  loss_bbox: 0.1648
# 11/11 13:45:44 - mmengine - INFO - Epoch(train) [1][1850/6164]  lr: 2.0000e-02  eta: 4:58:53  time: 0.7869  data_time: 0.0088  memory: 4334  loss: 0.4071  loss_rpn_cls: 0.0197  loss_rpn_bbox: 0.0166  loss_cls: 0.1948  acc: 96.2402  loss_bbox: 0.1760
# 11/11 13:46:23 - mmengine - INFO - Epoch(train) [1][1900/6164]  lr: 2.0000e-02  eta: 4:58:18  time: 0.7936  data_time: 0.0087  memory: 4334  loss: 0.4568  loss_rpn_cls: 0.0213  loss_rpn_bbox: 0.0197  loss_cls: 0.2121  acc: 93.6035  loss_bbox: 0.2037
# 11/11 13:47:02 - mmengine - INFO - Epoch(train) [1][1950/6164]  lr: 2.0000e-02  eta: 4:57:36  time: 0.7821  data_time: 0.0087  memory: 4334  loss: 0.4129  loss_rpn_cls: 0.0245  loss_rpn_bbox: 0.0160  loss_cls: 0.2030  acc: 95.2148  loss_bbox: 0.1695
# 11/11 13:47:42 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 13:47:42 - mmengine - INFO - Epoch(train) [1][2000/6164]  lr: 2.0000e-02  eta: 4:57:00  time: 0.7925  data_time: 0.0086  memory: 4334  loss: 0.4103  loss_rpn_cls: 0.0227  loss_rpn_bbox: 0.0179  loss_cls: 0.1962  acc: 93.8477  loss_bbox: 0.1735
# 11/11 13:48:22 - mmengine - INFO - Epoch(train) [1][2050/6164]  lr: 2.0000e-02  eta: 4:56:25  time: 0.7935  data_time: 0.0094  memory: 4334  loss: 0.4121  loss_rpn_cls: 0.0256  loss_rpn_bbox: 0.0175  loss_cls: 0.1970  acc: 91.7480  loss_bbox: 0.1719
# 11/11 13:49:01 - mmengine - INFO - Epoch(train) [1][2100/6164]  lr: 2.0000e-02  eta: 4:55:47  time: 0.7899  data_time: 0.0088  memory: 4334  loss: 0.4082  loss_rpn_cls: 0.0241  loss_rpn_bbox: 0.0175  loss_cls: 0.1889  acc: 97.7051  loss_bbox: 0.1777
# 11/11 13:49:41 - mmengine - INFO - Epoch(train) [1][2150/6164]  lr: 2.0000e-02  eta: 4:55:13  time: 0.7964  data_time: 0.0084  memory: 4334  loss: 0.3699  loss_rpn_cls: 0.0215  loss_rpn_bbox: 0.0155  loss_cls: 0.1747  acc: 97.3145  loss_bbox: 0.1581
# 11/11 13:50:21 - mmengine - INFO - Epoch(train) [1][2200/6164]  lr: 2.0000e-02  eta: 4:54:34  time: 0.7883  data_time: 0.0084  memory: 4334  loss: 0.3797  loss_rpn_cls: 0.0242  loss_rpn_bbox: 0.0155  loss_cls: 0.1759  acc: 97.6074  loss_bbox: 0.1642
# 11/11 13:51:00 - mmengine - INFO - Epoch(train) [1][2250/6164]  lr: 2.0000e-02  eta: 4:53:55  time: 0.7874  data_time: 0.0091  memory: 4334  loss: 0.3806  loss_rpn_cls: 0.0194  loss_rpn_bbox: 0.0153  loss_cls: 0.1778  acc: 95.5078  loss_bbox: 0.1681
# 11/11 13:51:40 - mmengine - INFO - Epoch(train) [1][2300/6164]  lr: 2.0000e-02  eta: 4:53:19  time: 0.7945  data_time: 0.0088  memory: 4334  loss: 0.3747  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0179  loss_cls: 0.1738  acc: 95.4102  loss_bbox: 0.1610
# 11/11 13:52:19 - mmengine - INFO - Epoch(train) [1][2350/6164]  lr: 2.0000e-02  eta: 4:52:40  time: 0.7866  data_time: 0.0091  memory: 4334  loss: 0.4430  loss_rpn_cls: 0.0210  loss_rpn_bbox: 0.0179  loss_cls: 0.2050  acc: 95.2148  loss_bbox: 0.1991
# 11/11 13:52:59 - mmengine - INFO - Epoch(train) [1][2400/6164]  lr: 2.0000e-02  eta: 4:52:04  time: 0.7958  data_time: 0.0092  memory: 4334  loss: 0.3331  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0138  loss_cls: 0.1554  acc: 95.5566  loss_bbox: 0.1464
# 11/11 13:53:39 - mmengine - INFO - Epoch(train) [1][2450/6164]  lr: 2.0000e-02  eta: 4:51:29  time: 0.7964  data_time: 0.0093  memory: 4334  loss: 0.3584  loss_rpn_cls: 0.0217  loss_rpn_bbox: 0.0159  loss_cls: 0.1740  acc: 95.5078  loss_bbox: 0.1468
# 11/11 13:54:18 - mmengine - INFO - Epoch(train) [1][2500/6164]  lr: 2.0000e-02  eta: 4:50:51  time: 0.7902  data_time: 0.0088  memory: 4334  loss: 0.3755  loss_rpn_cls: 0.0186  loss_rpn_bbox: 0.0164  loss_cls: 0.1786  acc: 95.9473  loss_bbox: 0.1620
# 11/11 13:54:57 - mmengine - INFO - Epoch(train) [1][2550/6164]  lr: 2.0000e-02  eta: 4:50:09  time: 0.7829  data_time: 0.0089  memory: 4334  loss: 0.4197  loss_rpn_cls: 0.0223  loss_rpn_bbox: 0.0177  loss_cls: 0.1901  acc: 93.3105  loss_bbox: 0.1896
# 11/11 13:55:36 - mmengine - INFO - Epoch(train) [1][2600/6164]  lr: 2.0000e-02  eta: 4:49:28  time: 0.7837  data_time: 0.0087  memory: 4334  loss: 0.3712  loss_rpn_cls: 0.0237  loss_rpn_bbox: 0.0169  loss_cls: 0.1731  acc: 96.0938  loss_bbox: 0.1575
# 11/11 13:56:16 - mmengine - INFO - Epoch(train) [1][2650/6164]  lr: 2.0000e-02  eta: 4:48:52  time: 0.7947  data_time: 0.0088  memory: 4334  loss: 0.4270  loss_rpn_cls: 0.0216  loss_rpn_bbox: 0.0168  loss_cls: 0.2045  acc: 89.2578  loss_bbox: 0.1840
# 11/11 13:56:56 - mmengine - INFO - Epoch(train) [1][2700/6164]  lr: 2.0000e-02  eta: 4:48:15  time: 0.7944  data_time: 0.0084  memory: 4334  loss: 0.4061  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0173  loss_cls: 0.1876  acc: 96.9727  loss_bbox: 0.1791
# 11/11 13:57:36 - mmengine - INFO - Epoch(train) [1][2750/6164]  lr: 2.0000e-02  eta: 4:47:40  time: 0.7986  data_time: 0.0086  memory: 4334  loss: 0.3436  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0142  loss_cls: 0.1635  acc: 93.4570  loss_bbox: 0.1497
# 11/11 13:58:15 - mmengine - INFO - Epoch(train) [1][2800/6164]  lr: 2.0000e-02  eta: 4:47:00  time: 0.7868  data_time: 0.0088  memory: 4334  loss: 0.3572  loss_rpn_cls: 0.0177  loss_rpn_bbox: 0.0145  loss_cls: 0.1742  acc: 98.4375  loss_bbox: 0.1508
# 11/11 13:58:55 - mmengine - INFO - Epoch(train) [1][2850/6164]  lr: 2.0000e-02  eta: 4:46:22  time: 0.7922  data_time: 0.0090  memory: 4334  loss: 0.3519  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0148  loss_cls: 0.1714  acc: 98.3887  loss_bbox: 0.1452
# 11/11 13:59:35 - mmengine - INFO - Epoch(train) [1][2900/6164]  lr: 2.0000e-02  eta: 4:45:50  time: 0.8079  data_time: 0.0086  memory: 4334  loss: 0.4074  loss_rpn_cls: 0.0212  loss_rpn_bbox: 0.0176  loss_cls: 0.1901  acc: 97.4609  loss_bbox: 0.1785
# 11/11 14:00:15 - mmengine - INFO - Epoch(train) [1][2950/6164]  lr: 2.0000e-02  eta: 4:45:12  time: 0.7916  data_time: 0.0088  memory: 4334  loss: 0.4158  loss_rpn_cls: 0.0171  loss_rpn_bbox: 0.0171  loss_cls: 0.1890  acc: 96.8750  loss_bbox: 0.1925
# 11/11 14:00:55 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 14:00:55 - mmengine - INFO - Epoch(train) [1][3000/6164]  lr: 2.0000e-02  eta: 4:44:38  time: 0.8021  data_time: 0.0086  memory: 4334  loss: 0.4165  loss_rpn_cls: 0.0252  loss_rpn_bbox: 0.0172  loss_cls: 0.1950  acc: 93.9453  loss_bbox: 0.1790
# 11/11 14:01:34 - mmengine - INFO - Epoch(train) [1][3050/6164]  lr: 2.0000e-02  eta: 4:43:58  time: 0.7864  data_time: 0.0093  memory: 4334  loss: 0.3856  loss_rpn_cls: 0.0188  loss_rpn_bbox: 0.0155  loss_cls: 0.1817  acc: 95.5566  loss_bbox: 0.1696
# 11/11 14:02:13 - mmengine - INFO - Epoch(train) [1][3100/6164]  lr: 2.0000e-02  eta: 4:43:15  time: 0.7800  data_time: 0.0091  memory: 4334  loss: 0.3773  loss_rpn_cls: 0.0171  loss_rpn_bbox: 0.0153  loss_cls: 0.1774  acc: 96.0938  loss_bbox: 0.1676
# 11/11 14:02:52 - mmengine - INFO - Epoch(train) [1][3150/6164]  lr: 2.0000e-02  eta: 4:42:34  time: 0.7822  data_time: 0.0086  memory: 4334  loss: 0.4412  loss_rpn_cls: 0.0230  loss_rpn_bbox: 0.0174  loss_cls: 0.2102  acc: 97.7051  loss_bbox: 0.1905
# 11/11 14:03:32 - mmengine - INFO - Epoch(train) [1][3200/6164]  lr: 2.0000e-02  eta: 4:41:56  time: 0.7929  data_time: 0.0085  memory: 4334  loss: 0.3989  loss_rpn_cls: 0.0189  loss_rpn_bbox: 0.0159  loss_cls: 0.1893  acc: 96.8262  loss_bbox: 0.1747
# 11/11 14:04:11 - mmengine - INFO - Epoch(train) [1][3250/6164]  lr: 2.0000e-02  eta: 4:41:14  time: 0.7804  data_time: 0.0091  memory: 4334  loss: 0.4326  loss_rpn_cls: 0.0202  loss_rpn_bbox: 0.0178  loss_cls: 0.2036  acc: 94.5312  loss_bbox: 0.1910
# 11/11 14:04:50 - mmengine - INFO - Epoch(train) [1][3300/6164]  lr: 2.0000e-02  eta: 4:40:35  time: 0.7907  data_time: 0.0090  memory: 4334  loss: 0.4231  loss_rpn_cls: 0.0201  loss_rpn_bbox: 0.0180  loss_cls: 0.2021  acc: 97.4121  loss_bbox: 0.1829
# 11/11 14:05:30 - mmengine - INFO - Epoch(train) [1][3350/6164]  lr: 2.0000e-02  eta: 4:39:54  time: 0.7818  data_time: 0.0094  memory: 4334  loss: 0.3642  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0145  loss_cls: 0.1746  acc: 94.3359  loss_bbox: 0.1596
# 11/11 14:06:09 - mmengine - INFO - Epoch(train) [1][3400/6164]  lr: 2.0000e-02  eta: 4:39:15  time: 0.7917  data_time: 0.0084  memory: 4334  loss: 0.4090  loss_rpn_cls: 0.0188  loss_rpn_bbox: 0.0167  loss_cls: 0.1950  acc: 97.4609  loss_bbox: 0.1786
# 11/11 14:06:50 - mmengine - INFO - Epoch(train) [1][3450/6164]  lr: 2.0000e-02  eta: 4:38:42  time: 0.8087  data_time: 0.0088  memory: 4334  loss: 0.3578  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0166  loss_cls: 0.1666  acc: 95.5078  loss_bbox: 0.1562
# 11/11 14:07:29 - mmengine - INFO - Epoch(train) [1][3500/6164]  lr: 2.0000e-02  eta: 4:38:05  time: 0.7968  data_time: 0.0092  memory: 4334  loss: 0.4013  loss_rpn_cls: 0.0217  loss_rpn_bbox: 0.0184  loss_cls: 0.1868  acc: 95.3125  loss_bbox: 0.1745
# 11/11 14:08:09 - mmengine - INFO - Epoch(train) [1][3550/6164]  lr: 2.0000e-02  eta: 4:37:28  time: 0.7956  data_time: 0.0096  memory: 4334  loss: 0.4231  loss_rpn_cls: 0.0209  loss_rpn_bbox: 0.0172  loss_cls: 0.1952  acc: 96.6797  loss_bbox: 0.1898
# 11/11 14:08:49 - mmengine - INFO - Epoch(train) [1][3600/6164]  lr: 2.0000e-02  eta: 4:36:51  time: 0.7966  data_time: 0.0093  memory: 4334  loss: 0.4292  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0180  loss_cls: 0.2005  acc: 92.8223  loss_bbox: 0.1901
# 11/11 14:09:29 - mmengine - INFO - Epoch(train) [1][3650/6164]  lr: 2.0000e-02  eta: 4:36:13  time: 0.7943  data_time: 0.0092  memory: 4334  loss: 0.3294  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0147  loss_cls: 0.1500  acc: 96.1914  loss_bbox: 0.1486
# 11/11 14:10:09 - mmengine - INFO - Epoch(train) [1][3700/6164]  lr: 2.0000e-02  eta: 4:35:35  time: 0.7964  data_time: 0.0089  memory: 4334  loss: 0.3896  loss_rpn_cls: 0.0196  loss_rpn_bbox: 0.0194  loss_cls: 0.1760  acc: 93.0664  loss_bbox: 0.1746
# 11/11 14:10:48 - mmengine - INFO - Epoch(train) [1][3750/6164]  lr: 2.0000e-02  eta: 4:34:57  time: 0.7946  data_time: 0.0088  memory: 4334  loss: 0.4067  loss_rpn_cls: 0.0177  loss_rpn_bbox: 0.0177  loss_cls: 0.1850  acc: 93.8965  loss_bbox: 0.1863
# 11/11 14:11:28 - mmengine - INFO - Epoch(train) [1][3800/6164]  lr: 2.0000e-02  eta: 4:34:21  time: 0.8008  data_time: 0.0089  memory: 4334  loss: 0.4071  loss_rpn_cls: 0.0213  loss_rpn_bbox: 0.0172  loss_cls: 0.1850  acc: 97.3633  loss_bbox: 0.1836
# 11/11 14:12:08 - mmengine - INFO - Epoch(train) [1][3850/6164]  lr: 2.0000e-02  eta: 4:33:43  time: 0.7942  data_time: 0.0090  memory: 4334  loss: 0.3799  loss_rpn_cls: 0.0178  loss_rpn_bbox: 0.0146  loss_cls: 0.1770  acc: 96.1426  loss_bbox: 0.1705
# 11/11 14:12:48 - mmengine - INFO - Epoch(train) [1][3900/6164]  lr: 2.0000e-02  eta: 4:33:05  time: 0.7959  data_time: 0.0096  memory: 4334  loss: 0.3917  loss_rpn_cls: 0.0166  loss_rpn_bbox: 0.0160  loss_cls: 0.1863  acc: 96.4355  loss_bbox: 0.1729
# 11/11 14:13:27 - mmengine - INFO - Epoch(train) [1][3950/6164]  lr: 2.0000e-02  eta: 4:32:24  time: 0.7827  data_time: 0.0094  memory: 4334  loss: 0.3600  loss_rpn_cls: 0.0159  loss_rpn_bbox: 0.0144  loss_cls: 0.1618  acc: 92.8711  loss_bbox: 0.1679
# 11/11 14:14:07 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 14:14:07 - mmengine - INFO - Epoch(train) [1][4000/6164]  lr: 2.0000e-02  eta: 4:31:46  time: 0.7929  data_time: 0.0086  memory: 4334  loss: 0.3981  loss_rpn_cls: 0.0170  loss_rpn_bbox: 0.0168  loss_cls: 0.1840  acc: 93.0664  loss_bbox: 0.1803
# 11/11 14:14:46 - mmengine - INFO - Epoch(train) [1][4050/6164]  lr: 2.0000e-02  eta: 4:31:08  time: 0.7967  data_time: 0.0095  memory: 4334  loss: 0.3799  loss_rpn_cls: 0.0199  loss_rpn_bbox: 0.0173  loss_cls: 0.1730  acc: 96.5820  loss_bbox: 0.1698
# 11/11 14:15:26 - mmengine - INFO - Epoch(train) [1][4100/6164]  lr: 2.0000e-02  eta: 4:30:28  time: 0.7872  data_time: 0.0100  memory: 4334  loss: 0.3812  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0148  loss_cls: 0.1815  acc: 95.9473  loss_bbox: 0.1674
# 11/11 14:16:06 - mmengine - INFO - Epoch(train) [1][4150/6164]  lr: 2.0000e-02  eta: 4:29:53  time: 0.8063  data_time: 0.0088  memory: 4334  loss: 0.3598  loss_rpn_cls: 0.0219  loss_rpn_bbox: 0.0157  loss_cls: 0.1623  acc: 95.6543  loss_bbox: 0.1599
# 11/11 14:16:46 - mmengine - INFO - Epoch(train) [1][4200/6164]  lr: 2.0000e-02  eta: 4:29:15  time: 0.7989  data_time: 0.0091  memory: 4334  loss: 0.4204  loss_rpn_cls: 0.0251  loss_rpn_bbox: 0.0201  loss_cls: 0.1851  acc: 95.9961  loss_bbox: 0.1902
# 11/11 14:17:26 - mmengine - INFO - Epoch(train) [1][4250/6164]  lr: 2.0000e-02  eta: 4:28:37  time: 0.7951  data_time: 0.0090  memory: 4334  loss: 0.3800  loss_rpn_cls: 0.0191  loss_rpn_bbox: 0.0166  loss_cls: 0.1754  acc: 93.9453  loss_bbox: 0.1689
# 11/11 14:18:06 - mmengine - INFO - Epoch(train) [1][4300/6164]  lr: 2.0000e-02  eta: 4:27:59  time: 0.7979  data_time: 0.0090  memory: 4334  loss: 0.3544  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0154  loss_cls: 0.1587  acc: 93.2617  loss_bbox: 0.1627
# 11/11 14:18:46 - mmengine - INFO - Epoch(train) [1][4350/6164]  lr: 2.0000e-02  eta: 4:27:22  time: 0.7976  data_time: 0.0094  memory: 4334  loss: 0.3864  loss_rpn_cls: 0.0198  loss_rpn_bbox: 0.0170  loss_cls: 0.1774  acc: 94.5801  loss_bbox: 0.1723
# 11/11 14:19:25 - mmengine - INFO - Epoch(train) [1][4400/6164]  lr: 2.0000e-02  eta: 4:26:44  time: 0.7964  data_time: 0.0086  memory: 4334  loss: 0.3948  loss_rpn_cls: 0.0173  loss_rpn_bbox: 0.0152  loss_cls: 0.1826  acc: 94.8242  loss_bbox: 0.1797
# 11/11 14:20:05 - mmengine - INFO - Epoch(train) [1][4450/6164]  lr: 2.0000e-02  eta: 4:26:07  time: 0.8016  data_time: 0.0091  memory: 4334  loss: 0.3915  loss_rpn_cls: 0.0160  loss_rpn_bbox: 0.0154  loss_cls: 0.1770  acc: 95.6055  loss_bbox: 0.1830
# 11/11 14:20:45 - mmengine - INFO - Epoch(train) [1][4500/6164]  lr: 2.0000e-02  eta: 4:25:28  time: 0.7923  data_time: 0.0090  memory: 4334  loss: 0.3179  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0156  loss_cls: 0.1438  acc: 93.6523  loss_bbox: 0.1430
# 11/11 14:21:25 - mmengine - INFO - Epoch(train) [1][4550/6164]  lr: 2.0000e-02  eta: 4:24:52  time: 0.8065  data_time: 0.0091  memory: 4334  loss: 0.3637  loss_rpn_cls: 0.0152  loss_rpn_bbox: 0.0166  loss_cls: 0.1637  acc: 94.5312  loss_bbox: 0.1682
# 11/11 14:22:05 - mmengine - INFO - Epoch(train) [1][4600/6164]  lr: 2.0000e-02  eta: 4:24:14  time: 0.7968  data_time: 0.0085  memory: 4334  loss: 0.3760  loss_rpn_cls: 0.0207  loss_rpn_bbox: 0.0159  loss_cls: 0.1686  acc: 97.4609  loss_bbox: 0.1707
# 11/11 14:22:45 - mmengine - INFO - Epoch(train) [1][4650/6164]  lr: 2.0000e-02  eta: 4:23:35  time: 0.7922  data_time: 0.0096  memory: 4334  loss: 0.3419  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0163  loss_cls: 0.1591  acc: 95.6543  loss_bbox: 0.1484
# 11/11 14:23:24 - mmengine - INFO - Epoch(train) [1][4700/6164]  lr: 2.0000e-02  eta: 4:22:54  time: 0.7878  data_time: 0.0087  memory: 4334  loss: 0.3523  loss_rpn_cls: 0.0166  loss_rpn_bbox: 0.0142  loss_cls: 0.1580  acc: 94.4336  loss_bbox: 0.1635
# 11/11 14:24:04 - mmengine - INFO - Epoch(train) [1][4750/6164]  lr: 2.0000e-02  eta: 4:22:17  time: 0.7988  data_time: 0.0087  memory: 4334  loss: 0.3536  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0164  loss_cls: 0.1633  acc: 95.2148  loss_bbox: 0.1557
# 11/11 14:24:44 - mmengine - INFO - Epoch(train) [1][4800/6164]  lr: 2.0000e-02  eta: 4:21:37  time: 0.7911  data_time: 0.0092  memory: 4334  loss: 0.3963  loss_rpn_cls: 0.0178  loss_rpn_bbox: 0.0182  loss_cls: 0.1782  acc: 91.6016  loss_bbox: 0.1821
# 11/11 14:25:23 - mmengine - INFO - Epoch(train) [1][4850/6164]  lr: 2.0000e-02  eta: 4:20:58  time: 0.7930  data_time: 0.0092  memory: 4334  loss: 0.3938  loss_rpn_cls: 0.0202  loss_rpn_bbox: 0.0158  loss_cls: 0.1810  acc: 94.2871  loss_bbox: 0.1768
# 11/11 14:26:03 - mmengine - INFO - Epoch(train) [1][4900/6164]  lr: 2.0000e-02  eta: 4:20:20  time: 0.7965  data_time: 0.0093  memory: 4334  loss: 0.3919  loss_rpn_cls: 0.0168  loss_rpn_bbox: 0.0161  loss_cls: 0.1834  acc: 95.1172  loss_bbox: 0.1756
# 11/11 14:26:42 - mmengine - INFO - Epoch(train) [1][4950/6164]  lr: 2.0000e-02  eta: 4:19:39  time: 0.7852  data_time: 0.0088  memory: 4334  loss: 0.3494  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0150  loss_cls: 0.1594  acc: 93.1641  loss_bbox: 0.1586
# 11/11 14:27:22 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 14:27:22 - mmengine - INFO - Epoch(train) [1][5000/6164]  lr: 2.0000e-02  eta: 4:19:00  time: 0.7911  data_time: 0.0087  memory: 4334  loss: 0.4113  loss_rpn_cls: 0.0149  loss_rpn_bbox: 0.0166  loss_cls: 0.1897  acc: 91.6504  loss_bbox: 0.1902
# 11/11 14:28:02 - mmengine - INFO - Epoch(train) [1][5050/6164]  lr: 2.0000e-02  eta: 4:18:21  time: 0.7954  data_time: 0.0086  memory: 4334  loss: 0.3821  loss_rpn_cls: 0.0217  loss_rpn_bbox: 0.0193  loss_cls: 0.1682  acc: 94.8730  loss_bbox: 0.1729
# 11/11 14:28:42 - mmengine - INFO - Epoch(train) [1][5100/6164]  lr: 2.0000e-02  eta: 4:17:42  time: 0.7941  data_time: 0.0087  memory: 4334  loss: 0.3683  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0160  loss_cls: 0.1652  acc: 97.5098  loss_bbox: 0.1687
# 11/11 14:29:21 - mmengine - INFO - Epoch(train) [1][5150/6164]  lr: 2.0000e-02  eta: 4:17:03  time: 0.7925  data_time: 0.0087  memory: 4334  loss: 0.3526  loss_rpn_cls: 0.0163  loss_rpn_bbox: 0.0140  loss_cls: 0.1581  acc: 98.4375  loss_bbox: 0.1642
# 11/11 14:30:01 - mmengine - INFO - Epoch(train) [1][5200/6164]  lr: 2.0000e-02  eta: 4:16:25  time: 0.7977  data_time: 0.0096  memory: 4334  loss: 0.3624  loss_rpn_cls: 0.0146  loss_rpn_bbox: 0.0149  loss_cls: 0.1629  acc: 96.2402  loss_bbox: 0.1701
# 11/11 14:30:41 - mmengine - INFO - Epoch(train) [1][5250/6164]  lr: 2.0000e-02  eta: 4:15:47  time: 0.7992  data_time: 0.0091  memory: 4334  loss: 0.4024  loss_rpn_cls: 0.0183  loss_rpn_bbox: 0.0187  loss_cls: 0.1829  acc: 96.7773  loss_bbox: 0.1824
# 11/11 14:31:20 - mmengine - INFO - Epoch(train) [1][5300/6164]  lr: 2.0000e-02  eta: 4:15:06  time: 0.7855  data_time: 0.0084  memory: 4334  loss: 0.3703  loss_rpn_cls: 0.0200  loss_rpn_bbox: 0.0163  loss_cls: 0.1745  acc: 94.0430  loss_bbox: 0.1595
# 11/11 14:32:00 - mmengine - INFO - Epoch(train) [1][5350/6164]  lr: 2.0000e-02  eta: 4:14:26  time: 0.7884  data_time: 0.0087  memory: 4334  loss: 0.3567  loss_rpn_cls: 0.0142  loss_rpn_bbox: 0.0155  loss_cls: 0.1627  acc: 97.6074  loss_bbox: 0.1644
# 11/11 14:32:40 - mmengine - INFO - Epoch(train) [1][5400/6164]  lr: 2.0000e-02  eta: 4:13:49  time: 0.8013  data_time: 0.0084  memory: 4334  loss: 0.3438  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0146  loss_cls: 0.1633  acc: 95.8984  loss_bbox: 0.1505
# 11/11 14:33:19 - mmengine - INFO - Epoch(train) [1][5450/6164]  lr: 2.0000e-02  eta: 4:13:08  time: 0.7864  data_time: 0.0092  memory: 4334  loss: 0.3553  loss_rpn_cls: 0.0153  loss_rpn_bbox: 0.0153  loss_cls: 0.1560  acc: 96.6309  loss_bbox: 0.1687
# 11/11 14:33:59 - mmengine - INFO - Epoch(train) [1][5500/6164]  lr: 2.0000e-02  eta: 4:12:30  time: 0.7952  data_time: 0.0092  memory: 4334  loss: 0.3708  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0169  loss_cls: 0.1728  acc: 95.6055  loss_bbox: 0.1627
# 11/11 14:34:39 - mmengine - INFO - Epoch(train) [1][5550/6164]  lr: 2.0000e-02  eta: 4:11:51  time: 0.7958  data_time: 0.0087  memory: 4334  loss: 0.3419  loss_rpn_cls: 0.0159  loss_rpn_bbox: 0.0147  loss_cls: 0.1555  acc: 97.8516  loss_bbox: 0.1557
# 11/11 14:35:18 - mmengine - INFO - Epoch(train) [1][5600/6164]  lr: 2.0000e-02  eta: 4:11:12  time: 0.7931  data_time: 0.0091  memory: 4334  loss: 0.3454  loss_rpn_cls: 0.0147  loss_rpn_bbox: 0.0152  loss_cls: 0.1566  acc: 97.9004  loss_bbox: 0.1590
# 11/11 14:35:58 - mmengine - INFO - Epoch(train) [1][5650/6164]  lr: 2.0000e-02  eta: 4:10:32  time: 0.7914  data_time: 0.0087  memory: 4334  loss: 0.3564  loss_rpn_cls: 0.0156  loss_rpn_bbox: 0.0147  loss_cls: 0.1552  acc: 96.6797  loss_bbox: 0.1709
# 11/11 14:36:37 - mmengine - INFO - Epoch(train) [1][5700/6164]  lr: 2.0000e-02  eta: 4:09:53  time: 0.7903  data_time: 0.0089  memory: 4334  loss: 0.3688  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0157  loss_cls: 0.1631  acc: 95.2148  loss_bbox: 0.1726
# 11/11 14:37:16 - mmengine - INFO - Epoch(train) [1][5750/6164]  lr: 2.0000e-02  eta: 4:09:11  time: 0.7790  data_time: 0.0089  memory: 4334  loss: 0.3940  loss_rpn_cls: 0.0169  loss_rpn_bbox: 0.0157  loss_cls: 0.1785  acc: 95.2148  loss_bbox: 0.1829
# 11/11 14:37:56 - mmengine - INFO - Epoch(train) [1][5800/6164]  lr: 2.0000e-02  eta: 4:08:30  time: 0.7836  data_time: 0.0088  memory: 4334  loss: 0.4002  loss_rpn_cls: 0.0158  loss_rpn_bbox: 0.0155  loss_cls: 0.1841  acc: 98.0957  loss_bbox: 0.1847
# 11/11 14:38:36 - mmengine - INFO - Epoch(train) [1][5850/6164]  lr: 2.0000e-02  eta: 4:07:53  time: 0.8007  data_time: 0.0092  memory: 4334  loss: 0.3527  loss_rpn_cls: 0.0154  loss_rpn_bbox: 0.0150  loss_cls: 0.1571  acc: 95.7520  loss_bbox: 0.1652
# 11/11 14:39:15 - mmengine - INFO - Epoch(train) [1][5900/6164]  lr: 2.0000e-02  eta: 4:07:14  time: 0.7949  data_time: 0.0093  memory: 4334  loss: 0.3360  loss_rpn_cls: 0.0243  loss_rpn_bbox: 0.0158  loss_cls: 0.1403  acc: 92.1875  loss_bbox: 0.1555
# 11/11 14:39:55 - mmengine - INFO - Epoch(train) [1][5950/6164]  lr: 2.0000e-02  eta: 4:06:34  time: 0.7881  data_time: 0.0096  memory: 4334  loss: 0.3456  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0147  loss_cls: 0.1539  acc: 93.0664  loss_bbox: 0.1607
# 11/11 14:40:34 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 14:40:34 - mmengine - INFO - Epoch(train) [1][6000/6164]  lr: 2.0000e-02  eta: 4:05:55  time: 0.7940  data_time: 0.0086  memory: 4334  loss: 0.3446  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0144  loss_cls: 0.1525  acc: 95.9473  loss_bbox: 0.1628
# 11/11 14:41:14 - mmengine - INFO - Epoch(train) [1][6050/6164]  lr: 2.0000e-02  eta: 4:05:14  time: 0.7853  data_time: 0.0092  memory: 4334  loss: 0.3389  loss_rpn_cls: 0.0179  loss_rpn_bbox: 0.0142  loss_cls: 0.1489  acc: 94.8730  loss_bbox: 0.1579
# ...
# 11/11 19:03:07 - mmengine - INFO - Epoch(train) [4][5850/6164]  lr: 2.0000e-02  eta: 0:04:08  time: 0.7928  data_time: 0.0096  memory: 4334  loss: 0.3024  loss_rpn_cls: 0.0089  loss_rpn_bbox: 0.0131  loss_cls: 0.1233  acc: 97.9980  loss_bbox: 0.1571
# 11/11 19:03:47 - mmengine - INFO - Epoch(train) [4][5900/6164]  lr: 2.0000e-02  eta: 0:03:29  time: 0.7979  data_time: 0.0090  memory: 4334  loss: 0.2561  loss_rpn_cls: 0.0069  loss_rpn_bbox: 0.0111  loss_cls: 0.1026  acc: 95.8984  loss_bbox: 0.1356
# 11/11 19:04:27 - mmengine - INFO - Epoch(train) [4][5950/6164]  lr: 2.0000e-02  eta: 0:02:49  time: 0.8037  data_time: 0.0093  memory: 4334  loss: 0.2894  loss_rpn_cls: 0.0080  loss_rpn_bbox: 0.0141  loss_cls: 0.1147  acc: 96.8750  loss_bbox: 0.1525
# 11/11 19:05:06 - mmengine - INFO - Epoch(train) [4][6000/6164]  lr: 2.0000e-02  eta: 0:02:10  time: 0.7813  data_time: 0.0084  memory: 4334  loss: 0.2632  loss_rpn_cls: 0.0076  loss_rpn_bbox: 0.0122  loss_cls: 0.1037  acc: 96.5820  loss_bbox: 0.1397
# 11/11 19:05:46 - mmengine - INFO - Epoch(train) [4][6050/6164]  lr: 2.0000e-02  eta: 0:01:30  time: 0.7975  data_time: 0.0085  memory: 4334  loss: 0.2893  loss_rpn_cls: 0.0084  loss_rpn_bbox: 0.0133  loss_cls: 0.1164  acc: 96.0938  loss_bbox: 0.1511
# 11/11 19:06:26 - mmengine - INFO - Epoch(train) [4][6100/6164]  lr: 2.0000e-02  eta: 0:00:50  time: 0.7988  data_time: 0.0097  memory: 4334  loss: 0.2888  loss_rpn_cls: 0.0097  loss_rpn_bbox: 0.0130  loss_cls: 0.1196  acc: 96.5332  loss_bbox: 0.1466
# 11/11 19:07:06 - mmengine - INFO - Epoch(train) [4][6150/6164]  lr: 2.0000e-02  eta: 0:00:11  time: 0.7923  data_time: 0.0098  memory: 4334  loss: 0.2290  loss_rpn_cls: 0.0070  loss_rpn_bbox: 0.0108  loss_cls: 0.0915  acc: 97.8027  loss_bbox: 0.1197
# 11/11 19:07:16 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251111_132002
# 11/11 19:07:16 - mmengine - INFO - Saving checkpoint at 4 epochs
# 11/11 19:07:22 - mmengine - INFO - Epoch(val) [4][  50/4952]    eta: 0:06:32  time: 0.0800  data_time: 0.0029  memory: 5416
# 11/11 19:07:26 - mmengine - INFO - Epoch(val) [4][ 100/4952]    eta: 0:06:28  time: 0.0800  data_time: 0.0025  memory: 692
# 11/11 19:07:30 - mmengine - INFO - Epoch(val) [4][ 150/4952]    eta: 0:06:25  time: 0.0810  data_time: 0.0025  memory: 681
# 11/11 19:07:34 - mmengine - INFO - Epoch(val) [4][ 200/4952]    eta: 0:06:21  time: 0.0804  data_time: 0.0026  memory: 673
# 11/11 19:07:38 - mmengine - INFO - Epoch(val) [4][ 250/4952]    eta: 0:06:17  time: 0.0802  data_time: 0.0024  memory: 692
# 11/11 19:07:42 - mmengine - INFO - Epoch(val) [4][ 300/4952]    eta: 0:06:12  time: 0.0789  data_time: 0.0027  memory: 685
# 11/11 19:07:46 - mmengine - INFO - Epoch(val) [4][ 350/4952]    eta: 0:06:08  time: 0.0794  data_time: 0.0025  memory: 692
# 11/11 19:07:50 - mmengine - INFO - Epoch(val) [4][ 400/4952]    eta: 0:06:04  time: 0.0807  data_time: 0.0025  memory: 692
# 11/11 19:07:54 - mmengine - INFO - Epoch(val) [4][ 450/4952]    eta: 0:06:00  time: 0.0804  data_time: 0.0027  memory: 681
# 11/11 19:07:58 - mmengine - INFO - Epoch(val) [4][ 500/4952]    eta: 0:05:56  time: 0.0796  data_time: 0.0027  memory: 681
# 11/11 19:08:02 - mmengine - INFO - Epoch(val) [4][ 550/4952]    eta: 0:05:52  time: 0.0794  data_time: 0.0026  memory: 685
# 11/11 19:08:06 - mmengine - INFO - Epoch(val) [4][ 600/4952]    eta: 0:05:48  time: 0.0803  data_time: 0.0026  memory: 681
# 11/11 19:08:10 - mmengine - INFO - Epoch(val) [4][ 650/4952]    eta: 0:05:44  time: 0.0797  data_time: 0.0025  memory: 685
# 11/11 19:08:14 - mmengine - INFO - Epoch(val) [4][ 700/4952]    eta: 0:05:40  time: 0.0797  data_time: 0.0024  memory: 681
# 11/11 19:08:18 - mmengine - INFO - Epoch(val) [4][ 750/4952]    eta: 0:05:36  time: 0.0804  data_time: 0.0024  memory: 685
# 11/11 19:08:22 - mmengine - INFO - Epoch(val) [4][ 800/4952]    eta: 0:05:32  time: 0.0797  data_time: 0.0026  memory: 681
# 11/11 19:08:26 - mmengine - INFO - Epoch(val) [4][ 850/4952]    eta: 0:05:28  time: 0.0797  data_time: 0.0026  memory: 681
# 11/11 19:08:30 - mmengine - INFO - Epoch(val) [4][ 900/4952]    eta: 0:05:24  time: 0.0801  data_time: 0.0028  memory: 692
# 11/11 19:08:34 - mmengine - INFO - Epoch(val) [4][ 950/4952]    eta: 0:05:19  time: 0.0794  data_time: 0.0025  memory: 685
# 11/11 19:08:38 - mmengine - INFO - Epoch(val) [4][1000/4952]    eta: 0:05:15  time: 0.0801  data_time: 0.0025  memory: 692
# 11/11 19:08:42 - mmengine - INFO - Epoch(val) [4][1050/4952]    eta: 0:05:12  time: 0.0802  data_time: 0.0024  memory: 692
# 11/11 19:08:46 - mmengine - INFO - Epoch(val) [4][1100/4952]    eta: 0:05:08  time: 0.0805  data_time: 0.0028  memory: 681
# 11/11 19:08:50 - mmengine - INFO - Epoch(val) [4][1150/4952]    eta: 0:05:04  time: 0.0803  data_time: 0.0029  memory: 692
# 11/11 19:08:54 - mmengine - INFO - Epoch(val) [4][1200/4952]    eta: 0:05:00  time: 0.0800  data_time: 0.0025  memory: 685
# 11/11 19:08:58 - mmengine - INFO - Epoch(val) [4][1250/4952]    eta: 0:04:56  time: 0.0804  data_time: 0.0025  memory: 681
# 11/11 19:09:02 - mmengine - INFO - Epoch(val) [4][1300/4952]    eta: 0:04:52  time: 0.0800  data_time: 0.0027  memory: 681
# 11/11 19:09:06 - mmengine - INFO - Epoch(val) [4][1350/4952]    eta: 0:04:48  time: 0.0792  data_time: 0.0024  memory: 692
# 11/11 19:09:10 - mmengine - INFO - Epoch(val) [4][1400/4952]    eta: 0:04:44  time: 0.0796  data_time: 0.0027  memory: 681
# 11/11 19:09:14 - mmengine - INFO - Epoch(val) [4][1450/4952]    eta: 0:04:40  time: 0.0803  data_time: 0.0027  memory: 692
# 11/11 19:09:18 - mmengine - INFO - Epoch(val) [4][1500/4952]    eta: 0:04:36  time: 0.0809  data_time: 0.0025  memory: 685
# 11/11 19:09:22 - mmengine - INFO - Epoch(val) [4][1550/4952]    eta: 0:04:32  time: 0.0799  data_time: 0.0023  memory: 681
# 11/11 19:09:26 - mmengine - INFO - Epoch(val) [4][1600/4952]    eta: 0:04:28  time: 0.0807  data_time: 0.0025  memory: 692
# 11/11 19:09:30 - mmengine - INFO - Epoch(val) [4][1650/4952]    eta: 0:04:24  time: 0.0800  data_time: 0.0025  memory: 681
# 11/11 19:09:34 - mmengine - INFO - Epoch(val) [4][1700/4952]    eta: 0:04:20  time: 0.0795  data_time: 0.0024  memory: 681
# 11/11 19:09:38 - mmengine - INFO - Epoch(val) [4][1750/4952]    eta: 0:04:16  time: 0.0799  data_time: 0.0024  memory: 673
# 11/11 19:09:42 - mmengine - INFO - Epoch(val) [4][1800/4952]    eta: 0:04:12  time: 0.0793  data_time: 0.0024  memory: 673
# 11/11 19:09:46 - mmengine - INFO - Epoch(val) [4][1850/4952]    eta: 0:04:08  time: 0.0796  data_time: 0.0026  memory: 673
# 11/11 19:09:50 - mmengine - INFO - Epoch(val) [4][1900/4952]    eta: 0:04:04  time: 0.0788  data_time: 0.0024  memory: 681
# 11/11 19:09:54 - mmengine - INFO - Epoch(val) [4][1950/4952]    eta: 0:04:00  time: 0.0799  data_time: 0.0023  memory: 685
# 11/11 19:09:58 - mmengine - INFO - Epoch(val) [4][2000/4952]    eta: 0:03:55  time: 0.0793  data_time: 0.0024  memory: 681
# 11/11 19:10:02 - mmengine - INFO - Epoch(val) [4][2050/4952]    eta: 0:03:51  time: 0.0802  data_time: 0.0026  memory: 692
# 11/11 19:10:06 - mmengine - INFO - Epoch(val) [4][2100/4952]    eta: 0:03:48  time: 0.0805  data_time: 0.0025  memory: 681
# 11/11 19:10:10 - mmengine - INFO - Epoch(val) [4][2150/4952]    eta: 0:03:43  time: 0.0789  data_time: 0.0025  memory: 685
# 11/11 19:10:14 - mmengine - INFO - Epoch(val) [4][2200/4952]    eta: 0:03:39  time: 0.0802  data_time: 0.0023  memory: 681
# 11/11 19:10:18 - mmengine - INFO - Epoch(val) [4][2250/4952]    eta: 0:03:35  time: 0.0798  data_time: 0.0027  memory: 692
# 11/11 19:10:22 - mmengine - INFO - Epoch(val) [4][2300/4952]    eta: 0:03:31  time: 0.0791  data_time: 0.0025  memory: 681
# 11/11 19:10:26 - mmengine - INFO - Epoch(val) [4][2350/4952]    eta: 0:03:27  time: 0.0781  data_time: 0.0026  memory: 681
# 11/11 19:10:30 - mmengine - INFO - Epoch(val) [4][2400/4952]    eta: 0:03:23  time: 0.0805  data_time: 0.0028  memory: 681
# 11/11 19:10:34 - mmengine - INFO - Epoch(val) [4][2450/4952]    eta: 0:03:19  time: 0.0794  data_time: 0.0022  memory: 681
# 11/11 19:10:38 - mmengine - INFO - Epoch(val) [4][2500/4952]    eta: 0:03:15  time: 0.0799  data_time: 0.0023  memory: 692
# 11/11 19:10:42 - mmengine - INFO - Epoch(val) [4][2550/4952]    eta: 0:03:11  time: 0.0802  data_time: 0.0025  memory: 673
# 11/11 19:10:46 - mmengine - INFO - Epoch(val) [4][2600/4952]    eta: 0:03:07  time: 0.0793  data_time: 0.0024  memory: 685
# 11/11 19:10:50 - mmengine - INFO - Epoch(val) [4][2650/4952]    eta: 0:03:03  time: 0.0801  data_time: 0.0024  memory: 685
# 11/11 19:10:54 - mmengine - INFO - Epoch(val) [4][2700/4952]    eta: 0:02:59  time: 0.0804  data_time: 0.0024  memory: 692
# 11/11 19:10:58 - mmengine - INFO - Epoch(val) [4][2750/4952]    eta: 0:02:55  time: 0.0804  data_time: 0.0025  memory: 681
# 11/11 19:11:02 - mmengine - INFO - Epoch(val) [4][2800/4952]    eta: 0:02:51  time: 0.0792  data_time: 0.0026  memory: 681
# 11/11 19:11:06 - mmengine - INFO - Epoch(val) [4][2850/4952]    eta: 0:02:47  time: 0.0801  data_time: 0.0025  memory: 681
# 11/11 19:11:10 - mmengine - INFO - Epoch(val) [4][2900/4952]    eta: 0:02:43  time: 0.0786  data_time: 0.0027  memory: 685
# 11/11 19:11:14 - mmengine - INFO - Epoch(val) [4][2950/4952]    eta: 0:02:39  time: 0.0801  data_time: 0.0025  memory: 692
# 11/11 19:11:18 - mmengine - INFO - Epoch(val) [4][3000/4952]    eta: 0:02:35  time: 0.0804  data_time: 0.0027  memory: 673
# 11/11 19:11:22 - mmengine - INFO - Epoch(val) [4][3050/4952]    eta: 0:02:31  time: 0.0792  data_time: 0.0023  memory: 681
# 11/11 19:11:26 - mmengine - INFO - Epoch(val) [4][3100/4952]    eta: 0:02:27  time: 0.0803  data_time: 0.0023  memory: 692
# 11/11 19:11:30 - mmengine - INFO - Epoch(val) [4][3150/4952]    eta: 0:02:24  time: 0.0825  data_time: 0.0026  memory: 681
# 11/11 19:11:34 - mmengine - INFO - Epoch(val) [4][3200/4952]    eta: 0:02:20  time: 0.0799  data_time: 0.0026  memory: 681
# 11/11 19:11:38 - mmengine - INFO - Epoch(val) [4][3250/4952]    eta: 0:02:15  time: 0.0791  data_time: 0.0024  memory: 681
# 11/11 19:11:42 - mmengine - INFO - Epoch(val) [4][3300/4952]    eta: 0:02:11  time: 0.0797  data_time: 0.0027  memory: 681
# 11/11 19:11:46 - mmengine - INFO - Epoch(val) [4][3350/4952]    eta: 0:02:08  time: 0.0800  data_time: 0.0025  memory: 681
# 11/11 19:11:50 - mmengine - INFO - Epoch(val) [4][3400/4952]    eta: 0:02:04  time: 0.0806  data_time: 0.0026  memory: 692
# 11/11 19:11:54 - mmengine - INFO - Epoch(val) [4][3450/4952]    eta: 0:01:59  time: 0.0783  data_time: 0.0024  memory: 681
# 11/11 19:11:58 - mmengine - INFO - Epoch(val) [4][3500/4952]    eta: 0:01:56  time: 0.0808  data_time: 0.0025  memory: 681
# 11/11 19:12:02 - mmengine - INFO - Epoch(val) [4][3550/4952]    eta: 0:01:52  time: 0.0805  data_time: 0.0027  memory: 673
# 11/11 19:12:06 - mmengine - INFO - Epoch(val) [4][3600/4952]    eta: 0:01:48  time: 0.0800  data_time: 0.0025  memory: 692
# 11/11 19:12:10 - mmengine - INFO - Epoch(val) [4][3650/4952]    eta: 0:01:44  time: 0.0796  data_time: 0.0025  memory: 692
# 11/11 19:12:14 - mmengine - INFO - Epoch(val) [4][3700/4952]    eta: 0:01:40  time: 0.0794  data_time: 0.0024  memory: 673
# 11/11 19:12:18 - mmengine - INFO - Epoch(val) [4][3750/4952]    eta: 0:01:36  time: 0.0782  data_time: 0.0024  memory: 681
# 11/11 19:12:22 - mmengine - INFO - Epoch(val) [4][3800/4952]    eta: 0:01:32  time: 0.0795  data_time: 0.0025  memory: 681
# 11/11 19:12:26 - mmengine - INFO - Epoch(val) [4][3850/4952]    eta: 0:01:28  time: 0.0791  data_time: 0.0024  memory: 681
# 11/11 19:12:29 - mmengine - INFO - Epoch(val) [4][3900/4952]    eta: 0:01:24  time: 0.0796  data_time: 0.0024  memory: 681
# 11/11 19:12:33 - mmengine - INFO - Epoch(val) [4][3950/4952]    eta: 0:01:20  time: 0.0794  data_time: 0.0027  memory: 681
# 11/11 19:12:37 - mmengine - INFO - Epoch(val) [4][4000/4952]    eta: 0:01:16  time: 0.0802  data_time: 0.0026  memory: 692
# 11/11 19:12:42 - mmengine - INFO - Epoch(val) [4][4050/4952]    eta: 0:01:12  time: 0.0810  data_time: 0.0026  memory: 685
# 11/11 19:12:45 - mmengine - INFO - Epoch(val) [4][4100/4952]    eta: 0:01:08  time: 0.0789  data_time: 0.0026  memory: 692
# 11/11 19:12:49 - mmengine - INFO - Epoch(val) [4][4150/4952]    eta: 0:01:04  time: 0.0789  data_time: 0.0025  memory: 692
# 11/11 19:12:53 - mmengine - INFO - Epoch(val) [4][4200/4952]    eta: 0:01:00  time: 0.0792  data_time: 0.0024  memory: 673
# 11/11 19:12:57 - mmengine - INFO - Epoch(val) [4][4250/4952]    eta: 0:00:56  time: 0.0795  data_time: 0.0025  memory: 692
# 11/11 19:13:01 - mmengine - INFO - Epoch(val) [4][4300/4952]    eta: 0:00:52  time: 0.0816  data_time: 0.0026  memory: 685
# 11/11 19:13:05 - mmengine - INFO - Epoch(val) [4][4350/4952]    eta: 0:00:48  time: 0.0808  data_time: 0.0024  memory: 692
# 11/11 19:13:09 - mmengine - INFO - Epoch(val) [4][4400/4952]    eta: 0:00:44  time: 0.0798  data_time: 0.0025  memory: 681
# 11/11 19:13:13 - mmengine - INFO - Epoch(val) [4][4450/4952]    eta: 0:00:40  time: 0.0790  data_time: 0.0025  memory: 681
# 11/11 19:13:17 - mmengine - INFO - Epoch(val) [4][4500/4952]    eta: 0:00:36  time: 0.0806  data_time: 0.0026  memory: 681
# 11/11 19:13:21 - mmengine - INFO - Epoch(val) [4][4550/4952]    eta: 0:00:32  time: 0.0806  data_time: 0.0024  memory: 685
# 11/11 19:13:25 - mmengine - INFO - Epoch(val) [4][4600/4952]    eta: 0:00:28  time: 0.0790  data_time: 0.0025  memory: 673
# 11/11 19:13:29 - mmengine - INFO - Epoch(val) [4][4650/4952]    eta: 0:00:24  time: 0.0799  data_time: 0.0025  memory: 681
# 11/11 19:13:33 - mmengine - INFO - Epoch(val) [4][4700/4952]    eta: 0:00:20  time: 0.0805  data_time: 0.0023  memory: 692
# 11/11 19:13:37 - mmengine - INFO - Epoch(val) [4][4750/4952]    eta: 0:00:16  time: 0.0796  data_time: 0.0025  memory: 681
# 11/11 19:13:41 - mmengine - INFO - Epoch(val) [4][4800/4952]    eta: 0:00:12  time: 0.0802  data_time: 0.0024  memory: 673
# 11/11 19:13:45 - mmengine - INFO - Epoch(val) [4][4850/4952]    eta: 0:00:08  time: 0.0802  data_time: 0.0025  memory: 685
# 11/11 19:13:49 - mmengine - INFO - Epoch(val) [4][4900/4952]    eta: 0:00:04  time: 0.0796  data_time: 0.0023  memory: 681
# 11/11 19:13:53 - mmengine - INFO - Epoch(val) [4][4950/4952]    eta: 0:00:00  time: 0.0805  data_time: 0.0024  memory: 685
# 11/11 19:13:54 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# 11/11 19:13:57 - mmengine - INFO -
# +-------------+------+-------+--------+-------+
# | class       | gts  | dets  | recall | ap    |
# +-------------+------+-------+--------+-------+
# | aeroplane   | 285  | 712   | 0.698  | 0.578 |
# | bicycle     | 337  | 3210  | 0.914  | 0.743 |
# | bird        | 459  | 2629  | 0.797  | 0.590 |
# | boat        | 263  | 2433  | 0.730  | 0.459 |
# | bottle      | 469  | 4270  | 0.601  | 0.411 |
# | bus         | 213  | 722   | 0.817  | 0.701 |
# | car         | 1201 | 2292  | 0.777  | 0.692 |
# | cat         | 358  | 1448  | 0.913  | 0.759 |
# | chair       | 756  | 3150  | 0.675  | 0.441 |
# | cow         | 244  | 1184  | 0.861  | 0.516 |
# | diningtable | 206  | 2534  | 0.879  | 0.592 |
# | dog         | 489  | 2118  | 0.904  | 0.671 |
# | horse       | 348  | 1698  | 0.914  | 0.716 |
# | motorbike   | 325  | 1928  | 0.862  | 0.694 |
# | person      | 4528 | 21393 | 0.868  | 0.731 |
# | pottedplant | 480  | 2594  | 0.677  | 0.390 |
# | sheep       | 242  | 1345  | 0.835  | 0.643 |
# | sofa        | 239  | 1304  | 0.900  | 0.633 |
# | train       | 282  | 979   | 0.883  | 0.692 |
# | tvmonitor   | 308  | 2474  | 0.828  | 0.650 |
# +-------------+------+-------+--------+-------+
# | mAP         |      |       |        | 0.615 |
# +-------------+------+-------+--------+-------+
# 11/11 19:13:57 - mmengine - INFO - Epoch(val) [4][4952/4952]    pascal_voc/mAP: 0.6150  pascal_voc/AP50: 0.6150  data_time: 0.0025  time: 0.0799
