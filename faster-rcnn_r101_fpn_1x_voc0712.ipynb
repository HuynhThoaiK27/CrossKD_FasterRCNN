# %% [markdown]
# <a href="https://www.kaggle.com/code/thoihunhvn/crosskd?scriptVersionId=276393883" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cài đặt

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113

# !pip install -U openmim

# !mim install "mmengine==0.7.3"

# !mim install "mmcv==2.0.0rc4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch==1.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (1837.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 633.9 kB/s eta 0:00:00
# Collecting torchvision==0.13.1
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.13.1%2Bcu113-cp310-cp310-linux_x86_64.whl (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 15.1 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==1.12.1) (4.12.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (2024.8.30)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# Successfully installed torch-1.12.1+cu113 torchaudio-0.12.1+cu113 torchvision-0.13.1+cu113
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /opt/conda/lib/python3.10/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /opt/conda/lib/python3.10/site-packages (from openmim) (24.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from openmim) (13.7.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (3.6)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (3.20.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (4.66.4)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 4.5 MB/s eta 0:00:00
# done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 19.0 MB/s eta 0:00:00
# done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.2 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.3-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.5/314.5 kB 19.9 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.1 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 13.5 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 28.1 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.3 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.7 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 42.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 7.0 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core
# done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=49469e6ebfaec66107c43c65e703883403676ea5b53fcbf29bb0cee9311c3c32
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
# done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535317 sha256=d2b649155d1cc9988f205d1c6a51d8a16acc60a6f89307621511c5335e847040
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
# Successfully built oss2 aliyun-python-sdk-core
# Installing collected packages: pytz, tqdm, setuptools, requests, packaging, ordered-set, jmespath, filelock, rich, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.1
#     Uninstalling filelock-3.15.1:
#       Successfully uninstalled filelock-3.15.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.0.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# boto3 1.26.100 requires botocore<1.30.0,>=1.29.100, but you have botocore 1.35.23 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# datasets 3.0.1 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.0.1 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-server 2.27.2 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.3 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmengine==0.7.3
#   Downloading mmengine-0.7.3-py3-none-any.whl.metadata (18 kB)
# Collecting addict (from mmengine==0.7.3)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (1.26.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (6.0.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (2.4.0)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (2.18.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine==0.7.3) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine==0.7.3) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine==0.7.3) (1.16.0)
# Downloading mmengine-0.7.3-py3-none-any.whl (372 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.1/372.1 kB 8.1 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict, mmengine
# Successfully installed addict-2.4.0 mmengine-0.7.3
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmcv==2.0.0rc4
#   Downloading https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/mmcv-2.0.0rc4-cp310-cp310-manylinux1_x86_64.whl (44.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (4.10.0.84)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (3.7.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv==2.0.0rc4) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0rc4

# %%
# !git clone --branch faster-rcnn https://github.com/jbwang1997/CrossKD.git
# %cd CrossKD
# Out:
# Cloning into 'CrossKD'...
# remote: Enumerating objects: 34364, done.
# remote: Counting objects: 100% (1727/1727), done.
# remote: Compressing objects: 100% (278/278), done.
# remote: Total 34364 (delta 1583), reused 1449 (delta 1449), pack-reused 32637 (from 2)
# Receiving objects: 100% (34364/34364), 32.16 MiB | 20.42 MiB/s, done.
# Resolving deltas: 100% (26898/26898), done.
# /kaggle/working/CrossKD

# %%
# !pip install -v -e .
# "-v" means verbose, or more output
# "-e" means installing a project in editable mode,
# thus any local modifications made to the code will take effect without reinstallation.

# !pip install yapf==0.32.0
# Out:
# Using pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/CrossKD
#   Running command python setup.py egg_info
#   /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#   ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#   Your build configuration is incomplete and previously worked by accident!
#   setuptools_scm requires setuptools>=61
#
#   Suggested workaround if applicable:
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-0z2eatbp/mmdet.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-0z2eatbp/mmdet.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmdet/VERSION'
#   warning: no files found matching 'mmdet/.mim/model-index.yml'
#   warning: no files found matching 'mmdet/.mim/demo/*/*'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
#   writing manifest file '/tmp/pip-pip-egg-info-0z2eatbp/mmdet.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.26.4)
# Collecting pycocotools (from mmdet==3.0.0rc6)
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/61/d7/32996d713921c504875a4cebf241c182aa37e58daab5c3c4737f539ac0d4/pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.14.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.16.0)
# Collecting terminaltables (from mmdet==3.0.0rc6)
#   Obtaining dependency information for terminaltables from https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl.metadata
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (2.9.0.post0)
# Downloading pycocotools-2.0.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.0/455.0 kB 885.5 kB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, pycocotools, mmdet
#   Running setup.py develop for mmdet
#     Running command python setup.py develop
#     /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#     ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#     Your build configuration is incomplete and previously worked by accident!
#     setuptools_scm requires setuptools>=61
#
#     Suggested workaround if applicable:
#      - migrating from the deprecated setup_requires mechanism to pep517/518
#        and using a pyproject.toml to declare build dependencies
#        which are reliably pre-installed before running the build tools
#
#       warnings.warn(
#     running develop
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     creating mmdet.egg-info
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     warning: no files found matching 'mmdet/VERSION'
#     warning: no files found matching 'mmdet/.mim/demo/*/*'
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     running build_ext
# Successfully installed mmdet-3.0.0rc6 pycocotools-2.0.10 terminaltables-3.1.10
# Collecting yapf==0.32.0
#   Downloading yapf-0.32.0-py2.py3-none-any.whl.metadata (34 kB)
# Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: yapf
#   Attempting uninstall: yapf
#     Found existing installation: yapf 0.40.2
#     Uninstalling yapf-0.40.2:
#       Successfully uninstalled yapf-0.40.2
# Successfully installed yapf-0.32.0

# %% [markdown]
# # Thực hiện các bước di chuyển và cài đặt cấu hình

# %%
# !ls configs/
# Out:
# _base_		  dino		       legacy_1.x	    rpn
# albu_example	  double_heads	       libra_rcnn	    rtmdet
# atss		  dyhead	       lvis		    sabl
# autoassign	  dynamic_rcnn	       mask2former	    scnet
# boxinst		  efficientnet	       mask_rcnn	    scratch
# carafe		  empirical_attention  maskformer	    seesaw_loss
# cascade_rcnn	  fast_rcnn	       misc		    selfsup_pretrain
# cascade_rpn	  faster_rcnn	       ms_rcnn		    simple_copy_paste
# centernet	  fcos		       nas_fcos		    soft_teacher
# centripetalnet	  foveabox	       nas_fpn		    solo
# cityscapes	  fpg		       objects365	    solov2
# common		  free_anchor	       openimages	    sparse_rcnn
# condinst	  fsaf		       paa		    ssd
# conditional_detr  gcnet		       pafpn		    strong_baselines
# convnext	  gfl		       panoptic_fpn	    swin
# cornernet	  ghm		       pascal_voc	    timm_example
# crosskd		  gn		       pisa		    tood
# crowddet	  gn+ws		       point_rend	    tridentnet
# dab_detr	  grid_rcnn	       pvt		    vfnet
# dcn		  groie		       queryinst	    wider_face
# dcnv2		  guided_anchoring     regnet		    yolact
# ddod		  hrnet		       reppoints	    yolo
# deepfashion	  htc		       res2net		    yolof
# deformable_detr   instaboost	       resnest		    yolox
# detectors	  lad		       resnet_strikes_back
# detr		  ld		       retinanet

# %%
# !cp /kaggle/input/voc-fasterrcnn/voc0712_faster_rcnn.py configs/_base_/datasets/voc0712.py

# %%
# !cp /kaggle/input/faster-rcnn-voc/faster-rcnn_r50_fpn_1x_voc0712.py configs/faster_rcnn/

# %%
# !cp /kaggle/input/schedule-1/schedule_1x.py configs/_base_/schedules/schedule_1x.py

# %%
# !cp /kaggle/input/base-configfasterrcnn/faster-rcnn_r50_fpn.py configs/_base_/models/faster-rcnn_r50_fpn.py

# %%
# !ls configs/faster_rcnn/
# Out:
# README.md
# faster-rcnn_r101-caffe_fpn_1x_coco.py
# faster-rcnn_r101-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r101_fpn_1x_coco.py
# faster-rcnn_r101_fpn_2x_coco.py
# faster-rcnn_r101_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r101_fpn_ms-3x_coco.py
# faster-rcnn_r18_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50-caffe-c4_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-3x_coco.py
# faster-rcnn_r50-caffe_c4-1x_coco.py
# faster-rcnn_r50-caffe_fpn_1x_coco.py
# faster-rcnn_r50-caffe_fpn_90k_coco.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person-bicycle-car.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-2x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-90k_coco.py
# faster-rcnn_r50-tnr-pre_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_voc0712.py
# faster-rcnn_r50_fpn_2x_coco.py
# faster-rcnn_r50_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50_fpn_amp-1x_coco.py
# faster-rcnn_r50_fpn_bounded-iou_1x_coco.py
# faster-rcnn_r50_fpn_ciou_1x_coco.py
# faster-rcnn_r50_fpn_fcos-rpn_1x_coco.py
# faster-rcnn_r50_fpn_giou_1x_coco.py
# faster-rcnn_r50_fpn_iou_1x_coco.py
# faster-rcnn_r50_fpn_ms-3x_coco.py
# faster-rcnn_r50_fpn_ohem_1x_coco.py
# faster-rcnn_r50_fpn_soft-nms_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_2x_coco.py
# faster-rcnn_x101-32x4d_fpn_ms-3x_coco.py
# faster-rcnn_x101-32x8d_fpn_ms-3x_coco.py
# faster-rcnn_x101-64x4d_fpn_1x_coco.py
# faster-rcnn_x101-64x4d_fpn_2x_coco.py
# faster-rcnn_x101-64x4d_fpn_ms-3x_coco.py
# metafile.yml

# %%
# !cat configs/faster_rcnn/faster-rcnn_r50_fpn_1x_voc0712.py
# Out:
# _base_ = [
#     '../_base_/models/faster-rcnn_r50_fpn.py',
#     '../_base_/datasets/voc0712.py',
#     '../_base_/schedules/schedule_1x.py', '../_base_/default_runtime.py'
# ]

# %%
# !cat configs/_base_/schedules/schedule_1x.py
# Out:
# # training schedule for 1x
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
#
# # learning rate
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
#
# # optimizer
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     clip_grad=dict(max_norm=35, norm_type=2))
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
# !cat configs/_base_/models/faster-rcnn_r50_fpn.py
# Out:
# # model settings
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[.0, .0, .0, .0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0., 0., 0., 0.],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     # model training and testing settings
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)
#         # soft-nms is also supported for rcnn testing
#         # e.g., nms=dict(type='soft_nms', iou_threshold=0.5, min_score=0.05)
#     ))

# %%
# !python tools/train.py configs/faster_rcnn/faster-rcnn_r50_fpn_1x_voc0712.py --work-dir /kaggle/working/w
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/12 03:42:10 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 170734469
#     GPU 0,1: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu113
#     OpenCV: 4.10.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/12 03:42:11 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'VOCDataset'
# data_root = '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit'
# file_client_args = dict(backend='disk')
# train_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='RepeatDataset',
#         times=3,
#         dataset=dict(
#             type='ConcatDataset',
#             ignore_keys=['dataset_type'],
#             datasets=[
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2007/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2007/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ]),
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2012/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2012/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ])
#             ])))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# val_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# test_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     clip_grad=dict(max_norm=35, norm_type=2))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# launcher = 'none'
# work_dir = '/kaggle/working/w'
#
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 11/12 03:42:18 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/12 03:42:18 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 11/12 03:42:18 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/12 03:42:18 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/12 03:43:21 - mmengine - INFO - load model from: torchvision://resnet50
# 11/12 03:43:21 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 253MB/s]
# 11/12 03:43:21 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 11/12 03:43:21 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/w.
# 11/12 03:43:58 - mmengine - INFO - Epoch(train) [1][  50/6164]  lr: 1.9820e-03  eta: 5:02:34  time: 0.7378  data_time: 0.0137  memory: 4333  grad_norm: 6.6323  loss: 1.1673  loss_rpn_cls: 0.3434  loss_rpn_bbox: 0.0197  loss_cls: 0.7381  acc: 96.6797  loss_bbox: 0.0662
# 11/12 03:44:34 - mmengine - INFO - Epoch(train) [1][ 100/6164]  lr: 3.9840e-03  eta: 4:59:07  time: 0.7239  data_time: 0.0093  memory: 4333  grad_norm: 1.7034  loss: 0.5329  loss_rpn_cls: 0.0609  loss_rpn_bbox: 0.0192  loss_cls: 0.2772  acc: 94.8242  loss_bbox: 0.1756
# 11/12 03:45:12 - mmengine - INFO - Epoch(train) [1][ 150/6164]  lr: 5.9860e-03  eta: 5:02:34  time: 0.7607  data_time: 0.0093  memory: 4333  grad_norm: 1.5182  loss: 0.4739  loss_rpn_cls: 0.0438  loss_rpn_bbox: 0.0172  loss_cls: 0.2415  acc: 97.0215  loss_bbox: 0.1713
# 11/12 03:45:52 - mmengine - INFO - Epoch(train) [1][ 200/6164]  lr: 7.9880e-03  eta: 5:07:34  time: 0.7959  data_time: 0.0097  memory: 4333  grad_norm: 1.6411  loss: 0.4530  loss_rpn_cls: 0.0394  loss_rpn_bbox: 0.0171  loss_cls: 0.2279  acc: 94.7266  loss_bbox: 0.1686
# 11/12 03:46:30 - mmengine - INFO - Epoch(train) [1][ 250/6164]  lr: 9.9900e-03  eta: 5:07:06  time: 0.7566  data_time: 0.0098  memory: 4333  grad_norm: 2.0307  loss: 0.5141  loss_rpn_cls: 0.0467  loss_rpn_bbox: 0.0194  loss_cls: 0.2636  acc: 95.5078  loss_bbox: 0.1843
# 11/12 03:47:09 - mmengine - INFO - Epoch(train) [1][ 300/6164]  lr: 1.1992e-02  eta: 5:08:33  time: 0.7858  data_time: 0.0095  memory: 4333  grad_norm: 1.9259  loss: 0.4691  loss_rpn_cls: 0.0344  loss_rpn_bbox: 0.0154  loss_cls: 0.2430  acc: 97.3145  loss_bbox: 0.1763
# 11/12 03:47:47 - mmengine - INFO - Epoch(train) [1][ 350/6164]  lr: 1.3994e-02  eta: 5:07:54  time: 0.7598  data_time: 0.0100  memory: 4333  grad_norm: 1.6587  loss: 0.4888  loss_rpn_cls: 0.0327  loss_rpn_bbox: 0.0180  loss_cls: 0.2453  acc: 94.3848  loss_bbox: 0.1929
# 11/12 03:48:26 - mmengine - INFO - Epoch(train) [1][ 400/6164]  lr: 1.5996e-02  eta: 5:07:51  time: 0.7715  data_time: 0.0095  memory: 4333  grad_norm: 1.9774  loss: 0.5207  loss_rpn_cls: 0.0384  loss_rpn_bbox: 0.0204  loss_cls: 0.2698  acc: 98.1934  loss_bbox: 0.1920
# 11/12 03:49:04 - mmengine - INFO - Epoch(train) [1][ 450/6164]  lr: 1.7998e-02  eta: 5:07:28  time: 0.7671  data_time: 0.0086  memory: 4333  grad_norm: 1.8111  loss: 0.5074  loss_rpn_cls: 0.0349  loss_rpn_bbox: 0.0183  loss_cls: 0.2639  acc: 97.3145  loss_bbox: 0.1902
# 11/12 03:49:42 - mmengine - INFO - Epoch(train) [1][ 500/6164]  lr: 2.0000e-02  eta: 5:06:47  time: 0.7611  data_time: 0.0086  memory: 4333  grad_norm: 2.0797  loss: 0.5505  loss_rpn_cls: 0.0367  loss_rpn_bbox: 0.0230  loss_cls: 0.2804  acc: 92.7734  loss_bbox: 0.2104
# 11/12 03:50:21 - mmengine - INFO - Epoch(train) [1][ 550/6164]  lr: 2.0000e-02  eta: 5:06:48  time: 0.7799  data_time: 0.0086  memory: 4333  grad_norm: 2.0171  loss: 0.5086  loss_rpn_cls: 0.0393  loss_rpn_bbox: 0.0210  loss_cls: 0.2622  acc: 94.3848  loss_bbox: 0.1861
# 11/12 03:50:59 - mmengine - INFO - Epoch(train) [1][ 600/6164]  lr: 2.0000e-02  eta: 5:06:11  time: 0.7640  data_time: 0.0085  memory: 4333  grad_norm: 1.4750  loss: 0.4602  loss_rpn_cls: 0.0303  loss_rpn_bbox: 0.0181  loss_cls: 0.2406  acc: 90.0391  loss_bbox: 0.1713
# 11/12 03:51:38 - mmengine - INFO - Epoch(train) [1][ 650/6164]  lr: 2.0000e-02  eta: 5:05:41  time: 0.7681  data_time: 0.0096  memory: 4333  grad_norm: 1.6947  loss: 0.4736  loss_rpn_cls: 0.0329  loss_rpn_bbox: 0.0173  loss_cls: 0.2383  acc: 97.9980  loss_bbox: 0.1852
# 11/12 03:52:16 - mmengine - INFO - Epoch(train) [1][ 700/6164]  lr: 2.0000e-02  eta: 5:05:10  time: 0.7682  data_time: 0.0094  memory: 4333  grad_norm: 1.5643  loss: 0.4775  loss_rpn_cls: 0.0290  loss_rpn_bbox: 0.0168  loss_cls: 0.2490  acc: 96.2891  loss_bbox: 0.1827
# 11/12 03:52:55 - mmengine - INFO - Epoch(train) [1][ 750/6164]  lr: 2.0000e-02  eta: 5:04:43  time: 0.7719  data_time: 0.0093  memory: 4333  grad_norm: 1.9240  loss: 0.5632  loss_rpn_cls: 0.0426  loss_rpn_bbox: 0.0222  loss_cls: 0.2799  acc: 96.3867  loss_bbox: 0.2185
# 11/12 03:53:34 - mmengine - INFO - Epoch(train) [1][ 800/6164]  lr: 2.0000e-02  eta: 5:04:23  time: 0.7766  data_time: 0.0094  memory: 4333  grad_norm: 1.8209  loss: 0.4747  loss_rpn_cls: 0.0308  loss_rpn_bbox: 0.0174  loss_cls: 0.2430  acc: 94.6289  loss_bbox: 0.1834
# 11/12 03:54:12 - mmengine - INFO - Epoch(train) [1][ 850/6164]  lr: 2.0000e-02  eta: 5:03:51  time: 0.7704  data_time: 0.0096  memory: 4333  grad_norm: 1.5619  loss: 0.4456  loss_rpn_cls: 0.0284  loss_rpn_bbox: 0.0173  loss_cls: 0.2291  acc: 96.5332  loss_bbox: 0.1708
# 11/12 03:54:51 - mmengine - INFO - Epoch(train) [1][ 900/6164]  lr: 2.0000e-02  eta: 5:03:22  time: 0.7727  data_time: 0.0092  memory: 4333  grad_norm: 1.5645  loss: 0.4684  loss_rpn_cls: 0.0270  loss_rpn_bbox: 0.0180  loss_cls: 0.2328  acc: 95.0195  loss_bbox: 0.1905
# 11/12 03:55:29 - mmengine - INFO - Epoch(train) [1][ 950/6164]  lr: 2.0000e-02  eta: 5:02:45  time: 0.7671  data_time: 0.0095  memory: 4333  grad_norm: 1.6301  loss: 0.4811  loss_rpn_cls: 0.0249  loss_rpn_bbox: 0.0171  loss_cls: 0.2412  acc: 94.8242  loss_bbox: 0.1978
# 11/12 03:56:08 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 03:56:08 - mmengine - INFO - Epoch(train) [1][1000/6164]  lr: 2.0000e-02  eta: 5:02:15  time: 0.7730  data_time: 0.0097  memory: 4333  grad_norm: 1.5756  loss: 0.4651  loss_rpn_cls: 0.0250  loss_rpn_bbox: 0.0178  loss_cls: 0.2293  acc: 94.3359  loss_bbox: 0.1930
# 11/12 03:56:46 - mmengine - INFO - Epoch(train) [1][1050/6164]  lr: 2.0000e-02  eta: 5:01:38  time: 0.7680  data_time: 0.0097  memory: 4333  grad_norm: 1.6085  loss: 0.4172  loss_rpn_cls: 0.0267  loss_rpn_bbox: 0.0168  loss_cls: 0.2049  acc: 95.7031  loss_bbox: 0.1688
# 11/12 03:57:24 - mmengine - INFO - Epoch(train) [1][1100/6164]  lr: 2.0000e-02  eta: 5:00:52  time: 0.7601  data_time: 0.0092  memory: 4333  grad_norm: 1.5453  loss: 0.4381  loss_rpn_cls: 0.0299  loss_rpn_bbox: 0.0168  loss_cls: 0.2239  acc: 94.4824  loss_bbox: 0.1676
# 11/12 03:58:03 - mmengine - INFO - Epoch(train) [1][1150/6164]  lr: 2.0000e-02  eta: 5:00:24  time: 0.7762  data_time: 0.0094  memory: 4333  grad_norm: 1.6221  loss: 0.4539  loss_rpn_cls: 0.0279  loss_rpn_bbox: 0.0184  loss_cls: 0.2226  acc: 86.2305  loss_bbox: 0.1851
# 11/12 03:58:41 - mmengine - INFO - Epoch(train) [1][1200/6164]  lr: 2.0000e-02  eta: 4:59:42  time: 0.7631  data_time: 0.0088  memory: 4333  grad_norm: 1.6890  loss: 0.4805  loss_rpn_cls: 0.0266  loss_rpn_bbox: 0.0174  loss_cls: 0.2425  acc: 97.2656  loss_bbox: 0.1940
# 11/12 03:59:20 - mmengine - INFO - Epoch(train) [1][1250/6164]  lr: 2.0000e-02  eta: 4:59:15  time: 0.7785  data_time: 0.0094  memory: 4333  grad_norm: 1.7006  loss: 0.4747  loss_rpn_cls: 0.0322  loss_rpn_bbox: 0.0212  loss_cls: 0.2356  acc: 93.8477  loss_bbox: 0.1857
# 11/12 03:59:59 - mmengine - INFO - Epoch(train) [1][1300/6164]  lr: 2.0000e-02  eta: 4:58:39  time: 0.7695  data_time: 0.0091  memory: 4333  grad_norm: 1.5507  loss: 0.4644  loss_rpn_cls: 0.0285  loss_rpn_bbox: 0.0189  loss_cls: 0.2213  acc: 96.2402  loss_bbox: 0.1956
# 11/12 04:00:38 - mmengine - INFO - Epoch(train) [1][1350/6164]  lr: 2.0000e-02  eta: 4:58:14  time: 0.7836  data_time: 0.0085  memory: 4333  grad_norm: 1.7035  loss: 0.4635  loss_rpn_cls: 0.0276  loss_rpn_bbox: 0.0175  loss_cls: 0.2310  acc: 96.8750  loss_bbox: 0.1874
# 11/12 04:01:16 - mmengine - INFO - Epoch(train) [1][1400/6164]  lr: 2.0000e-02  eta: 4:57:35  time: 0.7661  data_time: 0.0089  memory: 4333  grad_norm: 1.4637  loss: 0.4386  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0180  loss_cls: 0.2208  acc: 97.9004  loss_bbox: 0.1792
# 11/12 04:01:55 - mmengine - INFO - Epoch(train) [1][1450/6164]  lr: 2.0000e-02  eta: 4:57:03  time: 0.7762  data_time: 0.0150  memory: 4333  grad_norm: 1.5460  loss: 0.4384  loss_rpn_cls: 0.0235  loss_rpn_bbox: 0.0172  loss_cls: 0.2161  acc: 96.5332  loss_bbox: 0.1816
# 11/12 04:02:34 - mmengine - INFO - Epoch(train) [1][1500/6164]  lr: 2.0000e-02  eta: 4:56:27  time: 0.7709  data_time: 0.0092  memory: 4333  grad_norm: 1.6088  loss: 0.4558  loss_rpn_cls: 0.0232  loss_rpn_bbox: 0.0202  loss_cls: 0.2213  acc: 93.1641  loss_bbox: 0.1910
# 11/12 04:03:12 - mmengine - INFO - Epoch(train) [1][1550/6164]  lr: 2.0000e-02  eta: 4:55:43  time: 0.7616  data_time: 0.0095  memory: 4333  grad_norm: 1.7379  loss: 0.4592  loss_rpn_cls: 0.0256  loss_rpn_bbox: 0.0171  loss_cls: 0.2292  acc: 87.3535  loss_bbox: 0.1873
# 11/12 04:03:51 - mmengine - INFO - Epoch(train) [1][1600/6164]  lr: 2.0000e-02  eta: 4:55:16  time: 0.7828  data_time: 0.0089  memory: 4333  grad_norm: 1.6926  loss: 0.4229  loss_rpn_cls: 0.0208  loss_rpn_bbox: 0.0153  loss_cls: 0.2103  acc: 96.4844  loss_bbox: 0.1765
# 11/12 04:04:29 - mmengine - INFO - Epoch(train) [1][1650/6164]  lr: 2.0000e-02  eta: 4:54:40  time: 0.7721  data_time: 0.0090  memory: 4333  grad_norm: 1.7053  loss: 0.5022  loss_rpn_cls: 0.0235  loss_rpn_bbox: 0.0207  loss_cls: 0.2389  acc: 93.1152  loss_bbox: 0.2191
# 11/12 04:05:08 - mmengine - INFO - Epoch(train) [1][1700/6164]  lr: 2.0000e-02  eta: 4:54:06  time: 0.7752  data_time: 0.0088  memory: 4333  grad_norm: 1.7083  loss: 0.4453  loss_rpn_cls: 0.0222  loss_rpn_bbox: 0.0174  loss_cls: 0.2090  acc: 93.8965  loss_bbox: 0.1967
# 11/12 04:05:47 - mmengine - INFO - Epoch(train) [1][1750/6164]  lr: 2.0000e-02  eta: 4:53:28  time: 0.7701  data_time: 0.0092  memory: 4333  grad_norm: 1.5276  loss: 0.3898  loss_rpn_cls: 0.0187  loss_rpn_bbox: 0.0148  loss_cls: 0.1932  acc: 96.0938  loss_bbox: 0.1631
# 11/12 04:06:25 - mmengine - INFO - Epoch(train) [1][1800/6164]  lr: 2.0000e-02  eta: 4:52:53  time: 0.7740  data_time: 0.0096  memory: 4333  grad_norm: 1.6745  loss: 0.4147  loss_rpn_cls: 0.0224  loss_rpn_bbox: 0.0174  loss_cls: 0.1989  acc: 96.6309  loss_bbox: 0.1760
# 11/12 04:07:04 - mmengine - INFO - Epoch(train) [1][1850/6164]  lr: 2.0000e-02  eta: 4:52:13  time: 0.7660  data_time: 0.0087  memory: 4333  grad_norm: 1.3890  loss: 0.3847  loss_rpn_cls: 0.0213  loss_rpn_bbox: 0.0157  loss_cls: 0.1883  acc: 96.3867  loss_bbox: 0.1595
# 11/12 04:07:42 - mmengine - INFO - Epoch(train) [1][1900/6164]  lr: 2.0000e-02  eta: 4:51:34  time: 0.7683  data_time: 0.0091  memory: 4333  grad_norm: 1.6149  loss: 0.3883  loss_rpn_cls: 0.0194  loss_rpn_bbox: 0.0146  loss_cls: 0.1877  acc: 98.3398  loss_bbox: 0.1667
# 11/12 04:08:21 - mmengine - INFO - Epoch(train) [1][1950/6164]  lr: 2.0000e-02  eta: 4:51:03  time: 0.7816  data_time: 0.0090  memory: 4333  grad_norm: 1.6954  loss: 0.4134  loss_rpn_cls: 0.0200  loss_rpn_bbox: 0.0157  loss_cls: 0.1942  acc: 90.4785  loss_bbox: 0.1835
# 11/12 04:08:59 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 04:08:59 - mmengine - INFO - Epoch(train) [1][2000/6164]  lr: 2.0000e-02  eta: 4:50:22  time: 0.7641  data_time: 0.0085  memory: 4333  grad_norm: 1.6326  loss: 0.3995  loss_rpn_cls: 0.0263  loss_rpn_bbox: 0.0172  loss_cls: 0.1890  acc: 97.9492  loss_bbox: 0.1670
# 11/12 04:09:38 - mmengine - INFO - Epoch(train) [1][2050/6164]  lr: 2.0000e-02  eta: 4:49:46  time: 0.7727  data_time: 0.0093  memory: 4333  grad_norm: 1.5359  loss: 0.3937  loss_rpn_cls: 0.0180  loss_rpn_bbox: 0.0162  loss_cls: 0.1881  acc: 96.8750  loss_bbox: 0.1715
# 11/12 04:10:16 - mmengine - INFO - Epoch(train) [1][2100/6164]  lr: 2.0000e-02  eta: 4:49:00  time: 0.7560  data_time: 0.0092  memory: 4333  grad_norm: 1.5917  loss: 0.4002  loss_rpn_cls: 0.0187  loss_rpn_bbox: 0.0167  loss_cls: 0.1876  acc: 93.4570  loss_bbox: 0.1773
# 11/12 04:10:53 - mmengine - INFO - Epoch(train) [1][2150/6164]  lr: 2.0000e-02  eta: 4:48:14  time: 0.7536  data_time: 0.0093  memory: 4333  grad_norm: 1.5720  loss: 0.3833  loss_rpn_cls: 0.0235  loss_rpn_bbox: 0.0168  loss_cls: 0.1771  acc: 94.0430  loss_bbox: 0.1659
# 11/12 04:11:32 - mmengine - INFO - Epoch(train) [1][2200/6164]  lr: 2.0000e-02  eta: 4:47:35  time: 0.7678  data_time: 0.0087  memory: 4333  grad_norm: 1.6508  loss: 0.4049  loss_rpn_cls: 0.0198  loss_rpn_bbox: 0.0166  loss_cls: 0.1922  acc: 92.6758  loss_bbox: 0.1763
# 11/12 04:12:10 - mmengine - INFO - Epoch(train) [1][2250/6164]  lr: 2.0000e-02  eta: 4:46:58  time: 0.7716  data_time: 0.0091  memory: 4333  grad_norm: 1.8495  loss: 0.4326  loss_rpn_cls: 0.0274  loss_rpn_bbox: 0.0174  loss_cls: 0.2086  acc: 95.8984  loss_bbox: 0.1791
# 11/12 04:12:50 - mmengine - INFO - Epoch(train) [1][2300/6164]  lr: 2.0000e-02  eta: 4:46:27  time: 0.7833  data_time: 0.0092  memory: 4333  grad_norm: 1.6324  loss: 0.4284  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0181  loss_cls: 0.2009  acc: 96.7285  loss_bbox: 0.1888
# 11/12 04:13:28 - mmengine - INFO - Epoch(train) [1][2350/6164]  lr: 2.0000e-02  eta: 4:45:50  time: 0.7718  data_time: 0.0097  memory: 4333  grad_norm: 1.6698  loss: 0.3940  loss_rpn_cls: 0.0179  loss_rpn_bbox: 0.0142  loss_cls: 0.1883  acc: 97.0703  loss_bbox: 0.1736
# 11/12 04:14:07 - mmengine - INFO - Epoch(train) [1][2400/6164]  lr: 2.0000e-02  eta: 4:45:15  time: 0.7771  data_time: 0.0093  memory: 4333  grad_norm: 1.5669  loss: 0.3892  loss_rpn_cls: 0.0230  loss_rpn_bbox: 0.0158  loss_cls: 0.1807  acc: 93.5547  loss_bbox: 0.1696
# 11/12 04:14:45 - mmengine - INFO - Epoch(train) [1][2450/6164]  lr: 2.0000e-02  eta: 4:44:36  time: 0.7674  data_time: 0.0092  memory: 4333  grad_norm: 1.5875  loss: 0.4042  loss_rpn_cls: 0.0211  loss_rpn_bbox: 0.0167  loss_cls: 0.1941  acc: 91.1621  loss_bbox: 0.1723
# 11/12 04:15:24 - mmengine - INFO - Epoch(train) [1][2500/6164]  lr: 2.0000e-02  eta: 4:43:58  time: 0.7705  data_time: 0.0095  memory: 4333  grad_norm: 1.7172  loss: 0.4381  loss_rpn_cls: 0.0228  loss_rpn_bbox: 0.0190  loss_cls: 0.2047  acc: 94.5801  loss_bbox: 0.1916
# 11/12 04:16:03 - mmengine - INFO - Epoch(train) [1][2550/6164]  lr: 2.0000e-02  eta: 4:43:24  time: 0.7780  data_time: 0.0096  memory: 4333  grad_norm: 1.6669  loss: 0.4442  loss_rpn_cls: 0.0207  loss_rpn_bbox: 0.0187  loss_cls: 0.2093  acc: 96.1426  loss_bbox: 0.1955
# 11/12 04:16:41 - mmengine - INFO - Epoch(train) [1][2600/6164]  lr: 2.0000e-02  eta: 4:42:46  time: 0.7708  data_time: 0.0092  memory: 4333  grad_norm: 1.4783  loss: 0.3736  loss_rpn_cls: 0.0210  loss_rpn_bbox: 0.0147  loss_cls: 0.1774  acc: 95.7520  loss_bbox: 0.1605
# 11/12 04:17:20 - mmengine - INFO - Epoch(train) [1][2650/6164]  lr: 2.0000e-02  eta: 4:42:08  time: 0.7700  data_time: 0.0092  memory: 4333  grad_norm: 1.5567  loss: 0.3666  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0144  loss_cls: 0.1721  acc: 97.9980  loss_bbox: 0.1617
# 11/12 04:17:59 - mmengine - INFO - Epoch(train) [1][2700/6164]  lr: 2.0000e-02  eta: 4:41:31  time: 0.7738  data_time: 0.0100  memory: 4333  grad_norm: 1.6748  loss: 0.4148  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0197  loss_cls: 0.1902  acc: 96.5332  loss_bbox: 0.1843
# 11/12 04:18:37 - mmengine - INFO - Epoch(train) [1][2750/6164]  lr: 2.0000e-02  eta: 4:40:51  time: 0.7649  data_time: 0.0098  memory: 4333  grad_norm: 1.6742  loss: 0.4364  loss_rpn_cls: 0.0249  loss_rpn_bbox: 0.0220  loss_cls: 0.2039  acc: 91.2598  loss_bbox: 0.1856
# 11/12 04:19:15 - mmengine - INFO - Epoch(train) [1][2800/6164]  lr: 2.0000e-02  eta: 4:40:14  time: 0.7739  data_time: 0.0102  memory: 4333  grad_norm: 1.5558  loss: 0.3841  loss_rpn_cls: 0.0183  loss_rpn_bbox: 0.0153  loss_cls: 0.1787  acc: 94.6777  loss_bbox: 0.1717
# 11/12 04:19:54 - mmengine - INFO - Epoch(train) [1][2850/6164]  lr: 2.0000e-02  eta: 4:39:37  time: 0.7712  data_time: 0.0096  memory: 4333  grad_norm: 1.4198  loss: 0.3651  loss_rpn_cls: 0.0218  loss_rpn_bbox: 0.0171  loss_cls: 0.1671  acc: 93.7500  loss_bbox: 0.1591
# 11/12 04:20:33 - mmengine - INFO - Epoch(train) [1][2900/6164]  lr: 2.0000e-02  eta: 4:39:03  time: 0.7823  data_time: 0.0097  memory: 4333  grad_norm: 1.5546  loss: 0.3505  loss_rpn_cls: 0.0216  loss_rpn_bbox: 0.0165  loss_cls: 0.1691  acc: 95.9473  loss_bbox: 0.1433
# 11/12 04:21:11 - mmengine - INFO - Epoch(train) [1][2950/6164]  lr: 2.0000e-02  eta: 4:38:23  time: 0.7655  data_time: 0.0096  memory: 4333  grad_norm: 1.6835  loss: 0.4013  loss_rpn_cls: 0.0211  loss_rpn_bbox: 0.0165  loss_cls: 0.1910  acc: 92.7246  loss_bbox: 0.1726
# 11/12 04:21:50 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 04:21:50 - mmengine - INFO - Epoch(train) [1][3000/6164]  lr: 2.0000e-02  eta: 4:37:44  time: 0.7681  data_time: 0.0089  memory: 4333  grad_norm: 1.5285  loss: 0.3671  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0159  loss_cls: 0.1722  acc: 90.8203  loss_bbox: 0.1606
# 11/12 04:22:29 - mmengine - INFO - Epoch(train) [1][3050/6164]  lr: 2.0000e-02  eta: 4:37:07  time: 0.7750  data_time: 0.0093  memory: 4333  grad_norm: 1.6369  loss: 0.3757  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0151  loss_cls: 0.1830  acc: 89.7461  loss_bbox: 0.1595
# 11/12 04:23:08 - mmengine - INFO - Epoch(train) [1][3100/6164]  lr: 2.0000e-02  eta: 4:36:33  time: 0.7809  data_time: 0.0092  memory: 4333  grad_norm: 1.5155  loss: 0.4145  loss_rpn_cls: 0.0208  loss_rpn_bbox: 0.0188  loss_cls: 0.1878  acc: 93.7012  loss_bbox: 0.1871
# 11/12 04:23:46 - mmengine - INFO - Epoch(train) [1][3150/6164]  lr: 2.0000e-02  eta: 4:35:56  time: 0.7731  data_time: 0.0099  memory: 4333  grad_norm: 1.8499  loss: 0.4087  loss_rpn_cls: 0.0274  loss_rpn_bbox: 0.0157  loss_cls: 0.1882  acc: 95.3125  loss_bbox: 0.1775
# 11/12 04:24:25 - mmengine - INFO - Epoch(train) [1][3200/6164]  lr: 2.0000e-02  eta: 4:35:18  time: 0.7722  data_time: 0.0091  memory: 4333  grad_norm: 1.4710  loss: 0.3825  loss_rpn_cls: 0.0193  loss_rpn_bbox: 0.0161  loss_cls: 0.1796  acc: 99.3164  loss_bbox: 0.1675
# 11/12 04:25:04 - mmengine - INFO - Epoch(train) [1][3250/6164]  lr: 2.0000e-02  eta: 4:34:41  time: 0.7753  data_time: 0.0095  memory: 4333  grad_norm: 1.6120  loss: 0.3974  loss_rpn_cls: 0.0208  loss_rpn_bbox: 0.0189  loss_cls: 0.1815  acc: 95.5078  loss_bbox: 0.1762
# 11/12 04:25:43 - mmengine - INFO - Epoch(train) [1][3300/6164]  lr: 2.0000e-02  eta: 4:34:06  time: 0.7794  data_time: 0.0091  memory: 4333  grad_norm: 1.4532  loss: 0.3597  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0160  loss_cls: 0.1657  acc: 88.7207  loss_bbox: 0.1596
# 11/12 04:26:21 - mmengine - INFO - Epoch(train) [1][3350/6164]  lr: 2.0000e-02  eta: 4:33:28  time: 0.7721  data_time: 0.0095  memory: 4333  grad_norm: 1.5785  loss: 0.3875  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0156  loss_cls: 0.1863  acc: 94.2383  loss_bbox: 0.1681
# 11/12 04:27:00 - mmengine - INFO - Epoch(train) [1][3400/6164]  lr: 2.0000e-02  eta: 4:32:49  time: 0.7698  data_time: 0.0096  memory: 4333  grad_norm: 1.6809  loss: 0.3935  loss_rpn_cls: 0.0221  loss_rpn_bbox: 0.0171  loss_cls: 0.1854  acc: 94.0918  loss_bbox: 0.1689
# 11/12 04:27:38 - mmengine - INFO - Epoch(train) [1][3450/6164]  lr: 2.0000e-02  eta: 4:32:12  time: 0.7743  data_time: 0.0096  memory: 4333  grad_norm: 1.5607  loss: 0.3952  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0157  loss_cls: 0.1892  acc: 91.8457  loss_bbox: 0.1729
# 11/12 04:28:17 - mmengine - INFO - Epoch(train) [1][3500/6164]  lr: 2.0000e-02  eta: 4:31:35  time: 0.7745  data_time: 0.0094  memory: 4333  grad_norm: 1.5447  loss: 0.3723  loss_rpn_cls: 0.0183  loss_rpn_bbox: 0.0156  loss_cls: 0.1745  acc: 95.5078  loss_bbox: 0.1640
# 11/12 04:28:56 - mmengine - INFO - Epoch(train) [1][3550/6164]  lr: 2.0000e-02  eta: 4:30:55  time: 0.7676  data_time: 0.0092  memory: 4333  grad_norm: 1.5925  loss: 0.3727  loss_rpn_cls: 0.0180  loss_rpn_bbox: 0.0149  loss_cls: 0.1724  acc: 96.1914  loss_bbox: 0.1675
# 11/12 04:29:34 - mmengine - INFO - Epoch(train) [1][3600/6164]  lr: 2.0000e-02  eta: 4:30:18  time: 0.7741  data_time: 0.0098  memory: 4333  grad_norm: 1.4826  loss: 0.3611  loss_rpn_cls: 0.0183  loss_rpn_bbox: 0.0160  loss_cls: 0.1646  acc: 96.3379  loss_bbox: 0.1621
# 11/12 04:30:13 - mmengine - INFO - Epoch(train) [1][3650/6164]  lr: 2.0000e-02  eta: 4:29:44  time: 0.7840  data_time: 0.0095  memory: 4333  grad_norm: 1.5406  loss: 0.3565  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0147  loss_cls: 0.1629  acc: 95.9961  loss_bbox: 0.1613
# 11/12 04:30:53 - mmengine - INFO - Epoch(train) [1][3700/6164]  lr: 2.0000e-02  eta: 4:29:08  time: 0.7812  data_time: 0.0097  memory: 4333  grad_norm: 1.5348  loss: 0.3650  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0152  loss_cls: 0.1623  acc: 93.4570  loss_bbox: 0.1693
# 11/12 04:31:32 - mmengine - INFO - Epoch(train) [1][3750/6164]  lr: 2.0000e-02  eta: 4:28:32  time: 0.7796  data_time: 0.0098  memory: 4333  grad_norm: 1.4778  loss: 0.3706  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0173  loss_cls: 0.1611  acc: 97.8027  loss_bbox: 0.1716
# 11/12 04:32:10 - mmengine - INFO - Epoch(train) [1][3800/6164]  lr: 2.0000e-02  eta: 4:27:56  time: 0.7795  data_time: 0.0095  memory: 4333  grad_norm: 1.5626  loss: 0.3549  loss_rpn_cls: 0.0169  loss_rpn_bbox: 0.0153  loss_cls: 0.1621  acc: 94.1406  loss_bbox: 0.1606
# 11/12 04:32:49 - mmengine - INFO - Epoch(train) [1][3850/6164]  lr: 2.0000e-02  eta: 4:27:19  time: 0.7773  data_time: 0.0092  memory: 4333  grad_norm: 1.4131  loss: 0.3491  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0171  loss_cls: 0.1557  acc: 96.9727  loss_bbox: 0.1588
# 11/12 04:33:28 - mmengine - INFO - Epoch(train) [1][3900/6164]  lr: 2.0000e-02  eta: 4:26:43  time: 0.7790  data_time: 0.0096  memory: 4333  grad_norm: 1.7317  loss: 0.3901  loss_rpn_cls: 0.0201  loss_rpn_bbox: 0.0165  loss_cls: 0.1784  acc: 91.7480  loss_bbox: 0.1751
# 11/12 04:34:07 - mmengine - INFO - Epoch(train) [1][3950/6164]  lr: 2.0000e-02  eta: 4:26:06  time: 0.7789  data_time: 0.0091  memory: 4333  grad_norm: 1.4967  loss: 0.3458  loss_rpn_cls: 0.0148  loss_rpn_bbox: 0.0146  loss_cls: 0.1556  acc: 95.6055  loss_bbox: 0.1608
# 11/12 04:34:46 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 04:34:46 - mmengine - INFO - Epoch(train) [1][4000/6164]  lr: 2.0000e-02  eta: 4:25:30  time: 0.7813  data_time: 0.0093  memory: 4333  grad_norm: 1.6854  loss: 0.3801  loss_rpn_cls: 0.0176  loss_rpn_bbox: 0.0158  loss_cls: 0.1718  acc: 96.4355  loss_bbox: 0.1749
# 11/12 04:35:25 - mmengine - INFO - Epoch(train) [1][4050/6164]  lr: 2.0000e-02  eta: 4:24:52  time: 0.7739  data_time: 0.0090  memory: 4333  grad_norm: 1.5149  loss: 0.3388  loss_rpn_cls: 0.0173  loss_rpn_bbox: 0.0140  loss_cls: 0.1482  acc: 98.3398  loss_bbox: 0.1593
# 11/12 04:36:03 - mmengine - INFO - Epoch(train) [1][4100/6164]  lr: 2.0000e-02  eta: 4:24:13  time: 0.7677  data_time: 0.0091  memory: 4333  grad_norm: 1.7317  loss: 0.4019  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0155  loss_cls: 0.1910  acc: 95.8008  loss_bbox: 0.1772
# 11/12 04:36:42 - mmengine - INFO - Epoch(train) [1][4150/6164]  lr: 2.0000e-02  eta: 4:23:36  time: 0.7796  data_time: 0.0085  memory: 4333  grad_norm: 1.4631  loss: 0.3430  loss_rpn_cls: 0.0153  loss_rpn_bbox: 0.0148  loss_cls: 0.1585  acc: 95.4102  loss_bbox: 0.1544
# 11/12 04:37:21 - mmengine - INFO - Epoch(train) [1][4200/6164]  lr: 2.0000e-02  eta: 4:23:00  time: 0.7788  data_time: 0.0088  memory: 4333  grad_norm: 1.5554  loss: 0.3664  loss_rpn_cls: 0.0158  loss_rpn_bbox: 0.0155  loss_cls: 0.1655  acc: 95.8008  loss_bbox: 0.1695
# 11/12 04:38:00 - mmengine - INFO - Epoch(train) [1][4250/6164]  lr: 2.0000e-02  eta: 4:22:21  time: 0.7709  data_time: 0.0095  memory: 4333  grad_norm: 1.6064  loss: 0.3519  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0149  loss_cls: 0.1655  acc: 95.8008  loss_bbox: 0.1533
# 11/12 04:38:38 - mmengine - INFO - Epoch(train) [1][4300/6164]  lr: 2.0000e-02  eta: 4:21:41  time: 0.7667  data_time: 0.0094  memory: 4333  grad_norm: 1.5466  loss: 0.3697  loss_rpn_cls: 0.0236  loss_rpn_bbox: 0.0167  loss_cls: 0.1621  acc: 94.1895  loss_bbox: 0.1673
# 11/12 04:39:17 - mmengine - INFO - Epoch(train) [1][4350/6164]  lr: 2.0000e-02  eta: 4:21:04  time: 0.7784  data_time: 0.0096  memory: 4333  grad_norm: 1.5488  loss: 0.3577  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0149  loss_cls: 0.1653  acc: 95.0195  loss_bbox: 0.1600
# 11/12 04:39:55 - mmengine - INFO - Epoch(train) [1][4400/6164]  lr: 2.0000e-02  eta: 4:20:25  time: 0.7661  data_time: 0.0094  memory: 4333  grad_norm: 1.6783  loss: 0.3888  loss_rpn_cls: 0.0168  loss_rpn_bbox: 0.0157  loss_cls: 0.1787  acc: 96.0938  loss_bbox: 0.1776
# 11/12 04:40:34 - mmengine - INFO - Epoch(train) [1][4450/6164]  lr: 2.0000e-02  eta: 4:19:46  time: 0.7702  data_time: 0.0097  memory: 4333  grad_norm: 1.6131  loss: 0.3620  loss_rpn_cls: 0.0179  loss_rpn_bbox: 0.0140  loss_cls: 0.1663  acc: 96.8262  loss_bbox: 0.1639
# 11/12 04:41:13 - mmengine - INFO - Epoch(train) [1][4500/6164]  lr: 2.0000e-02  eta: 4:19:08  time: 0.7747  data_time: 0.0094  memory: 4333  grad_norm: 1.4829  loss: 0.3582  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0168  loss_cls: 0.1553  acc: 95.4590  loss_bbox: 0.1697
# 11/12 04:41:51 - mmengine - INFO - Epoch(train) [1][4550/6164]  lr: 2.0000e-02  eta: 4:18:30  time: 0.7763  data_time: 0.0091  memory: 4333  grad_norm: 1.5345  loss: 0.3577  loss_rpn_cls: 0.0173  loss_rpn_bbox: 0.0149  loss_cls: 0.1590  acc: 95.0195  loss_bbox: 0.1665
# 11/12 04:42:31 - mmengine - INFO - Epoch(train) [1][4600/6164]  lr: 2.0000e-02  eta: 4:17:54  time: 0.7826  data_time: 0.0092  memory: 4333  grad_norm: 1.5653  loss: 0.3851  loss_rpn_cls: 0.0156  loss_rpn_bbox: 0.0181  loss_cls: 0.1771  acc: 94.2383  loss_bbox: 0.1743
# 11/12 04:43:09 - mmengine - INFO - Epoch(train) [1][4650/6164]  lr: 2.0000e-02  eta: 4:17:16  time: 0.7723  data_time: 0.0091  memory: 4333  grad_norm: 1.6741  loss: 0.3848  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0162  loss_cls: 0.1814  acc: 95.3613  loss_bbox: 0.1690
# 11/12 04:43:48 - mmengine - INFO - Epoch(train) [1][4700/6164]  lr: 2.0000e-02  eta: 4:16:38  time: 0.7758  data_time: 0.0092  memory: 4333  grad_norm: 1.5272  loss: 0.3574  loss_rpn_cls: 0.0132  loss_rpn_bbox: 0.0132  loss_cls: 0.1710  acc: 93.7988  loss_bbox: 0.1601
# 11/12 04:44:27 - mmengine - INFO - Epoch(train) [1][4750/6164]  lr: 2.0000e-02  eta: 4:16:00  time: 0.7747  data_time: 0.0099  memory: 4333  grad_norm: 1.5163  loss: 0.3741  loss_rpn_cls: 0.0193  loss_rpn_bbox: 0.0173  loss_cls: 0.1676  acc: 94.2383  loss_bbox: 0.1699
# 11/12 04:45:05 - mmengine - INFO - Epoch(train) [1][4800/6164]  lr: 2.0000e-02  eta: 4:15:21  time: 0.7682  data_time: 0.0093  memory: 4333  grad_norm: 1.5869  loss: 0.3818  loss_rpn_cls: 0.0166  loss_rpn_bbox: 0.0160  loss_cls: 0.1783  acc: 94.1895  loss_bbox: 0.1709
# 11/12 04:45:43 - mmengine - INFO - Epoch(train) [1][4850/6164]  lr: 2.0000e-02  eta: 4:14:41  time: 0.7642  data_time: 0.0095  memory: 4333  grad_norm: 1.6903  loss: 0.3849  loss_rpn_cls: 0.0204  loss_rpn_bbox: 0.0151  loss_cls: 0.1800  acc: 96.6309  loss_bbox: 0.1693
# 11/12 04:46:23 - mmengine - INFO - Epoch(train) [1][4900/6164]  lr: 2.0000e-02  eta: 4:14:06  time: 0.7891  data_time: 0.0099  memory: 4333  grad_norm: 1.5471  loss: 0.3544  loss_rpn_cls: 0.0142  loss_rpn_bbox: 0.0160  loss_cls: 0.1607  acc: 95.2148  loss_bbox: 0.1635
# 11/12 04:47:02 - mmengine - INFO - Epoch(train) [1][4950/6164]  lr: 2.0000e-02  eta: 4:13:29  time: 0.7800  data_time: 0.0098  memory: 4333  grad_norm: 1.6456  loss: 0.4027  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0180  loss_cls: 0.1818  acc: 96.4355  loss_bbox: 0.1824
# 11/12 04:47:41 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 04:47:41 - mmengine - INFO - Epoch(train) [1][5000/6164]  lr: 2.0000e-02  eta: 4:12:51  time: 0.7777  data_time: 0.0096  memory: 4333  grad_norm: 1.5212  loss: 0.3623  loss_rpn_cls: 0.0167  loss_rpn_bbox: 0.0163  loss_cls: 0.1636  acc: 93.0176  loss_bbox: 0.1657
# 11/12 04:48:20 - mmengine - INFO - Epoch(train) [1][5050/6164]  lr: 2.0000e-02  eta: 4:12:14  time: 0.7791  data_time: 0.0099  memory: 4333  grad_norm: 1.4997  loss: 0.3626  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0181  loss_cls: 0.1580  acc: 95.5566  loss_bbox: 0.1701
# 11/12 04:48:59 - mmengine - INFO - Epoch(train) [1][5100/6164]  lr: 2.0000e-02  eta: 4:11:37  time: 0.7782  data_time: 0.0098  memory: 4333  grad_norm: 1.4800  loss: 0.3586  loss_rpn_cls: 0.0142  loss_rpn_bbox: 0.0153  loss_cls: 0.1627  acc: 96.2891  loss_bbox: 0.1664
# 11/12 04:49:38 - mmengine - INFO - Epoch(train) [1][5150/6164]  lr: 2.0000e-02  eta: 4:11:00  time: 0.7802  data_time: 0.0093  memory: 4333  grad_norm: 1.7018  loss: 0.3722  loss_rpn_cls: 0.0204  loss_rpn_bbox: 0.0158  loss_cls: 0.1667  acc: 93.4082  loss_bbox: 0.1693
# 11/12 04:50:16 - mmengine - INFO - Epoch(train) [1][5200/6164]  lr: 2.0000e-02  eta: 4:10:22  time: 0.7745  data_time: 0.0087  memory: 4333  grad_norm: 1.6268  loss: 0.3514  loss_rpn_cls: 0.0161  loss_rpn_bbox: 0.0147  loss_cls: 0.1691  acc: 97.0215  loss_bbox: 0.1515
# 11/12 04:50:55 - mmengine - INFO - Epoch(train) [1][5250/6164]  lr: 2.0000e-02  eta: 4:09:44  time: 0.7795  data_time: 0.0096  memory: 4333  grad_norm: 1.6132  loss: 0.3672  loss_rpn_cls: 0.0175  loss_rpn_bbox: 0.0154  loss_cls: 0.1675  acc: 93.8477  loss_bbox: 0.1668
# 11/12 04:51:34 - mmengine - INFO - Epoch(train) [1][5300/6164]  lr: 2.0000e-02  eta: 4:09:06  time: 0.7747  data_time: 0.0097  memory: 4333  grad_norm: 1.4347  loss: 0.3445  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0150  loss_cls: 0.1570  acc: 93.5547  loss_bbox: 0.1574
# 11/12 04:52:13 - mmengine - INFO - Epoch(train) [1][5350/6164]  lr: 2.0000e-02  eta: 4:08:28  time: 0.7763  data_time: 0.0092  memory: 4333  grad_norm: 1.4844  loss: 0.3572  loss_rpn_cls: 0.0183  loss_rpn_bbox: 0.0174  loss_cls: 0.1574  acc: 94.3848  loss_bbox: 0.1640
# 11/12 04:52:52 - mmengine - INFO - Epoch(train) [1][5400/6164]  lr: 2.0000e-02  eta: 4:07:51  time: 0.7764  data_time: 0.0089  memory: 4333  grad_norm: 1.4868  loss: 0.3367  loss_rpn_cls: 0.0145  loss_rpn_bbox: 0.0150  loss_cls: 0.1563  acc: 94.6289  loss_bbox: 0.1509
# 11/12 04:53:30 - mmengine - INFO - Epoch(train) [1][5450/6164]  lr: 2.0000e-02  eta: 4:07:12  time: 0.7704  data_time: 0.0092  memory: 4333  grad_norm: 1.5031  loss: 0.3396  loss_rpn_cls: 0.0146  loss_rpn_bbox: 0.0141  loss_cls: 0.1494  acc: 93.8965  loss_bbox: 0.1615
# 11/12 04:54:09 - mmengine - INFO - Epoch(train) [1][5500/6164]  lr: 2.0000e-02  eta: 4:06:34  time: 0.7774  data_time: 0.0090  memory: 4333  grad_norm: 1.6079  loss: 0.3798  loss_rpn_cls: 0.0165  loss_rpn_bbox: 0.0167  loss_cls: 0.1644  acc: 96.9727  loss_bbox: 0.1823
# 11/12 04:54:48 - mmengine - INFO - Epoch(train) [1][5550/6164]  lr: 2.0000e-02  eta: 4:05:56  time: 0.7754  data_time: 0.0093  memory: 4333  grad_norm: 1.5525  loss: 0.3673  loss_rpn_cls: 0.0141  loss_rpn_bbox: 0.0153  loss_cls: 0.1630  acc: 93.3105  loss_bbox: 0.1749
# 11/12 04:55:27 - mmengine - INFO - Epoch(train) [1][5600/6164]  lr: 2.0000e-02  eta: 4:05:19  time: 0.7810  data_time: 0.0098  memory: 4333  grad_norm: 1.5629  loss: 0.3818  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0180  loss_cls: 0.1679  acc: 95.1172  loss_bbox: 0.1777
# ...
# 11/12 09:17:12 - mmengine - INFO - Epoch(train) [4][5850/6164]  lr: 2.0000e-02  eta: 0:04:03  time: 0.7790  data_time: 0.0102  memory: 4333  grad_norm: 1.4965  loss: 0.2571  loss_rpn_cls: 0.0069  loss_rpn_bbox: 0.0124  loss_cls: 0.1046  acc: 97.7539  loss_bbox: 0.1333
# 11/12 09:17:51 - mmengine - INFO - Epoch(train) [4][5900/6164]  lr: 2.0000e-02  eta: 0:03:24  time: 0.7742  data_time: 0.0097  memory: 4333  grad_norm: 1.6060  loss: 0.2665  loss_rpn_cls: 0.0072  loss_rpn_bbox: 0.0111  loss_cls: 0.1085  acc: 95.6543  loss_bbox: 0.1396
# 11/12 09:18:29 - mmengine - INFO - Epoch(train) [4][5950/6164]  lr: 2.0000e-02  eta: 0:02:45  time: 0.7722  data_time: 0.0100  memory: 4333  grad_norm: 1.6632  loss: 0.2607  loss_rpn_cls: 0.0076  loss_rpn_bbox: 0.0121  loss_cls: 0.1040  acc: 95.9473  loss_bbox: 0.1370
# 11/12 09:19:08 - mmengine - INFO - Epoch(train) [4][6000/6164]  lr: 2.0000e-02  eta: 0:02:07  time: 0.7712  data_time: 0.0091  memory: 4333  grad_norm: 1.5856  loss: 0.2507  loss_rpn_cls: 0.0071  loss_rpn_bbox: 0.0114  loss_cls: 0.1003  acc: 94.5801  loss_bbox: 0.1318
# 11/12 09:19:47 - mmengine - INFO - Epoch(train) [4][6050/6164]  lr: 2.0000e-02  eta: 0:01:28  time: 0.7840  data_time: 0.0100  memory: 4333  grad_norm: 1.6455  loss: 0.2780  loss_rpn_cls: 0.0074  loss_rpn_bbox: 0.0119  loss_cls: 0.1132  acc: 98.4863  loss_bbox: 0.1455
# 11/12 09:20:26 - mmengine - INFO - Epoch(train) [4][6100/6164]  lr: 2.0000e-02  eta: 0:00:49  time: 0.7769  data_time: 0.0095  memory: 4333  grad_norm: 1.5780  loss: 0.2738  loss_rpn_cls: 0.0068  loss_rpn_bbox: 0.0117  loss_cls: 0.1131  acc: 96.0449  loss_bbox: 0.1422
# 11/12 09:21:05 - mmengine - INFO - Epoch(train) [4][6150/6164]  lr: 2.0000e-02  eta: 0:00:10  time: 0.7758  data_time: 0.0098  memory: 4333  grad_norm: 1.5165  loss: 0.2657  loss_rpn_cls: 0.0067  loss_rpn_bbox: 0.0136  loss_cls: 0.1033  acc: 96.4355  loss_bbox: 0.1420
# 11/12 09:21:15 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251112_034209
# 11/12 09:21:15 - mmengine - INFO - Saving checkpoint at 4 epochs
# 11/12 09:21:21 - mmengine - INFO - Epoch(val) [4][  50/4952]    eta: 0:06:25  time: 0.0787  data_time: 0.0029  memory: 5064
# 11/12 09:21:25 - mmengine - INFO - Epoch(val) [4][ 100/4952]    eta: 0:06:20  time: 0.0784  data_time: 0.0030  memory: 689
# 11/12 09:21:29 - mmengine - INFO - Epoch(val) [4][ 150/4952]    eta: 0:06:17  time: 0.0788  data_time: 0.0028  memory: 675
# 11/12 09:21:33 - mmengine - INFO - Epoch(val) [4][ 200/4952]    eta: 0:06:13  time: 0.0789  data_time: 0.0030  memory: 669
# 11/12 09:21:37 - mmengine - INFO - Epoch(val) [4][ 250/4952]    eta: 0:06:09  time: 0.0784  data_time: 0.0029  memory: 689
# 11/12 09:21:40 - mmengine - INFO - Epoch(val) [4][ 300/4952]    eta: 0:06:04  time: 0.0769  data_time: 0.0026  memory: 682
# 11/12 09:21:44 - mmengine - INFO - Epoch(val) [4][ 350/4952]    eta: 0:06:00  time: 0.0784  data_time: 0.0029  memory: 689
# 11/12 09:21:48 - mmengine - INFO - Epoch(val) [4][ 400/4952]    eta: 0:05:56  time: 0.0787  data_time: 0.0031  memory: 689
# 11/12 09:21:52 - mmengine - INFO - Epoch(val) [4][ 450/4952]    eta: 0:05:53  time: 0.0791  data_time: 0.0028  memory: 677
# 11/12 09:21:56 - mmengine - INFO - Epoch(val) [4][ 500/4952]    eta: 0:05:49  time: 0.0778  data_time: 0.0029  memory: 675
# 11/12 09:22:00 - mmengine - INFO - Epoch(val) [4][ 550/4952]    eta: 0:05:44  time: 0.0776  data_time: 0.0027  memory: 682
# 11/12 09:22:04 - mmengine - INFO - Epoch(val) [4][ 600/4952]    eta: 0:05:41  time: 0.0791  data_time: 0.0028  memory: 675
# 11/12 09:22:08 - mmengine - INFO - Epoch(val) [4][ 650/4952]    eta: 0:05:36  time: 0.0775  data_time: 0.0027  memory: 682
# 11/12 09:22:12 - mmengine - INFO - Epoch(val) [4][ 700/4952]    eta: 0:05:33  time: 0.0785  data_time: 0.0028  memory: 675
# 11/12 09:22:16 - mmengine - INFO - Epoch(val) [4][ 750/4952]    eta: 0:05:29  time: 0.0790  data_time: 0.0031  memory: 682
# 11/12 09:22:20 - mmengine - INFO - Epoch(val) [4][ 800/4952]    eta: 0:05:25  time: 0.0773  data_time: 0.0030  memory: 675
# 11/12 09:22:24 - mmengine - INFO - Epoch(val) [4][ 850/4952]    eta: 0:05:21  time: 0.0785  data_time: 0.0032  memory: 677
# 11/12 09:22:28 - mmengine - INFO - Epoch(val) [4][ 900/4952]    eta: 0:05:17  time: 0.0784  data_time: 0.0028  memory: 689
# 11/12 09:22:31 - mmengine - INFO - Epoch(val) [4][ 950/4952]    eta: 0:05:13  time: 0.0778  data_time: 0.0026  memory: 682
# 11/12 09:22:35 - mmengine - INFO - Epoch(val) [4][1000/4952]    eta: 0:05:09  time: 0.0795  data_time: 0.0032  memory: 689
# 11/12 09:22:39 - mmengine - INFO - Epoch(val) [4][1050/4952]    eta: 0:05:05  time: 0.0785  data_time: 0.0029  memory: 689
# 11/12 09:22:43 - mmengine - INFO - Epoch(val) [4][1100/4952]    eta: 0:05:01  time: 0.0786  data_time: 0.0029  memory: 677
# 11/12 09:22:47 - mmengine - INFO - Epoch(val) [4][1150/4952]    eta: 0:04:58  time: 0.0794  data_time: 0.0031  memory: 689
# 11/12 09:22:51 - mmengine - INFO - Epoch(val) [4][1200/4952]    eta: 0:04:54  time: 0.0783  data_time: 0.0027  memory: 682
# 11/12 09:22:55 - mmengine - INFO - Epoch(val) [4][1250/4952]    eta: 0:04:50  time: 0.0783  data_time: 0.0028  memory: 677
# 11/12 09:22:59 - mmengine - INFO - Epoch(val) [4][1300/4952]    eta: 0:04:46  time: 0.0786  data_time: 0.0030  memory: 677
# 11/12 09:23:03 - mmengine - INFO - Epoch(val) [4][1350/4952]    eta: 0:04:42  time: 0.0777  data_time: 0.0030  memory: 689
# 11/12 09:23:07 - mmengine - INFO - Epoch(val) [4][1400/4952]    eta: 0:04:38  time: 0.0780  data_time: 0.0027  memory: 675
# 11/12 09:23:11 - mmengine - INFO - Epoch(val) [4][1450/4952]    eta: 0:04:34  time: 0.0787  data_time: 0.0029  memory: 689
# 11/12 09:23:15 - mmengine - INFO - Epoch(val) [4][1500/4952]    eta: 0:04:30  time: 0.0792  data_time: 0.0028  memory: 682
# 11/12 09:23:19 - mmengine - INFO - Epoch(val) [4][1550/4952]    eta: 0:04:26  time: 0.0784  data_time: 0.0029  memory: 677
# 11/12 09:23:23 - mmengine - INFO - Epoch(val) [4][1600/4952]    eta: 0:04:22  time: 0.0790  data_time: 0.0029  memory: 688
# 11/12 09:23:26 - mmengine - INFO - Epoch(val) [4][1650/4952]    eta: 0:04:18  time: 0.0779  data_time: 0.0029  memory: 677
# 11/12 09:23:30 - mmengine - INFO - Epoch(val) [4][1700/4952]    eta: 0:04:14  time: 0.0777  data_time: 0.0028  memory: 677
# 11/12 09:23:34 - mmengine - INFO - Epoch(val) [4][1750/4952]    eta: 0:04:11  time: 0.0789  data_time: 0.0031  memory: 669
# 11/12 09:23:38 - mmengine - INFO - Epoch(val) [4][1800/4952]    eta: 0:04:07  time: 0.0776  data_time: 0.0028  memory: 669
# 11/12 09:23:42 - mmengine - INFO - Epoch(val) [4][1850/4952]    eta: 0:04:03  time: 0.0776  data_time: 0.0027  memory: 669
# 11/12 09:23:46 - mmengine - INFO - Epoch(val) [4][1900/4952]    eta: 0:03:59  time: 0.0774  data_time: 0.0027  memory: 675
# 11/12 09:23:50 - mmengine - INFO - Epoch(val) [4][1950/4952]    eta: 0:03:55  time: 0.0785  data_time: 0.0029  memory: 682
# 11/12 09:23:54 - mmengine - INFO - Epoch(val) [4][2000/4952]    eta: 0:03:51  time: 0.0775  data_time: 0.0029  memory: 675
# 11/12 09:23:58 - mmengine - INFO - Epoch(val) [4][2050/4952]    eta: 0:03:47  time: 0.0782  data_time: 0.0029  memory: 689
# 11/12 09:24:02 - mmengine - INFO - Epoch(val) [4][2100/4952]    eta: 0:03:43  time: 0.0787  data_time: 0.0031  memory: 677
# 11/12 09:24:05 - mmengine - INFO - Epoch(val) [4][2150/4952]    eta: 0:03:39  time: 0.0776  data_time: 0.0029  memory: 682
# 11/12 09:24:09 - mmengine - INFO - Epoch(val) [4][2200/4952]    eta: 0:03:35  time: 0.0790  data_time: 0.0029  memory: 675
# 11/12 09:24:13 - mmengine - INFO - Epoch(val) [4][2250/4952]    eta: 0:03:31  time: 0.0777  data_time: 0.0029  memory: 689
# 11/12 09:24:17 - mmengine - INFO - Epoch(val) [4][2300/4952]    eta: 0:03:27  time: 0.0780  data_time: 0.0026  memory: 677
# 11/12 09:24:21 - mmengine - INFO - Epoch(val) [4][2350/4952]    eta: 0:03:23  time: 0.0777  data_time: 0.0028  memory: 677
# 11/12 09:24:25 - mmengine - INFO - Epoch(val) [4][2400/4952]    eta: 0:03:19  time: 0.0786  data_time: 0.0027  memory: 677
# 11/12 09:24:29 - mmengine - INFO - Epoch(val) [4][2450/4952]    eta: 0:03:15  time: 0.0782  data_time: 0.0027  memory: 677
# 11/12 09:24:33 - mmengine - INFO - Epoch(val) [4][2500/4952]    eta: 0:03:12  time: 0.0788  data_time: 0.0026  memory: 688
# 11/12 09:24:37 - mmengine - INFO - Epoch(val) [4][2550/4952]    eta: 0:03:08  time: 0.0782  data_time: 0.0031  memory: 669
# 11/12 09:24:41 - mmengine - INFO - Epoch(val) [4][2600/4952]    eta: 0:03:04  time: 0.0782  data_time: 0.0033  memory: 682
# 11/12 09:24:45 - mmengine - INFO - Epoch(val) [4][2650/4952]    eta: 0:03:00  time: 0.0789  data_time: 0.0029  memory: 682
# 11/12 09:24:49 - mmengine - INFO - Epoch(val) [4][2700/4952]    eta: 0:02:56  time: 0.0786  data_time: 0.0030  memory: 689
# 11/12 09:24:53 - mmengine - INFO - Epoch(val) [4][2750/4952]    eta: 0:02:52  time: 0.0789  data_time: 0.0031  memory: 675
# 11/12 09:24:56 - mmengine - INFO - Epoch(val) [4][2800/4952]    eta: 0:02:48  time: 0.0772  data_time: 0.0028  memory: 677
# 11/12 09:25:00 - mmengine - INFO - Epoch(val) [4][2850/4952]    eta: 0:02:44  time: 0.0790  data_time: 0.0029  memory: 677
# 11/12 09:25:04 - mmengine - INFO - Epoch(val) [4][2900/4952]    eta: 0:02:40  time: 0.0772  data_time: 0.0032  memory: 682
# 11/12 09:25:08 - mmengine - INFO - Epoch(val) [4][2950/4952]    eta: 0:02:36  time: 0.0777  data_time: 0.0027  memory: 688
# 11/12 09:25:12 - mmengine - INFO - Epoch(val) [4][3000/4952]    eta: 0:02:32  time: 0.0791  data_time: 0.0028  memory: 669
# 11/12 09:25:16 - mmengine - INFO - Epoch(val) [4][3050/4952]    eta: 0:02:28  time: 0.0776  data_time: 0.0028  memory: 677
# 11/12 09:25:20 - mmengine - INFO - Epoch(val) [4][3100/4952]    eta: 0:02:25  time: 0.0788  data_time: 0.0027  memory: 689
# 11/12 09:25:24 - mmengine - INFO - Epoch(val) [4][3150/4952]    eta: 0:02:21  time: 0.0788  data_time: 0.0029  memory: 677
# 11/12 09:25:28 - mmengine - INFO - Epoch(val) [4][3200/4952]    eta: 0:02:17  time: 0.0786  data_time: 0.0030  memory: 677
# 11/12 09:25:32 - mmengine - INFO - Epoch(val) [4][3250/4952]    eta: 0:02:13  time: 0.0784  data_time: 0.0028  memory: 677
# 11/12 09:25:36 - mmengine - INFO - Epoch(val) [4][3300/4952]    eta: 0:02:09  time: 0.0789  data_time: 0.0029  memory: 675
# 11/12 09:25:40 - mmengine - INFO - Epoch(val) [4][3350/4952]    eta: 0:02:05  time: 0.0783  data_time: 0.0026  memory: 677
# 11/12 09:25:44 - mmengine - INFO - Epoch(val) [4][3400/4952]    eta: 0:02:01  time: 0.0791  data_time: 0.0027  memory: 688
# 11/12 09:25:47 - mmengine - INFO - Epoch(val) [4][3450/4952]    eta: 0:01:57  time: 0.0770  data_time: 0.0025  memory: 675
# 11/12 09:25:51 - mmengine - INFO - Epoch(val) [4][3500/4952]    eta: 0:01:53  time: 0.0791  data_time: 0.0031  memory: 677
# 11/12 09:25:55 - mmengine - INFO - Epoch(val) [4][3550/4952]    eta: 0:01:49  time: 0.0797  data_time: 0.0030  memory: 669
# 11/12 09:25:59 - mmengine - INFO - Epoch(val) [4][3600/4952]    eta: 0:01:45  time: 0.0788  data_time: 0.0030  memory: 688
# 11/12 09:26:03 - mmengine - INFO - Epoch(val) [4][3650/4952]    eta: 0:01:42  time: 0.0786  data_time: 0.0033  memory: 689
# 11/12 09:26:07 - mmengine - INFO - Epoch(val) [4][3700/4952]    eta: 0:01:38  time: 0.0782  data_time: 0.0030  memory: 669
# 11/12 09:26:11 - mmengine - INFO - Epoch(val) [4][3750/4952]    eta: 0:01:34  time: 0.0772  data_time: 0.0029  memory: 677
# 11/12 09:26:15 - mmengine - INFO - Epoch(val) [4][3800/4952]    eta: 0:01:30  time: 0.0783  data_time: 0.0030  memory: 677
# 11/12 09:26:19 - mmengine - INFO - Epoch(val) [4][3850/4952]    eta: 0:01:26  time: 0.0784  data_time: 0.0029  memory: 675
# 11/12 09:26:23 - mmengine - INFO - Epoch(val) [4][3900/4952]    eta: 0:01:22  time: 0.0785  data_time: 0.0030  memory: 677
# 11/12 09:26:27 - mmengine - INFO - Epoch(val) [4][3950/4952]    eta: 0:01:18  time: 0.0776  data_time: 0.0027  memory: 677
# 11/12 09:26:31 - mmengine - INFO - Epoch(val) [4][4000/4952]    eta: 0:01:14  time: 0.0793  data_time: 0.0029  memory: 689
# 11/12 09:26:35 - mmengine - INFO - Epoch(val) [4][4050/4952]    eta: 0:01:10  time: 0.0795  data_time: 0.0031  memory: 682
# 11/12 09:26:38 - mmengine - INFO - Epoch(val) [4][4100/4952]    eta: 0:01:06  time: 0.0770  data_time: 0.0030  memory: 689
# 11/12 09:26:42 - mmengine - INFO - Epoch(val) [4][4150/4952]    eta: 0:01:02  time: 0.0771  data_time: 0.0026  memory: 688
# 11/12 09:26:46 - mmengine - INFO - Epoch(val) [4][4200/4952]    eta: 0:00:58  time: 0.0775  data_time: 0.0030  memory: 669
# 11/12 09:26:50 - mmengine - INFO - Epoch(val) [4][4250/4952]    eta: 0:00:54  time: 0.0780  data_time: 0.0030  memory: 689
# 11/12 09:26:54 - mmengine - INFO - Epoch(val) [4][4300/4952]    eta: 0:00:51  time: 0.0800  data_time: 0.0029  memory: 682
# 11/12 09:26:58 - mmengine - INFO - Epoch(val) [4][4350/4952]    eta: 0:00:47  time: 0.0789  data_time: 0.0028  memory: 689
# 11/12 09:27:02 - mmengine - INFO - Epoch(val) [4][4400/4952]    eta: 0:00:43  time: 0.0784  data_time: 0.0030  memory: 675
# 11/12 09:27:06 - mmengine - INFO - Epoch(val) [4][4450/4952]    eta: 0:00:39  time: 0.0804  data_time: 0.0029  memory: 675
# 11/12 09:27:10 - mmengine - INFO - Epoch(val) [4][4500/4952]    eta: 0:00:35  time: 0.0780  data_time: 0.0027  memory: 677
# 11/12 09:27:14 - mmengine - INFO - Epoch(val) [4][4550/4952]    eta: 0:00:31  time: 0.0791  data_time: 0.0030  memory: 682
# 11/12 09:27:18 - mmengine - INFO - Epoch(val) [4][4600/4952]    eta: 0:00:27  time: 0.0768  data_time: 0.0026  memory: 669
# 11/12 09:27:22 - mmengine - INFO - Epoch(val) [4][4650/4952]    eta: 0:00:23  time: 0.0777  data_time: 0.0028  memory: 675
# 11/12 09:27:26 - mmengine - INFO - Epoch(val) [4][4700/4952]    eta: 0:00:19  time: 0.0791  data_time: 0.0028  memory: 688
# 11/12 09:27:29 - mmengine - INFO - Epoch(val) [4][4750/4952]    eta: 0:00:15  time: 0.0777  data_time: 0.0030  memory: 677
# 11/12 09:27:33 - mmengine - INFO - Epoch(val) [4][4800/4952]    eta: 0:00:11  time: 0.0786  data_time: 0.0028  memory: 669
# 11/12 09:27:37 - mmengine - INFO - Epoch(val) [4][4850/4952]    eta: 0:00:07  time: 0.0784  data_time: 0.0027  memory: 682
# 11/12 09:27:41 - mmengine - INFO - Epoch(val) [4][4900/4952]    eta: 0:00:04  time: 0.0783  data_time: 0.0028  memory: 675
# 11/12 09:27:45 - mmengine - INFO - Epoch(val) [4][4950/4952]    eta: 0:00:00  time: 0.0793  data_time: 0.0029  memory: 682
# 11/12 09:27:45 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# 11/12 09:27:49 - mmengine - INFO -
# +-------------+------+-------+--------+-------+
# | class       | gts  | dets  | recall | ap    |
# +-------------+------+-------+--------+-------+
# | aeroplane   | 285  | 845   | 0.716  | 0.630 |
# | bicycle     | 337  | 793   | 0.843  | 0.726 |
# | bird        | 459  | 1750  | 0.776  | 0.631 |
# | boat        | 263  | 660   | 0.643  | 0.448 |
# | bottle      | 469  | 2339  | 0.539  | 0.351 |
# | bus         | 213  | 1529  | 0.892  | 0.715 |
# | car         | 1201 | 7616  | 0.896  | 0.777 |
# | cat         | 358  | 2339  | 0.936  | 0.790 |
# | chair       | 756  | 3236  | 0.720  | 0.496 |
# | cow         | 244  | 1666  | 0.881  | 0.637 |
# | diningtable | 206  | 1849  | 0.869  | 0.632 |
# | dog         | 489  | 2564  | 0.943  | 0.681 |
# | horse       | 348  | 1593  | 0.911  | 0.748 |
# | motorbike   | 325  | 3695  | 0.938  | 0.747 |
# | person      | 4528 | 16957 | 0.857  | 0.736 |
# | pottedplant | 480  | 3004  | 0.706  | 0.412 |
# | sheep       | 242  | 1038  | 0.736  | 0.584 |
# | sofa        | 239  | 1320  | 0.891  | 0.655 |
# | train       | 282  | 3492  | 0.943  | 0.734 |
# | tvmonitor   | 308  | 778   | 0.747  | 0.643 |
# +-------------+------+-------+--------+-------+
# | mAP         |      |       |        | 0.639 |
# +-------------+------+-------+--------+-------+
# 11/12 09:27:49 - mmengine - INFO - Epoch(val) [4][4952/4952]    pascal_voc/mAP: 0.6387  pascal_voc/AP50: 0.6390  data_time: 0.0029  time: 0.0784
