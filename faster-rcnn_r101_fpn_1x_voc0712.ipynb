# %% [markdown]
# <a href="https://www.kaggle.com/code/thoihunhvn/crosskd?scriptVersionId=288654407" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cài đặt

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113

# !pip install -U openmim

# !mim install "mmengine==0.7.3"

# !mim install "mmcv==2.0.0rc4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch==1.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (1837.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 461.7 kB/s eta 0:00:00
# Collecting torchvision==0.13.1
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.13.1%2Bcu113-cp310-cp310-linux_x86_64.whl (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 92.0 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1
#   Downloading https://download.pytorch.org/whl/cu113/torchaudio-0.12.1%2Bcu113-cp310-cp310-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==1.12.1) (4.12.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.13.1) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.13.1) (2024.8.30)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# Successfully installed torch-1.12.1+cu113 torchaudio-0.12.1+cu113 torchvision-0.13.1+cu113
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /opt/conda/lib/python3.10/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /opt/conda/lib/python3.10/site-packages (from openmim) (24.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from openmim) (13.7.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (3.6)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (3.20.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (4.66.4)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 9.1 MB/s eta 0:00:00
# done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 22.5 MB/s eta 0:00:00
# done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.8 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.3-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.5/314.5 kB 22.0 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.4 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 17.4 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 32.0 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.6 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.2 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 48.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 6.9 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core
# done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=9848d15902cc9564b03b46d7be314810d785ee27ddccfbb672d5bb11b98d9f16
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
# done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535317 sha256=4a1cde3dae8a1ddf945e1736dfb4210a4bc6b19dbba4565d94928d0dc6abab22
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
# Successfully built oss2 aliyun-python-sdk-core
# Installing collected packages: pytz, tqdm, setuptools, requests, packaging, ordered-set, jmespath, filelock, rich, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.1
#     Uninstalling filelock-3.15.1:
#       Successfully uninstalled filelock-3.15.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.0.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# boto3 1.26.100 requires botocore<1.30.0,>=1.29.100, but you have botocore 1.35.23 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# datasets 3.0.1 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.0.1 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-server 2.27.2 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.12.1+cu113 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.12.1+cu113 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.3 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmengine==0.7.3
#   Downloading mmengine-0.7.3-py3-none-any.whl.metadata (18 kB)
# Collecting addict (from mmengine==0.7.3)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (1.26.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (6.0.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (2.4.0)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmengine==0.7.3) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine==0.7.3) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine==0.7.3) (2.18.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine==0.7.3) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine==0.7.3) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine==0.7.3) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine==0.7.3) (1.16.0)
# Downloading mmengine-0.7.3-py3-none-any.whl (372 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 372.1/372.1 kB 8.0 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict, mmengine
# Successfully installed addict-2.4.0 mmengine-0.7.3
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/index.html
# Collecting mmcv==2.0.0rc4
#   Downloading https://download.openmmlab.com/mmcv/dist/cu113/torch1.12.0/mmcv-2.0.0rc4-cp310-cp310-manylinux1_x86_64.whl (44.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: mmengine>=0.2.0 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.7.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.0.0rc4) (4.10.0.84)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (3.7.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.2.0->mmcv==2.0.0rc4) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.0.0rc4) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv==2.0.0rc4) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.2.0->mmcv==2.0.0rc4) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv==2.0.0rc4) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.0rc4

# %%
# !git clone --branch faster-rcnn https://github.com/jbwang1997/CrossKD.git
# %cd CrossKD
# Out:
# Cloning into 'CrossKD'...
# remote: Enumerating objects: 34364, done.
# remote: Counting objects: 100% (1727/1727), done.
# remote: Compressing objects: 100% (278/278), done.
# remote: Total 34364 (delta 1583), reused 1449 (delta 1449), pack-reused 32637 (from 2)
# Receiving objects: 100% (34364/34364), 32.16 MiB | 36.23 MiB/s, done.
# Resolving deltas: 100% (26898/26898), done.
# /kaggle/working/CrossKD

# %%
# !pip install -v -e .
# "-v" means verbose, or more output
# "-e" means installing a project in editable mode,
# thus any local modifications made to the code will take effect without reinstallation.

# !pip install yapf==0.32.0
# Out:
# Using pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/CrossKD
#   Running command python setup.py egg_info
#   /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#   ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#   Your build configuration is incomplete and previously worked by accident!
#   setuptools_scm requires setuptools>=61
#
#   Suggested workaround if applicable:
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-ii7hm60f/mmdet.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-ii7hm60f/mmdet.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmdet/VERSION'
#   warning: no files found matching 'mmdet/.mim/model-index.yml'
#   warning: no files found matching 'mmdet/.mim/demo/*/*'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmdet/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmdet/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmdet/.mim/tools'
#   writing manifest file '/tmp/pip-pip-egg-info-ii7hm60f/mmdet.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.26.4)
# Collecting pycocotools (from mmdet==3.0.0rc6)
#   Obtaining dependency information for pycocotools from https://files.pythonhosted.org/packages/c5/a1/b4b49b85763043372e66baa10dffa42337cf4687d6db22546c27f3a4d732/pycocotools-2.0.11-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading pycocotools-2.0.11-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.14.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from mmdet==3.0.0rc6) (1.16.0)
# Collecting terminaltables (from mmdet==3.0.0rc6)
#   Obtaining dependency information for terminaltables from https://files.pythonhosted.org/packages/c4/fb/ea621e0a19733e01fe4005d46087d383693c0f4a8f824b47d8d4122c87e0/terminaltables-3.1.10-py2.py3-none-any.whl.metadata
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet==3.0.0rc6) (2.9.0.post0)
# Downloading pycocotools-2.0.11-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.5/472.5 kB 13.2 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, pycocotools, mmdet
#   Running setup.py develop for mmdet
#     Running command python setup.py develop
#     /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#     ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#     Your build configuration is incomplete and previously worked by accident!
#     setuptools_scm requires setuptools>=61
#
#     Suggested workaround if applicable:
#      - migrating from the deprecated setup_requires mechanism to pep517/518
#        and using a pyproject.toml to declare build dependencies
#        which are reliably pre-installed before running the build tools
#
#       warnings.warn(
#     running develop
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /opt/conda/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     creating mmdet.egg-info
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     warning: no files found matching 'mmdet/VERSION'
#     warning: no files found matching 'mmdet/.mim/demo/*/*'
#     writing manifest file 'mmdet.egg-info/SOURCES.txt'
#     running build_ext
# Successfully installed mmdet-3.0.0rc6 pycocotools-2.0.11 terminaltables-3.1.10
# Collecting yapf==0.32.0
#   Downloading yapf-0.32.0-py2.py3-none-any.whl.metadata (34 kB)
# Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: yapf
#   Attempting uninstall: yapf
#     Found existing installation: yapf 0.40.2
#     Uninstalling yapf-0.40.2:
#       Successfully uninstalled yapf-0.40.2
# Successfully installed yapf-0.32.0

# %% [markdown]
# # Thực hiện các bước di chuyển và cài đặt cấu hình

# %%
# !ls configs/
# Out:
# _base_		  dino		       legacy_1.x	    rpn
# albu_example	  double_heads	       libra_rcnn	    rtmdet
# atss		  dyhead	       lvis		    sabl
# autoassign	  dynamic_rcnn	       mask2former	    scnet
# boxinst		  efficientnet	       mask_rcnn	    scratch
# carafe		  empirical_attention  maskformer	    seesaw_loss
# cascade_rcnn	  fast_rcnn	       misc		    selfsup_pretrain
# cascade_rpn	  faster_rcnn	       ms_rcnn		    simple_copy_paste
# centernet	  fcos		       nas_fcos		    soft_teacher
# centripetalnet	  foveabox	       nas_fpn		    solo
# cityscapes	  fpg		       objects365	    solov2
# common		  free_anchor	       openimages	    sparse_rcnn
# condinst	  fsaf		       paa		    ssd
# conditional_detr  gcnet		       pafpn		    strong_baselines
# convnext	  gfl		       panoptic_fpn	    swin
# cornernet	  ghm		       pascal_voc	    timm_example
# crosskd		  gn		       pisa		    tood
# crowddet	  gn+ws		       point_rend	    tridentnet
# dab_detr	  grid_rcnn	       pvt		    vfnet
# dcn		  groie		       queryinst	    wider_face
# dcnv2		  guided_anchoring     regnet		    yolact
# ddod		  hrnet		       reppoints	    yolo
# deepfashion	  htc		       res2net		    yolof
# deformable_detr   instaboost	       resnest		    yolox
# detectors	  lad		       resnet_strikes_back
# detr		  ld		       retinanet

# %%
# !cp /kaggle/input/voc-fasterrcnn/voc0712_faster_rcnn.py configs/_base_/datasets/voc0712.py

# %%
# !cp /kaggle/input/faster-rcnn-voc/faster-rcnn_r50_fpn_1x_voc0712.py configs/faster_rcnn/

# %%
# !cp /kaggle/input/base-r18/faster-rcnn_r18_fpn_1x_voc0712.py configs/faster_rcnn/

# %%
# !cp /kaggle/input/schedule-1/schedule_1x.py configs/_base_/schedules/schedule_1x.py

# %%
# !cp /kaggle/input/base-configfasterrcnn/faster-rcnn_r50_fpn.py configs/_base_/models/faster-rcnn_r50_fpn.py

# %%
# !ls configs/faster_rcnn/
# Out:
# README.md
# faster-rcnn_r101-caffe_fpn_1x_coco.py
# faster-rcnn_r101-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r101_fpn_1x_coco.py
# faster-rcnn_r101_fpn_2x_coco.py
# faster-rcnn_r101_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r101_fpn_ms-3x_coco.py
# faster-rcnn_r18_fpn_1x_voc0712.py
# faster-rcnn_r18_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50-caffe-c4_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-1x_coco.py
# faster-rcnn_r50-caffe-dc5_ms-3x_coco.py
# faster-rcnn_r50-caffe_c4-1x_coco.py
# faster-rcnn_r50-caffe_fpn_1x_coco.py
# faster-rcnn_r50-caffe_fpn_90k_coco.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person-bicycle-car.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco-person.py
# faster-rcnn_r50-caffe_fpn_ms-1x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-2x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-3x_coco.py
# faster-rcnn_r50-caffe_fpn_ms-90k_coco.py
# faster-rcnn_r50-tnr-pre_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_coco.py
# faster-rcnn_r50_fpn_1x_voc0712.py
# faster-rcnn_r50_fpn_2x_coco.py
# faster-rcnn_r50_fpn_8xb8-amp-lsj-200e_coco.py
# faster-rcnn_r50_fpn_amp-1x_coco.py
# faster-rcnn_r50_fpn_bounded-iou_1x_coco.py
# faster-rcnn_r50_fpn_ciou_1x_coco.py
# faster-rcnn_r50_fpn_fcos-rpn_1x_coco.py
# faster-rcnn_r50_fpn_giou_1x_coco.py
# faster-rcnn_r50_fpn_iou_1x_coco.py
# faster-rcnn_r50_fpn_ms-3x_coco.py
# faster-rcnn_r50_fpn_ohem_1x_coco.py
# faster-rcnn_r50_fpn_soft-nms_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_1x_coco.py
# faster-rcnn_x101-32x4d_fpn_2x_coco.py
# faster-rcnn_x101-32x4d_fpn_ms-3x_coco.py
# faster-rcnn_x101-32x8d_fpn_ms-3x_coco.py
# faster-rcnn_x101-64x4d_fpn_1x_coco.py
# faster-rcnn_x101-64x4d_fpn_2x_coco.py
# faster-rcnn_x101-64x4d_fpn_ms-3x_coco.py
# metafile.yml

# %%
# !cat configs/faster_rcnn/faster-rcnn_r18_fpn_1x_voc0712.py
# Out:
# _base_ = [
#     '../_base_/models/faster-rcnn_r50_fpn.py',
#     '../_base_/datasets/voc0712.py',
#     '../_base_/schedules/schedule_1x.py', '../_base_/default_runtime.py'
# ]
#
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=18,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet18')),
#     neck=dict(
#         type='FPN',
#         in_channels=[64, 128, 256, 512],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))

# %%
# !cat configs/_base_/schedules/schedule_1x.py
# Out:
# # training schedule for 1x
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
#
# # learning rate
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
#
# # optimizer
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     clip_grad=dict(max_norm=35, norm_type=2))
# auto_scale_lr = dict(enable=False, base_batch_size=16)

# %%
# !cat configs/_base_/models/faster-rcnn_r50_fpn.py
# Out:
# # model settings
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[.0, .0, .0, .0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0., 0., 0., 0.],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     # model training and testing settings
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)
#         # soft-nms is also supported for rcnn testing
#         # e.g., nms=dict(type='soft_nms', iou_threshold=0.5, min_score=0.05)
#     ))

# %%
# !python tools/train.py configs/faster_rcnn/faster-rcnn_r50_fpn_1x_voc0712.py --work-dir /kaggle/working/w
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 12/27 06:46:44 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     numpy_random_seed: 480003274
#     GPU 0,1: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 1.12.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu113
#     OpenCV: 4.10.0
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 12/27 06:46:44 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=20,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'VOCDataset'
# data_root = '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit'
# file_client_args = dict(backend='disk')
# train_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', file_client_args=dict(backend='disk')),
#     dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='RepeatDataset',
#         times=3,
#         dataset=dict(
#             type='ConcatDataset',
#             ignore_keys=['dataset_type'],
#             datasets=[
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2007/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2007/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ]),
#                 dict(
#                     type='VOCDataset',
#                     data_root=
#                     '/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#                     ann_file='VOC2012/ImageSets/Main/train.txt',
#                     data_prefix=dict(sub_data_root='VOC2012/'),
#                     filter_cfg=dict(
#                         filter_empty_gt=True, min_size=32, bbox_min_size=32),
#                     pipeline=[
#                         dict(
#                             type='LoadImageFromFile',
#                             file_client_args=dict(backend='disk')),
#                         dict(type='LoadAnnotations', with_bbox=True),
#                         dict(
#                             type='Resize', scale=(1000, 600), keep_ratio=True),
#                         dict(type='RandomFlip', prob=0.5),
#                         dict(type='PackDetInputs')
#                     ])
#             ])))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='VOCDataset',
#         data_root='/kaggle/input/pascal-voc-2007-and-2012/VOCdevkit',
#         ann_file='VOC2007/ImageSets/Main/test.txt',
#         data_prefix=dict(sub_data_root='VOC2007/'),
#         test_mode=True,
#         pipeline=[
#             dict(
#                 type='LoadImageFromFile',
#                 file_client_args=dict(backend='disk')),
#             dict(type='Resize', scale=(1000, 600), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ]))
# val_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# test_evaluator = dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=4, val_interval=1)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     clip_grad=dict(max_norm=35, norm_type=2))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# load_from = None
# resume = False
# launcher = 'none'
# work_dir = '/kaggle/working/w'
#
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.8 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 12/27 06:46:51 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 12/27 06:46:51 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 12/27 06:46:51 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 12/27 06:46:51 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 12/27 06:48:44 - mmengine - INFO - load model from: torchvision://resnet50
# 12/27 06:48:44 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 208MB/s]
# 12/27 06:48:45 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 12/27 06:48:45 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/w.
# 12/27 06:49:22 - mmengine - INFO - Epoch(train) [1][  50/6164]  lr: 1.9820e-03  eta: 5:05:55  time: 0.7460  data_time: 0.0115  memory: 4333  grad_norm: 6.3456  loss: 1.1577  loss_rpn_cls: 0.3517  loss_rpn_bbox: 0.0212  loss_cls: 0.7168  acc: 97.1191  loss_bbox: 0.0681
# 12/27 06:50:01 - mmengine - INFO - Epoch(train) [1][ 100/6164]  lr: 3.9840e-03  eta: 5:12:36  time: 0.7816  data_time: 0.0077  memory: 4333  grad_norm: 1.6492  loss: 0.4911  loss_rpn_cls: 0.0638  loss_rpn_bbox: 0.0217  loss_cls: 0.2473  acc: 95.6055  loss_bbox: 0.1582
# 12/27 06:50:43 - mmengine - INFO - Epoch(train) [1][ 150/6164]  lr: 5.9860e-03  eta: 5:22:22  time: 0.8403  data_time: 0.0080  memory: 4333  grad_norm: 1.5553  loss: 0.4685  loss_rpn_cls: 0.0503  loss_rpn_bbox: 0.0183  loss_cls: 0.2332  acc: 97.0215  loss_bbox: 0.1667
# 12/27 06:51:24 - mmengine - INFO - Epoch(train) [1][ 200/6164]  lr: 7.9880e-03  eta: 5:23:50  time: 0.8102  data_time: 0.0081  memory: 4333  grad_norm: 1.9912  loss: 0.5134  loss_rpn_cls: 0.0466  loss_rpn_bbox: 0.0187  loss_cls: 0.2604  acc: 97.4121  loss_bbox: 0.1877
# 12/27 06:52:04 - mmengine - INFO - Epoch(train) [1][ 250/6164]  lr: 9.9900e-03  eta: 5:25:06  time: 0.8181  data_time: 0.0078  memory: 4332  grad_norm: 1.9060  loss: 0.4968  loss_rpn_cls: 0.0411  loss_rpn_bbox: 0.0203  loss_cls: 0.2541  acc: 97.0703  loss_bbox: 0.1813
# 12/27 06:52:45 - mmengine - INFO - Epoch(train) [1][ 300/6164]  lr: 1.1992e-02  eta: 5:25:30  time: 0.8151  data_time: 0.0075  memory: 4333  grad_norm: 2.0907  loss: 0.4888  loss_rpn_cls: 0.0421  loss_rpn_bbox: 0.0201  loss_cls: 0.2491  acc: 97.2656  loss_bbox: 0.1775
# 12/27 06:53:26 - mmengine - INFO - Epoch(train) [1][ 350/6164]  lr: 1.3994e-02  eta: 5:25:47  time: 0.8182  data_time: 0.0081  memory: 4333  grad_norm: 1.7024  loss: 0.4877  loss_rpn_cls: 0.0323  loss_rpn_bbox: 0.0173  loss_cls: 0.2495  acc: 94.9219  loss_bbox: 0.1885
# 12/27 06:54:07 - mmengine - INFO - Epoch(train) [1][ 400/6164]  lr: 1.5996e-02  eta: 5:25:30  time: 0.8119  data_time: 0.0075  memory: 4333  grad_norm: 1.6614  loss: 0.4799  loss_rpn_cls: 0.0349  loss_rpn_bbox: 0.0164  loss_cls: 0.2464  acc: 92.0898  loss_bbox: 0.1822
# 12/27 06:54:47 - mmengine - INFO - Epoch(train) [1][ 450/6164]  lr: 1.7998e-02  eta: 5:24:41  time: 0.8018  data_time: 0.0079  memory: 4333  grad_norm: 2.0471  loss: 0.5350  loss_rpn_cls: 0.0338  loss_rpn_bbox: 0.0195  loss_cls: 0.2827  acc: 91.4551  loss_bbox: 0.1990
# 12/27 06:55:27 - mmengine - INFO - Epoch(train) [1][ 500/6164]  lr: 2.0000e-02  eta: 5:24:20  time: 0.8129  data_time: 0.0083  memory: 4333  grad_norm: 1.6089  loss: 0.4758  loss_rpn_cls: 0.0346  loss_rpn_bbox: 0.0195  loss_cls: 0.2390  acc: 96.1914  loss_bbox: 0.1826
# 12/27 06:56:08 - mmengine - INFO - Epoch(train) [1][ 550/6164]  lr: 2.0000e-02  eta: 5:23:42  time: 0.8067  data_time: 0.0079  memory: 4333  grad_norm: 2.1012  loss: 0.5490  loss_rpn_cls: 0.0443  loss_rpn_bbox: 0.0203  loss_cls: 0.2803  acc: 92.9199  loss_bbox: 0.2041
# 12/27 06:56:48 - mmengine - INFO - Epoch(train) [1][ 600/6164]  lr: 2.0000e-02  eta: 5:23:02  time: 0.8060  data_time: 0.0079  memory: 4333  grad_norm: 1.8141  loss: 0.4921  loss_rpn_cls: 0.0406  loss_rpn_bbox: 0.0210  loss_cls: 0.2539  acc: 96.3379  loss_bbox: 0.1766
# 12/27 06:57:29 - mmengine - INFO - Epoch(train) [1][ 650/6164]  lr: 2.0000e-02  eta: 5:22:33  time: 0.8119  data_time: 0.0077  memory: 4333  grad_norm: 1.6516  loss: 0.5126  loss_rpn_cls: 0.0369  loss_rpn_bbox: 0.0206  loss_cls: 0.2624  acc: 95.7520  loss_bbox: 0.1928
# 12/27 06:58:09 - mmengine - INFO - Epoch(train) [1][ 700/6164]  lr: 2.0000e-02  eta: 5:22:08  time: 0.8149  data_time: 0.0080  memory: 4333  grad_norm: 1.5560  loss: 0.5076  loss_rpn_cls: 0.0285  loss_rpn_bbox: 0.0204  loss_cls: 0.2539  acc: 95.3125  loss_bbox: 0.2048
# 12/27 06:58:50 - mmengine - INFO - Epoch(train) [1][ 750/6164]  lr: 2.0000e-02  eta: 5:21:28  time: 0.8072  data_time: 0.0079  memory: 4332  grad_norm: 1.9839  loss: 0.5425  loss_rpn_cls: 0.0322  loss_rpn_bbox: 0.0194  loss_cls: 0.2815  acc: 95.1660  loss_bbox: 0.2095
# 12/27 06:59:30 - mmengine - INFO - Epoch(train) [1][ 800/6164]  lr: 2.0000e-02  eta: 5:20:42  time: 0.8034  data_time: 0.0072  memory: 4333  grad_norm: 1.5371  loss: 0.4525  loss_rpn_cls: 0.0272  loss_rpn_bbox: 0.0177  loss_cls: 0.2264  acc: 95.4102  loss_bbox: 0.1813
# 12/27 07:00:10 - mmengine - INFO - Epoch(train) [1][ 850/6164]  lr: 2.0000e-02  eta: 5:20:06  time: 0.8091  data_time: 0.0081  memory: 4332  grad_norm: 1.5261  loss: 0.4529  loss_rpn_cls: 0.0231  loss_rpn_bbox: 0.0168  loss_cls: 0.2294  acc: 95.3125  loss_bbox: 0.1837
# 12/27 07:00:51 - mmengine - INFO - Epoch(train) [1][ 900/6164]  lr: 2.0000e-02  eta: 5:19:39  time: 0.8170  data_time: 0.0082  memory: 4333  grad_norm: 1.7014  loss: 0.4788  loss_rpn_cls: 0.0278  loss_rpn_bbox: 0.0178  loss_cls: 0.2458  acc: 89.6973  loss_bbox: 0.1874
# 12/27 07:01:32 - mmengine - INFO - Epoch(train) [1][ 950/6164]  lr: 2.0000e-02  eta: 5:18:58  time: 0.8068  data_time: 0.0075  memory: 4332  grad_norm: 1.3886  loss: 0.3934  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0156  loss_cls: 0.1951  acc: 93.7012  loss_bbox: 0.1654
# 12/27 07:02:12 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 07:02:12 - mmengine - INFO - Epoch(train) [1][1000/6164]  lr: 2.0000e-02  eta: 5:18:19  time: 0.8085  data_time: 0.0075  memory: 4333  grad_norm: 1.5532  loss: 0.4210  loss_rpn_cls: 0.0243  loss_rpn_bbox: 0.0162  loss_cls: 0.2070  acc: 96.4844  loss_bbox: 0.1735
# 12/27 07:02:52 - mmengine - INFO - Epoch(train) [1][1050/6164]  lr: 2.0000e-02  eta: 5:17:27  time: 0.7972  data_time: 0.0073  memory: 4332  grad_norm: 1.6962  loss: 0.4679  loss_rpn_cls: 0.0288  loss_rpn_bbox: 0.0178  loss_cls: 0.2370  acc: 95.3125  loss_bbox: 0.1844
# 12/27 07:03:32 - mmengine - INFO - Epoch(train) [1][1100/6164]  lr: 2.0000e-02  eta: 5:16:38  time: 0.7991  data_time: 0.0073  memory: 4332  grad_norm: 1.7139  loss: 0.4566  loss_rpn_cls: 0.0236  loss_rpn_bbox: 0.0170  loss_cls: 0.2303  acc: 96.0938  loss_bbox: 0.1857
# 12/27 07:04:12 - mmengine - INFO - Epoch(train) [1][1150/6164]  lr: 2.0000e-02  eta: 5:15:54  time: 0.8028  data_time: 0.0076  memory: 4333  grad_norm: 1.8483  loss: 0.4852  loss_rpn_cls: 0.0258  loss_rpn_bbox: 0.0167  loss_cls: 0.2431  acc: 94.6777  loss_bbox: 0.1996
# 12/27 07:04:52 - mmengine - INFO - Epoch(train) [1][1200/6164]  lr: 2.0000e-02  eta: 5:15:04  time: 0.7968  data_time: 0.0077  memory: 4332  grad_norm: 1.6841  loss: 0.4561  loss_rpn_cls: 0.0262  loss_rpn_bbox: 0.0149  loss_cls: 0.2364  acc: 95.6543  loss_bbox: 0.1786
# 12/27 07:05:32 - mmengine - INFO - Epoch(train) [1][1250/6164]  lr: 2.0000e-02  eta: 5:14:28  time: 0.8104  data_time: 0.0081  memory: 4333  grad_norm: 1.5944  loss: 0.4434  loss_rpn_cls: 0.0249  loss_rpn_bbox: 0.0170  loss_cls: 0.2216  acc: 94.5312  loss_bbox: 0.1799
# 12/27 07:06:13 - mmengine - INFO - Epoch(train) [1][1300/6164]  lr: 2.0000e-02  eta: 5:13:59  time: 0.8187  data_time: 0.0078  memory: 4333  grad_norm: 1.7899  loss: 0.4638  loss_rpn_cls: 0.0294  loss_rpn_bbox: 0.0189  loss_cls: 0.2264  acc: 95.1660  loss_bbox: 0.1891
# 12/27 07:06:54 - mmengine - INFO - Epoch(train) [1][1350/6164]  lr: 2.0000e-02  eta: 5:13:34  time: 0.8237  data_time: 0.0082  memory: 4333  grad_norm: 1.6789  loss: 0.4511  loss_rpn_cls: 0.0277  loss_rpn_bbox: 0.0171  loss_cls: 0.2264  acc: 98.3398  loss_bbox: 0.1798
# 12/27 07:07:35 - mmengine - INFO - Epoch(train) [1][1400/6164]  lr: 2.0000e-02  eta: 5:12:49  time: 0.8021  data_time: 0.0075  memory: 4333  grad_norm: 1.7015  loss: 0.4691  loss_rpn_cls: 0.0267  loss_rpn_bbox: 0.0200  loss_cls: 0.2408  acc: 95.9961  loss_bbox: 0.1816
# 12/27 07:08:15 - mmengine - INFO - Epoch(train) [1][1450/6164]  lr: 2.0000e-02  eta: 5:12:05  time: 0.8027  data_time: 0.0075  memory: 4333  grad_norm: 1.5773  loss: 0.4245  loss_rpn_cls: 0.0245  loss_rpn_bbox: 0.0164  loss_cls: 0.2049  acc: 90.9180  loss_bbox: 0.1788
# 12/27 07:08:55 - mmengine - INFO - Epoch(train) [1][1500/6164]  lr: 2.0000e-02  eta: 5:11:26  time: 0.8083  data_time: 0.0081  memory: 4333  grad_norm: 1.5208  loss: 0.4120  loss_rpn_cls: 0.0231  loss_rpn_bbox: 0.0166  loss_cls: 0.1934  acc: 93.8965  loss_bbox: 0.1789
# 12/27 07:09:36 - mmengine - INFO - Epoch(train) [1][1550/6164]  lr: 2.0000e-02  eta: 5:10:53  time: 0.8165  data_time: 0.0081  memory: 4333  grad_norm: 1.5961  loss: 0.4344  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0176  loss_cls: 0.2109  acc: 95.0195  loss_bbox: 0.1840
# 12/27 07:10:17 - mmengine - INFO - Epoch(train) [1][1600/6164]  lr: 2.0000e-02  eta: 5:10:20  time: 0.8182  data_time: 0.0083  memory: 4333  grad_norm: 1.6721  loss: 0.4597  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0181  loss_cls: 0.2275  acc: 95.8496  loss_bbox: 0.1921
# 12/27 07:10:58 - mmengine - INFO - Epoch(train) [1][1650/6164]  lr: 2.0000e-02  eta: 5:09:46  time: 0.8166  data_time: 0.0082  memory: 4333  grad_norm: 1.6848  loss: 0.5030  loss_rpn_cls: 0.0252  loss_rpn_bbox: 0.0202  loss_cls: 0.2442  acc: 94.9219  loss_bbox: 0.2134
# 12/27 07:11:38 - mmengine - INFO - Epoch(train) [1][1700/6164]  lr: 2.0000e-02  eta: 5:09:09  time: 0.8130  data_time: 0.0080  memory: 4333  grad_norm: 1.7006  loss: 0.4351  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0174  loss_cls: 0.2178  acc: 96.9727  loss_bbox: 0.1779
# 12/27 07:12:19 - mmengine - INFO - Epoch(train) [1][1750/6164]  lr: 2.0000e-02  eta: 5:08:32  time: 0.8140  data_time: 0.0084  memory: 4333  grad_norm: 1.6031  loss: 0.4337  loss_rpn_cls: 0.0240  loss_rpn_bbox: 0.0164  loss_cls: 0.2107  acc: 96.8750  loss_bbox: 0.1826
# 12/27 07:12:59 - mmengine - INFO - Epoch(train) [1][1800/6164]  lr: 2.0000e-02  eta: 5:07:51  time: 0.8069  data_time: 0.0074  memory: 4333  grad_norm: 1.5920  loss: 0.4177  loss_rpn_cls: 0.0238  loss_rpn_bbox: 0.0163  loss_cls: 0.2037  acc: 97.5098  loss_bbox: 0.1739
# 12/27 07:13:40 - mmengine - INFO - Epoch(train) [1][1850/6164]  lr: 2.0000e-02  eta: 5:07:19  time: 0.8208  data_time: 0.0079  memory: 4333  grad_norm: 1.7037  loss: 0.4380  loss_rpn_cls: 0.0214  loss_rpn_bbox: 0.0163  loss_cls: 0.2122  acc: 95.3613  loss_bbox: 0.1882
# 12/27 07:14:21 - mmengine - INFO - Epoch(train) [1][1900/6164]  lr: 2.0000e-02  eta: 5:06:39  time: 0.8092  data_time: 0.0083  memory: 4333  grad_norm: 1.5719  loss: 0.4301  loss_rpn_cls: 0.0233  loss_rpn_bbox: 0.0186  loss_cls: 0.2048  acc: 93.8477  loss_bbox: 0.1834
# 12/27 07:15:01 - mmengine - INFO - Epoch(train) [1][1950/6164]  lr: 2.0000e-02  eta: 5:05:59  time: 0.8100  data_time: 0.0082  memory: 4333  grad_norm: 1.4531  loss: 0.3920  loss_rpn_cls: 0.0195  loss_rpn_bbox: 0.0176  loss_cls: 0.1833  acc: 97.1191  loss_bbox: 0.1717
# 12/27 07:15:42 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 07:15:42 - mmengine - INFO - Epoch(train) [1][2000/6164]  lr: 2.0000e-02  eta: 5:05:25  time: 0.8197  data_time: 0.0080  memory: 4333  grad_norm: 1.5874  loss: 0.3928  loss_rpn_cls: 0.0206  loss_rpn_bbox: 0.0167  loss_cls: 0.1907  acc: 94.5801  loss_bbox: 0.1648
# 12/27 07:16:23 - mmengine - INFO - Epoch(train) [1][2050/6164]  lr: 2.0000e-02  eta: 5:04:42  time: 0.8048  data_time: 0.0075  memory: 4333  grad_norm: 1.5277  loss: 0.4127  loss_rpn_cls: 0.0212  loss_rpn_bbox: 0.0159  loss_cls: 0.1972  acc: 95.2148  loss_bbox: 0.1784
# 12/27 07:17:03 - mmengine - INFO - Epoch(train) [1][2100/6164]  lr: 2.0000e-02  eta: 5:04:06  time: 0.8174  data_time: 0.0074  memory: 4333  grad_norm: 1.4662  loss: 0.3974  loss_rpn_cls: 0.0186  loss_rpn_bbox: 0.0153  loss_cls: 0.1913  acc: 95.8496  loss_bbox: 0.1723
# 12/27 07:17:44 - mmengine - INFO - Epoch(train) [1][2150/6164]  lr: 2.0000e-02  eta: 5:03:28  time: 0.8122  data_time: 0.0076  memory: 4333  grad_norm: 1.6200  loss: 0.3947  loss_rpn_cls: 0.0207  loss_rpn_bbox: 0.0159  loss_cls: 0.1890  acc: 95.7520  loss_bbox: 0.1691
# 12/27 07:18:24 - mmengine - INFO - Epoch(train) [1][2200/6164]  lr: 2.0000e-02  eta: 5:02:47  time: 0.8087  data_time: 0.0075  memory: 4332  grad_norm: 1.5164  loss: 0.4152  loss_rpn_cls: 0.0215  loss_rpn_bbox: 0.0149  loss_cls: 0.1980  acc: 96.0938  loss_bbox: 0.1808
# 12/27 07:19:06 - mmengine - INFO - Epoch(train) [1][2250/6164]  lr: 2.0000e-02  eta: 5:02:15  time: 0.8269  data_time: 0.0082  memory: 4333  grad_norm: 1.6257  loss: 0.4281  loss_rpn_cls: 0.0194  loss_rpn_bbox: 0.0174  loss_cls: 0.2121  acc: 97.8516  loss_bbox: 0.1792
# 12/27 07:19:47 - mmengine - INFO - Epoch(train) [1][2300/6164]  lr: 2.0000e-02  eta: 5:01:41  time: 0.8212  data_time: 0.0080  memory: 4333  grad_norm: 1.6474  loss: 0.4524  loss_rpn_cls: 0.0186  loss_rpn_bbox: 0.0187  loss_cls: 0.2133  acc: 96.5820  loss_bbox: 0.2018
# 12/27 07:20:27 - mmengine - INFO - Epoch(train) [1][2350/6164]  lr: 2.0000e-02  eta: 5:01:01  time: 0.8105  data_time: 0.0079  memory: 4332  grad_norm: 1.6323  loss: 0.4035  loss_rpn_cls: 0.0236  loss_rpn_bbox: 0.0172  loss_cls: 0.1875  acc: 95.4590  loss_bbox: 0.1751
# 12/27 07:21:08 - mmengine - INFO - Epoch(train) [1][2400/6164]  lr: 2.0000e-02  eta: 5:00:23  time: 0.8164  data_time: 0.0077  memory: 4332  grad_norm: 1.5267  loss: 0.3771  loss_rpn_cls: 0.0232  loss_rpn_bbox: 0.0147  loss_cls: 0.1814  acc: 94.5801  loss_bbox: 0.1577
# 12/27 07:21:49 - mmengine - INFO - Epoch(train) [1][2450/6164]  lr: 2.0000e-02  eta: 4:59:46  time: 0.8176  data_time: 0.0078  memory: 4333  grad_norm: 1.4865  loss: 0.4002  loss_rpn_cls: 0.0180  loss_rpn_bbox: 0.0168  loss_cls: 0.1863  acc: 97.7539  loss_bbox: 0.1791
# 12/27 07:22:30 - mmengine - INFO - Epoch(train) [1][2500/6164]  lr: 2.0000e-02  eta: 4:59:05  time: 0.8078  data_time: 0.0079  memory: 4333  grad_norm: 1.6014  loss: 0.3806  loss_rpn_cls: 0.0195  loss_rpn_bbox: 0.0156  loss_cls: 0.1804  acc: 95.8984  loss_bbox: 0.1651
# 12/27 07:23:10 - mmengine - INFO - Epoch(train) [1][2550/6164]  lr: 2.0000e-02  eta: 4:58:28  time: 0.8189  data_time: 0.0078  memory: 4333  grad_norm: 1.6041  loss: 0.3899  loss_rpn_cls: 0.0192  loss_rpn_bbox: 0.0164  loss_cls: 0.1815  acc: 95.8984  loss_bbox: 0.1728
# 12/27 07:23:51 - mmengine - INFO - Epoch(train) [1][2600/6164]  lr: 2.0000e-02  eta: 4:57:47  time: 0.8091  data_time: 0.0082  memory: 4333  grad_norm: 1.6725  loss: 0.4380  loss_rpn_cls: 0.0242  loss_rpn_bbox: 0.0193  loss_cls: 0.2044  acc: 90.3320  loss_bbox: 0.1901
# 12/27 07:24:31 - mmengine - INFO - Epoch(train) [1][2650/6164]  lr: 2.0000e-02  eta: 4:57:05  time: 0.8068  data_time: 0.0081  memory: 4333  grad_norm: 1.7362  loss: 0.4237  loss_rpn_cls: 0.0245  loss_rpn_bbox: 0.0184  loss_cls: 0.2105  acc: 93.4570  loss_bbox: 0.1703
# 12/27 07:25:12 - mmengine - INFO - Epoch(train) [1][2700/6164]  lr: 2.0000e-02  eta: 4:56:27  time: 0.8155  data_time: 0.0077  memory: 4333  grad_norm: 1.5874  loss: 0.4147  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0177  loss_cls: 0.1970  acc: 92.2363  loss_bbox: 0.1779
# 12/27 07:25:52 - mmengine - INFO - Epoch(train) [1][2750/6164]  lr: 2.0000e-02  eta: 4:55:45  time: 0.8062  data_time: 0.0073  memory: 4333  grad_norm: 1.6294  loss: 0.4103  loss_rpn_cls: 0.0245  loss_rpn_bbox: 0.0182  loss_cls: 0.1921  acc: 95.8984  loss_bbox: 0.1754
# 12/27 07:26:33 - mmengine - INFO - Epoch(train) [1][2800/6164]  lr: 2.0000e-02  eta: 4:55:06  time: 0.8129  data_time: 0.0073  memory: 4333  grad_norm: 1.4298  loss: 0.3826  loss_rpn_cls: 0.0221  loss_rpn_bbox: 0.0163  loss_cls: 0.1820  acc: 95.5078  loss_bbox: 0.1622
# 12/27 07:27:13 - mmengine - INFO - Epoch(train) [1][2850/6164]  lr: 2.0000e-02  eta: 4:54:24  time: 0.8077  data_time: 0.0077  memory: 4333  grad_norm: 1.5273  loss: 0.4031  loss_rpn_cls: 0.0247  loss_rpn_bbox: 0.0193  loss_cls: 0.1832  acc: 94.1406  loss_bbox: 0.1758
# 12/27 07:27:55 - mmengine - INFO - Epoch(train) [1][2900/6164]  lr: 2.0000e-02  eta: 4:53:49  time: 0.8232  data_time: 0.0080  memory: 4333  grad_norm: 1.5494  loss: 0.4069  loss_rpn_cls: 0.0197  loss_rpn_bbox: 0.0179  loss_cls: 0.1895  acc: 94.6289  loss_bbox: 0.1798
# 12/27 07:28:36 - mmengine - INFO - Epoch(train) [1][2950/6164]  lr: 2.0000e-02  eta: 4:53:13  time: 0.8246  data_time: 0.0079  memory: 4333  grad_norm: 1.7105  loss: 0.4190  loss_rpn_cls: 0.0193  loss_rpn_bbox: 0.0167  loss_cls: 0.2007  acc: 96.6309  loss_bbox: 0.1824
# 12/27 07:29:16 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 07:29:16 - mmengine - INFO - Epoch(train) [1][3000/6164]  lr: 2.0000e-02  eta: 4:52:32  time: 0.8097  data_time: 0.0078  memory: 4333  grad_norm: 1.5649  loss: 0.3905  loss_rpn_cls: 0.0197  loss_rpn_bbox: 0.0154  loss_cls: 0.1847  acc: 98.4375  loss_bbox: 0.1706
# 12/27 07:29:57 - mmengine - INFO - Epoch(train) [1][3050/6164]  lr: 2.0000e-02  eta: 4:51:52  time: 0.8122  data_time: 0.0079  memory: 4333  grad_norm: 1.6263  loss: 0.3990  loss_rpn_cls: 0.0199  loss_rpn_bbox: 0.0161  loss_cls: 0.1909  acc: 94.2871  loss_bbox: 0.1722
# 12/27 07:30:37 - mmengine - INFO - Epoch(train) [1][3100/6164]  lr: 2.0000e-02  eta: 4:51:12  time: 0.8112  data_time: 0.0086  memory: 4333  grad_norm: 1.7050  loss: 0.4427  loss_rpn_cls: 0.0220  loss_rpn_bbox: 0.0171  loss_cls: 0.2145  acc: 94.4824  loss_bbox: 0.1891
# 12/27 07:31:18 - mmengine - INFO - Epoch(train) [1][3150/6164]  lr: 2.0000e-02  eta: 4:50:33  time: 0.8140  data_time: 0.0078  memory: 4333  grad_norm: 1.5540  loss: 0.3963  loss_rpn_cls: 0.0213  loss_rpn_bbox: 0.0173  loss_cls: 0.1832  acc: 96.6797  loss_bbox: 0.1745
# 12/27 07:31:59 - mmengine - INFO - Epoch(train) [1][3200/6164]  lr: 2.0000e-02  eta: 4:49:56  time: 0.8207  data_time: 0.0083  memory: 4333  grad_norm: 1.5080  loss: 0.3963  loss_rpn_cls: 0.0199  loss_rpn_bbox: 0.0193  loss_cls: 0.1804  acc: 95.2637  loss_bbox: 0.1767
# 12/27 07:32:40 - mmengine - INFO - Epoch(train) [1][3250/6164]  lr: 2.0000e-02  eta: 4:49:17  time: 0.8159  data_time: 0.0082  memory: 4332  grad_norm: 1.3537  loss: 0.3739  loss_rpn_cls: 0.0199  loss_rpn_bbox: 0.0163  loss_cls: 0.1725  acc: 96.9238  loss_bbox: 0.1652
# 12/27 07:33:21 - mmengine - INFO - Epoch(train) [1][3300/6164]  lr: 2.0000e-02  eta: 4:48:36  time: 0.8109  data_time: 0.0077  memory: 4333  grad_norm: 1.4833  loss: 0.3977  loss_rpn_cls: 0.0181  loss_rpn_bbox: 0.0179  loss_cls: 0.1756  acc: 92.8711  loss_bbox: 0.1861
# 12/27 07:34:01 - mmengine - INFO - Epoch(train) [1][3350/6164]  lr: 2.0000e-02  eta: 4:47:55  time: 0.8085  data_time: 0.0075  memory: 4333  grad_norm: 1.6138  loss: 0.4448  loss_rpn_cls: 0.0202  loss_rpn_bbox: 0.0191  loss_cls: 0.2083  acc: 91.8457  loss_bbox: 0.1972
# 12/27 07:34:41 - mmengine - INFO - Epoch(train) [1][3400/6164]  lr: 2.0000e-02  eta: 4:47:14  time: 0.8108  data_time: 0.0078  memory: 4333  grad_norm: 1.5040  loss: 0.4032  loss_rpn_cls: 0.0203  loss_rpn_bbox: 0.0174  loss_cls: 0.1908  acc: 92.6270  loss_bbox: 0.1748
# 12/27 07:35:22 - mmengine - INFO - Epoch(train) [1][3450/6164]  lr: 2.0000e-02  eta: 4:46:34  time: 0.8121  data_time: 0.0081  memory: 4333  grad_norm: 1.7109  loss: 0.4281  loss_rpn_cls: 0.0212  loss_rpn_bbox: 0.0173  loss_cls: 0.2017  acc: 91.6992  loss_bbox: 0.1878
# 12/27 07:36:03 - mmengine - INFO - Epoch(train) [1][3500/6164]  lr: 2.0000e-02  eta: 4:45:54  time: 0.8126  data_time: 0.0084  memory: 4333  grad_norm: 1.6820  loss: 0.3797  loss_rpn_cls: 0.0200  loss_rpn_bbox: 0.0152  loss_cls: 0.1788  acc: 93.9453  loss_bbox: 0.1658
# 12/27 07:36:43 - mmengine - INFO - Epoch(train) [1][3550/6164]  lr: 2.0000e-02  eta: 4:45:10  time: 0.7974  data_time: 0.0079  memory: 4333  grad_norm: 1.6995  loss: 0.3934  loss_rpn_cls: 0.0242  loss_rpn_bbox: 0.0161  loss_cls: 0.1904  acc: 96.3379  loss_bbox: 0.1627
# 12/27 07:37:23 - mmengine - INFO - Epoch(train) [1][3600/6164]  lr: 2.0000e-02  eta: 4:44:31  time: 0.8152  data_time: 0.0079  memory: 4333  grad_norm: 1.5420  loss: 0.3737  loss_rpn_cls: 0.0200  loss_rpn_bbox: 0.0153  loss_cls: 0.1765  acc: 94.7754  loss_bbox: 0.1619
# 12/27 07:38:03 - mmengine - INFO - Epoch(train) [1][3650/6164]  lr: 2.0000e-02  eta: 4:43:47  time: 0.8000  data_time: 0.0079  memory: 4332  grad_norm: 1.4608  loss: 0.3312  loss_rpn_cls: 0.0177  loss_rpn_bbox: 0.0144  loss_cls: 0.1511  acc: 96.8750  loss_bbox: 0.1480
# 12/27 07:38:43 - mmengine - INFO - Epoch(train) [1][3700/6164]  lr: 2.0000e-02  eta: 4:43:04  time: 0.8028  data_time: 0.0077  memory: 4333  grad_norm: 1.6709  loss: 0.4337  loss_rpn_cls: 0.0212  loss_rpn_bbox: 0.0191  loss_cls: 0.2024  acc: 91.0156  loss_bbox: 0.1909
# 12/27 07:39:24 - mmengine - INFO - Epoch(train) [1][3750/6164]  lr: 2.0000e-02  eta: 4:42:24  time: 0.8105  data_time: 0.0075  memory: 4333  grad_norm: 1.3907  loss: 0.3205  loss_rpn_cls: 0.0172  loss_rpn_bbox: 0.0138  loss_cls: 0.1449  acc: 93.9453  loss_bbox: 0.1447
# 12/27 07:40:05 - mmengine - INFO - Epoch(train) [1][3800/6164]  lr: 2.0000e-02  eta: 4:41:43  time: 0.8111  data_time: 0.0076  memory: 4333  grad_norm: 1.4848  loss: 0.3604  loss_rpn_cls: 0.0174  loss_rpn_bbox: 0.0148  loss_cls: 0.1643  acc: 96.5820  loss_bbox: 0.1638
# 12/27 07:40:45 - mmengine - INFO - Epoch(train) [1][3850/6164]  lr: 2.0000e-02  eta: 4:41:03  time: 0.8117  data_time: 0.0081  memory: 4333  grad_norm: 1.6306  loss: 0.4085  loss_rpn_cls: 0.0198  loss_rpn_bbox: 0.0179  loss_cls: 0.1897  acc: 96.3379  loss_bbox: 0.1812
# 12/27 07:41:26 - mmengine - INFO - Epoch(train) [1][3900/6164]  lr: 2.0000e-02  eta: 4:40:24  time: 0.8153  data_time: 0.0083  memory: 4333  grad_norm: 1.4506  loss: 0.3615  loss_rpn_cls: 0.0185  loss_rpn_bbox: 0.0157  loss_cls: 0.1590  acc: 93.6035  loss_bbox: 0.1683
# 12/27 07:42:06 - mmengine - INFO - Epoch(train) [1][3950/6164]  lr: 2.0000e-02  eta: 4:39:43  time: 0.8101  data_time: 0.0088  memory: 4333  grad_norm: 1.5083  loss: 0.3820  loss_rpn_cls: 0.0214  loss_rpn_bbox: 0.0180  loss_cls: 0.1765  acc: 94.9219  loss_bbox: 0.1661
# 12/27 07:42:47 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 07:42:47 - mmengine - INFO - Epoch(train) [1][4000/6164]  lr: 2.0000e-02  eta: 4:39:02  time: 0.8086  data_time: 0.0075  memory: 4333  grad_norm: 1.6416  loss: 0.4090  loss_rpn_cls: 0.0188  loss_rpn_bbox: 0.0187  loss_cls: 0.1816  acc: 97.5098  loss_bbox: 0.1899
# 12/27 07:43:27 - mmengine - INFO - Epoch(train) [1][4050/6164]  lr: 2.0000e-02  eta: 4:38:20  time: 0.8053  data_time: 0.0074  memory: 4333  grad_norm: 1.4408  loss: 0.3470  loss_rpn_cls: 0.0176  loss_rpn_bbox: 0.0153  loss_cls: 0.1557  acc: 97.0215  loss_bbox: 0.1584
# 12/27 07:44:07 - mmengine - INFO - Epoch(train) [1][4100/6164]  lr: 2.0000e-02  eta: 4:37:38  time: 0.8043  data_time: 0.0078  memory: 4333  grad_norm: 1.6522  loss: 0.3862  loss_rpn_cls: 0.0167  loss_rpn_bbox: 0.0156  loss_cls: 0.1807  acc: 95.8496  loss_bbox: 0.1733
# 12/27 07:44:48 - mmengine - INFO - Epoch(train) [1][4150/6164]  lr: 2.0000e-02  eta: 4:36:59  time: 0.8139  data_time: 0.0080  memory: 4333  grad_norm: 1.6414  loss: 0.3830  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0185  loss_cls: 0.1763  acc: 93.1641  loss_bbox: 0.1698
# 12/27 07:45:29 - mmengine - INFO - Epoch(train) [1][4200/6164]  lr: 2.0000e-02  eta: 4:36:19  time: 0.8165  data_time: 0.0079  memory: 4333  grad_norm: 1.5249  loss: 0.3694  loss_rpn_cls: 0.0166  loss_rpn_bbox: 0.0141  loss_cls: 0.1742  acc: 95.6543  loss_bbox: 0.1645
# 12/27 07:46:09 - mmengine - INFO - Epoch(train) [1][4250/6164]  lr: 2.0000e-02  eta: 4:35:39  time: 0.8089  data_time: 0.0078  memory: 4332  grad_norm: 1.5167  loss: 0.3859  loss_rpn_cls: 0.0209  loss_rpn_bbox: 0.0171  loss_cls: 0.1703  acc: 94.0918  loss_bbox: 0.1776
# 12/27 07:46:50 - mmengine - INFO - Epoch(train) [1][4300/6164]  lr: 2.0000e-02  eta: 4:35:00  time: 0.8188  data_time: 0.0074  memory: 4333  grad_norm: 1.6295  loss: 0.3889  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0162  loss_cls: 0.1802  acc: 91.9922  loss_bbox: 0.1741
# 12/27 07:47:30 - mmengine - INFO - Epoch(train) [1][4350/6164]  lr: 2.0000e-02  eta: 4:34:18  time: 0.8042  data_time: 0.0077  memory: 4333  grad_norm: 1.6649  loss: 0.3930  loss_rpn_cls: 0.0179  loss_rpn_bbox: 0.0175  loss_cls: 0.1792  acc: 95.6055  loss_bbox: 0.1785
# 12/27 07:48:11 - mmengine - INFO - Epoch(train) [1][4400/6164]  lr: 2.0000e-02  eta: 4:33:36  time: 0.8059  data_time: 0.0080  memory: 4333  grad_norm: 1.5112  loss: 0.3660  loss_rpn_cls: 0.0187  loss_rpn_bbox: 0.0152  loss_cls: 0.1677  acc: 95.5566  loss_bbox: 0.1643
# 12/27 07:48:52 - mmengine - INFO - Epoch(train) [1][4450/6164]  lr: 2.0000e-02  eta: 4:32:59  time: 0.8224  data_time: 0.0085  memory: 4333  grad_norm: 1.4523  loss: 0.3771  loss_rpn_cls: 0.0196  loss_rpn_bbox: 0.0177  loss_cls: 0.1705  acc: 97.1680  loss_bbox: 0.1693
# 12/27 07:49:33 - mmengine - INFO - Epoch(train) [1][4500/6164]  lr: 2.0000e-02  eta: 4:32:20  time: 0.8174  data_time: 0.0076  memory: 4333  grad_norm: 1.6086  loss: 0.3579  loss_rpn_cls: 0.0185  loss_rpn_bbox: 0.0162  loss_cls: 0.1624  acc: 96.2402  loss_bbox: 0.1608
# 12/27 07:50:14 - mmengine - INFO - Epoch(train) [1][4550/6164]  lr: 2.0000e-02  eta: 4:31:43  time: 0.8296  data_time: 0.0082  memory: 4333  grad_norm: 1.7559  loss: 0.4241  loss_rpn_cls: 0.0191  loss_rpn_bbox: 0.0173  loss_cls: 0.2008  acc: 97.2168  loss_bbox: 0.1870
# 12/27 07:50:55 - mmengine - INFO - Epoch(train) [1][4600/6164]  lr: 2.0000e-02  eta: 4:31:03  time: 0.8115  data_time: 0.0082  memory: 4333  grad_norm: 1.4286  loss: 0.3397  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0162  loss_cls: 0.1489  acc: 97.1191  loss_bbox: 0.1584
# 12/27 07:51:35 - mmengine - INFO - Epoch(train) [1][4650/6164]  lr: 2.0000e-02  eta: 4:30:22  time: 0.8105  data_time: 0.0084  memory: 4333  grad_norm: 1.5401  loss: 0.3403  loss_rpn_cls: 0.0145  loss_rpn_bbox: 0.0151  loss_cls: 0.1539  acc: 96.1914  loss_bbox: 0.1568
# 12/27 07:52:16 - mmengine - INFO - Epoch(train) [1][4700/6164]  lr: 2.0000e-02  eta: 4:29:41  time: 0.8056  data_time: 0.0082  memory: 4333  grad_norm: 1.6087  loss: 0.3860  loss_rpn_cls: 0.0161  loss_rpn_bbox: 0.0163  loss_cls: 0.1761  acc: 95.8984  loss_bbox: 0.1774
# 12/27 07:52:56 - mmengine - INFO - Epoch(train) [1][4750/6164]  lr: 2.0000e-02  eta: 4:29:01  time: 0.8162  data_time: 0.0080  memory: 4333  grad_norm: 1.6321  loss: 0.3877  loss_rpn_cls: 0.0169  loss_rpn_bbox: 0.0175  loss_cls: 0.1811  acc: 95.4590  loss_bbox: 0.1722
# 12/27 07:53:37 - mmengine - INFO - Epoch(train) [1][4800/6164]  lr: 2.0000e-02  eta: 4:28:20  time: 0.8061  data_time: 0.0073  memory: 4333  grad_norm: 1.5402  loss: 0.3505  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0125  loss_cls: 0.1673  acc: 90.6250  loss_bbox: 0.1557
# 12/27 07:54:18 - mmengine - INFO - Epoch(train) [1][4850/6164]  lr: 2.0000e-02  eta: 4:27:40  time: 0.8164  data_time: 0.0080  memory: 4333  grad_norm: 1.5488  loss: 0.3879  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0155  loss_cls: 0.1767  acc: 93.3105  loss_bbox: 0.1775
# 12/27 07:54:59 - mmengine - INFO - Epoch(train) [1][4900/6164]  lr: 2.0000e-02  eta: 4:27:02  time: 0.8220  data_time: 0.0087  memory: 4333  grad_norm: 1.5934  loss: 0.3718  loss_rpn_cls: 0.0171  loss_rpn_bbox: 0.0154  loss_cls: 0.1734  acc: 93.7988  loss_bbox: 0.1659
# 12/27 07:55:39 - mmengine - INFO - Epoch(train) [1][4950/6164]  lr: 2.0000e-02  eta: 4:26:21  time: 0.8097  data_time: 0.0082  memory: 4333  grad_norm: 1.4885  loss: 0.3485  loss_rpn_cls: 0.0179  loss_rpn_bbox: 0.0147  loss_cls: 0.1597  acc: 95.5078  loss_bbox: 0.1563
# 12/27 07:56:20 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 07:56:20 - mmengine - INFO - Epoch(train) [1][5000/6164]  lr: 2.0000e-02  eta: 4:25:40  time: 0.8105  data_time: 0.0083  memory: 4333  grad_norm: 1.5735  loss: 0.3692  loss_rpn_cls: 0.0170  loss_rpn_bbox: 0.0159  loss_cls: 0.1657  acc: 92.8711  loss_bbox: 0.1707
# 12/27 07:57:00 - mmengine - INFO - Epoch(train) [1][5050/6164]  lr: 2.0000e-02  eta: 4:25:00  time: 0.8112  data_time: 0.0083  memory: 4333  grad_norm: 1.5755  loss: 0.3863  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0156  loss_cls: 0.1801  acc: 94.9707  loss_bbox: 0.1722
# 12/27 07:57:41 - mmengine - INFO - Epoch(train) [1][5100/6164]  lr: 2.0000e-02  eta: 4:24:19  time: 0.8091  data_time: 0.0077  memory: 4333  grad_norm: 1.5608  loss: 0.3761  loss_rpn_cls: 0.0171  loss_rpn_bbox: 0.0164  loss_cls: 0.1705  acc: 96.4355  loss_bbox: 0.1720
# 12/27 07:58:21 - mmengine - INFO - Epoch(train) [1][5150/6164]  lr: 2.0000e-02  eta: 4:23:37  time: 0.8040  data_time: 0.0075  memory: 4332  grad_norm: 1.4825  loss: 0.3531  loss_rpn_cls: 0.0169  loss_rpn_bbox: 0.0153  loss_cls: 0.1579  acc: 96.7773  loss_bbox: 0.1630
# 12/27 07:59:01 - mmengine - INFO - Epoch(train) [1][5200/6164]  lr: 2.0000e-02  eta: 4:22:57  time: 0.8115  data_time: 0.0081  memory: 4333  grad_norm: 1.4362  loss: 0.3256  loss_rpn_cls: 0.0152  loss_rpn_bbox: 0.0156  loss_cls: 0.1445  acc: 93.4570  loss_bbox: 0.1503
# 12/27 07:59:42 - mmengine - INFO - Epoch(train) [1][5250/6164]  lr: 2.0000e-02  eta: 4:22:16  time: 0.8080  data_time: 0.0084  memory: 4333  grad_norm: 1.6389  loss: 0.3818  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0165  loss_cls: 0.1697  acc: 95.5078  loss_bbox: 0.1794
# 12/27 08:00:22 - mmengine - INFO - Epoch(train) [1][5300/6164]  lr: 2.0000e-02  eta: 4:21:35  time: 0.8104  data_time: 0.0077  memory: 4333  grad_norm: 1.6723  loss: 0.3700  loss_rpn_cls: 0.0146  loss_rpn_bbox: 0.0151  loss_cls: 0.1719  acc: 94.9707  loss_bbox: 0.1685
# 12/27 08:01:03 - mmengine - INFO - Epoch(train) [1][5350/6164]  lr: 2.0000e-02  eta: 4:20:56  time: 0.8212  data_time: 0.0074  memory: 4333  grad_norm: 1.5862  loss: 0.3604  loss_rpn_cls: 0.0162  loss_rpn_bbox: 0.0157  loss_cls: 0.1660  acc: 95.9473  loss_bbox: 0.1625
# 12/27 08:01:43 - mmengine - INFO - Epoch(train) [1][5400/6164]  lr: 2.0000e-02  eta: 4:20:14  time: 0.8011  data_time: 0.0082  memory: 4333  grad_norm: 1.7025  loss: 0.3764  loss_rpn_cls: 0.0151  loss_rpn_bbox: 0.0155  loss_cls: 0.1715  acc: 99.2188  loss_bbox: 0.1743
# 12/27 08:02:24 - mmengine - INFO - Epoch(train) [1][5450/6164]  lr: 2.0000e-02  eta: 4:19:33  time: 0.8094  data_time: 0.0078  memory: 4332  grad_norm: 1.7265  loss: 0.3944  loss_rpn_cls: 0.0164  loss_rpn_bbox: 0.0161  loss_cls: 0.1815  acc: 95.3613  loss_bbox: 0.1804
# 12/27 08:03:05 - mmengine - INFO - Epoch(train) [1][5500/6164]  lr: 2.0000e-02  eta: 4:18:55  time: 0.8237  data_time: 0.0077  memory: 4333  grad_norm: 1.6307  loss: 0.3726  loss_rpn_cls: 0.0197  loss_rpn_bbox: 0.0162  loss_cls: 0.1657  acc: 96.0449  loss_bbox: 0.1710
# 12/27 08:03:46 - mmengine - INFO - Epoch(train) [1][5550/6164]  lr: 2.0000e-02  eta: 4:18:15  time: 0.8128  data_time: 0.0079  memory: 4333  grad_norm: 1.5123  loss: 0.3392  loss_rpn_cls: 0.0163  loss_rpn_bbox: 0.0141  loss_cls: 0.1523  acc: 90.4297  loss_bbox: 0.1565
# 12/27 08:04:26 - mmengine - INFO - Epoch(train) [1][5600/6164]  lr: 2.0000e-02  eta: 4:17:34  time: 0.8117  data_time: 0.0079  memory: 4332  grad_norm: 1.4473  loss: 0.3447  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0157  loss_cls: 0.1512  acc: 97.0703  loss_bbox: 0.1596
# ...
# 12/27 12:39:02 - mmengine - INFO - Epoch(train) [4][5850/6164]  lr: 2.0000e-02  eta: 0:04:15  time: 0.8218  data_time: 0.0083  memory: 4333  grad_norm: 1.7974  loss: 0.2740  loss_rpn_cls: 0.0086  loss_rpn_bbox: 0.0113  loss_cls: 0.1211  acc: 96.2402  loss_bbox: 0.1330
# 12/27 12:39:42 - mmengine - INFO - Epoch(train) [4][5900/6164]  lr: 2.0000e-02  eta: 0:03:34  time: 0.7981  data_time: 0.0085  memory: 4333  grad_norm: 1.5604  loss: 0.2588  loss_rpn_cls: 0.0067  loss_rpn_bbox: 0.0114  loss_cls: 0.1042  acc: 97.5586  loss_bbox: 0.1364
# 12/27 12:40:23 - mmengine - INFO - Epoch(train) [4][5950/6164]  lr: 2.0000e-02  eta: 0:02:54  time: 0.8135  data_time: 0.0084  memory: 4332  grad_norm: 1.5563  loss: 0.2721  loss_rpn_cls: 0.0069  loss_rpn_bbox: 0.0118  loss_cls: 0.1043  acc: 97.3633  loss_bbox: 0.1491
# 12/27 12:41:03 - mmengine - INFO - Epoch(train) [4][6000/6164]  lr: 2.0000e-02  eta: 0:02:13  time: 0.8041  data_time: 0.0075  memory: 4333  grad_norm: 1.6562  loss: 0.2729  loss_rpn_cls: 0.0075  loss_rpn_bbox: 0.0124  loss_cls: 0.1081  acc: 96.5820  loss_bbox: 0.1449
# 12/27 12:41:44 - mmengine - INFO - Epoch(train) [4][6050/6164]  lr: 2.0000e-02  eta: 0:01:32  time: 0.8187  data_time: 0.0089  memory: 4333  grad_norm: 1.8530  loss: 0.3090  loss_rpn_cls: 0.0094  loss_rpn_bbox: 0.0139  loss_cls: 0.1260  acc: 98.2910  loss_bbox: 0.1596
# 12/27 12:42:25 - mmengine - INFO - Epoch(train) [4][6100/6164]  lr: 2.0000e-02  eta: 0:00:52  time: 0.8189  data_time: 0.0082  memory: 4333  grad_norm: 1.5743  loss: 0.2765  loss_rpn_cls: 0.0082  loss_rpn_bbox: 0.0126  loss_cls: 0.1092  acc: 98.0469  loss_bbox: 0.1466
# 12/27 12:43:06 - mmengine - INFO - Epoch(train) [4][6150/6164]  lr: 2.0000e-02  eta: 0:00:11  time: 0.8171  data_time: 0.0078  memory: 4333  grad_norm: 1.8336  loss: 0.2854  loss_rpn_cls: 0.0082  loss_rpn_bbox: 0.0120  loss_cls: 0.1193  acc: 95.9961  loss_bbox: 0.1459
# 12/27 12:43:17 - mmengine - INFO - Exp name: faster-rcnn_r50_fpn_1x_voc0712_20251227_064643
# 12/27 12:43:17 - mmengine - INFO - Saving checkpoint at 4 epochs
# 12/27 12:43:22 - mmengine - INFO - Epoch(val) [4][  50/4952]    eta: 0:06:36  time: 0.0808  data_time: 0.0027  memory: 4436
# 12/27 12:43:26 - mmengine - INFO - Epoch(val) [4][ 100/4952]    eta: 0:06:31  time: 0.0804  data_time: 0.0022  memory: 691
# 12/27 12:43:30 - mmengine - INFO - Epoch(val) [4][ 150/4952]    eta: 0:06:27  time: 0.0811  data_time: 0.0021  memory: 680
# 12/27 12:43:34 - mmengine - INFO - Epoch(val) [4][ 200/4952]    eta: 0:06:23  time: 0.0807  data_time: 0.0022  memory: 672
# 12/27 12:43:38 - mmengine - INFO - Epoch(val) [4][ 250/4952]    eta: 0:06:19  time: 0.0809  data_time: 0.0022  memory: 691
# 12/27 12:43:42 - mmengine - INFO - Epoch(val) [4][ 300/4952]    eta: 0:06:14  time: 0.0791  data_time: 0.0023  memory: 684
# 12/27 12:43:46 - mmengine - INFO - Epoch(val) [4][ 350/4952]    eta: 0:06:10  time: 0.0802  data_time: 0.0024  memory: 691
# 12/27 12:43:50 - mmengine - INFO - Epoch(val) [4][ 400/4952]    eta: 0:06:06  time: 0.0817  data_time: 0.0025  memory: 691
# 12/27 12:43:54 - mmengine - INFO - Epoch(val) [4][ 450/4952]    eta: 0:06:03  time: 0.0817  data_time: 0.0023  memory: 680
# 12/27 12:43:58 - mmengine - INFO - Epoch(val) [4][ 500/4952]    eta: 0:05:59  time: 0.0801  data_time: 0.0027  memory: 680
# 12/27 12:44:02 - mmengine - INFO - Epoch(val) [4][ 550/4952]    eta: 0:05:54  time: 0.0799  data_time: 0.0020  memory: 684
# 12/27 12:44:06 - mmengine - INFO - Epoch(val) [4][ 600/4952]    eta: 0:05:51  time: 0.0815  data_time: 0.0022  memory: 680
# 12/27 12:44:10 - mmengine - INFO - Epoch(val) [4][ 650/4952]    eta: 0:05:46  time: 0.0802  data_time: 0.0022  memory: 684
# 12/27 12:44:14 - mmengine - INFO - Epoch(val) [4][ 700/4952]    eta: 0:05:43  time: 0.0814  data_time: 0.0023  memory: 680
# 12/27 12:44:19 - mmengine - INFO - Epoch(val) [4][ 750/4952]    eta: 0:05:39  time: 0.0817  data_time: 0.0024  memory: 684
# 12/27 12:44:23 - mmengine - INFO - Epoch(val) [4][ 800/4952]    eta: 0:05:35  time: 0.0799  data_time: 0.0022  memory: 680
# 12/27 12:44:27 - mmengine - INFO - Epoch(val) [4][ 850/4952]    eta: 0:05:31  time: 0.0813  data_time: 0.0023  memory: 680
# 12/27 12:44:31 - mmengine - INFO - Epoch(val) [4][ 900/4952]    eta: 0:05:27  time: 0.0807  data_time: 0.0022  memory: 691
# 12/27 12:44:35 - mmengine - INFO - Epoch(val) [4][ 950/4952]    eta: 0:05:23  time: 0.0808  data_time: 0.0023  memory: 684
# 12/27 12:44:39 - mmengine - INFO - Epoch(val) [4][1000/4952]    eta: 0:05:19  time: 0.0811  data_time: 0.0023  memory: 691
# 12/27 12:44:43 - mmengine - INFO - Epoch(val) [4][1050/4952]    eta: 0:05:15  time: 0.0805  data_time: 0.0021  memory: 691
# 12/27 12:44:47 - mmengine - INFO - Epoch(val) [4][1100/4952]    eta: 0:05:11  time: 0.0807  data_time: 0.0021  memory: 680
# 12/27 12:44:51 - mmengine - INFO - Epoch(val) [4][1150/4952]    eta: 0:05:07  time: 0.0813  data_time: 0.0023  memory: 691
# 12/27 12:44:55 - mmengine - INFO - Epoch(val) [4][1200/4952]    eta: 0:05:02  time: 0.0805  data_time: 0.0023  memory: 684
# 12/27 12:44:59 - mmengine - INFO - Epoch(val) [4][1250/4952]    eta: 0:04:58  time: 0.0805  data_time: 0.0023  memory: 680
# 12/27 12:45:03 - mmengine - INFO - Epoch(val) [4][1300/4952]    eta: 0:04:54  time: 0.0805  data_time: 0.0021  memory: 680
# 12/27 12:45:07 - mmengine - INFO - Epoch(val) [4][1350/4952]    eta: 0:04:50  time: 0.0799  data_time: 0.0021  memory: 691
# 12/27 12:45:11 - mmengine - INFO - Epoch(val) [4][1400/4952]    eta: 0:04:46  time: 0.0798  data_time: 0.0021  memory: 680
# 12/27 12:45:15 - mmengine - INFO - Epoch(val) [4][1450/4952]    eta: 0:04:42  time: 0.0811  data_time: 0.0022  memory: 691
# 12/27 12:45:19 - mmengine - INFO - Epoch(val) [4][1500/4952]    eta: 0:04:38  time: 0.0818  data_time: 0.0022  memory: 684
# 12/27 12:45:23 - mmengine - INFO - Epoch(val) [4][1550/4952]    eta: 0:04:34  time: 0.0807  data_time: 0.0022  memory: 680
# 12/27 12:45:27 - mmengine - INFO - Epoch(val) [4][1600/4952]    eta: 0:04:30  time: 0.0812  data_time: 0.0025  memory: 691
# 12/27 12:45:31 - mmengine - INFO - Epoch(val) [4][1650/4952]    eta: 0:04:26  time: 0.0804  data_time: 0.0024  memory: 680
# 12/27 12:45:35 - mmengine - INFO - Epoch(val) [4][1700/4952]    eta: 0:04:22  time: 0.0800  data_time: 0.0021  memory: 680
# 12/27 12:45:39 - mmengine - INFO - Epoch(val) [4][1750/4952]    eta: 0:04:18  time: 0.0815  data_time: 0.0022  memory: 672
# 12/27 12:45:43 - mmengine - INFO - Epoch(val) [4][1800/4952]    eta: 0:04:14  time: 0.0798  data_time: 0.0021  memory: 672
# 12/27 12:45:47 - mmengine - INFO - Epoch(val) [4][1850/4952]    eta: 0:04:10  time: 0.0799  data_time: 0.0022  memory: 672
# 12/27 12:45:51 - mmengine - INFO - Epoch(val) [4][1900/4952]    eta: 0:04:06  time: 0.0799  data_time: 0.0025  memory: 680
# 12/27 12:45:55 - mmengine - INFO - Epoch(val) [4][1950/4952]    eta: 0:04:02  time: 0.0806  data_time: 0.0023  memory: 684
# 12/27 12:45:59 - mmengine - INFO - Epoch(val) [4][2000/4952]    eta: 0:03:58  time: 0.0799  data_time: 0.0022  memory: 680
# 12/27 12:46:03 - mmengine - INFO - Epoch(val) [4][2050/4952]    eta: 0:03:54  time: 0.0807  data_time: 0.0023  memory: 691
# 12/27 12:46:07 - mmengine - INFO - Epoch(val) [4][2100/4952]    eta: 0:03:50  time: 0.0812  data_time: 0.0023  memory: 680
# 12/27 12:46:11 - mmengine - INFO - Epoch(val) [4][2150/4952]    eta: 0:03:45  time: 0.0796  data_time: 0.0023  memory: 684
# 12/27 12:46:15 - mmengine - INFO - Epoch(val) [4][2200/4952]    eta: 0:03:41  time: 0.0811  data_time: 0.0023  memory: 680
# 12/27 12:46:20 - mmengine - INFO - Epoch(val) [4][2250/4952]    eta: 0:03:37  time: 0.0802  data_time: 0.0022  memory: 691
# 12/27 12:46:24 - mmengine - INFO - Epoch(val) [4][2300/4952]    eta: 0:03:33  time: 0.0804  data_time: 0.0022  memory: 680
# 12/27 12:46:28 - mmengine - INFO - Epoch(val) [4][2350/4952]    eta: 0:03:29  time: 0.0799  data_time: 0.0021  memory: 680
# 12/27 12:46:32 - mmengine - INFO - Epoch(val) [4][2400/4952]    eta: 0:03:25  time: 0.0807  data_time: 0.0021  memory: 680
# 12/27 12:46:36 - mmengine - INFO - Epoch(val) [4][2450/4952]    eta: 0:03:21  time: 0.0803  data_time: 0.0020  memory: 680
# 12/27 12:46:40 - mmengine - INFO - Epoch(val) [4][2500/4952]    eta: 0:03:17  time: 0.0808  data_time: 0.0021  memory: 691
# 12/27 12:46:44 - mmengine - INFO - Epoch(val) [4][2550/4952]    eta: 0:03:13  time: 0.0805  data_time: 0.0023  memory: 672
# 12/27 12:46:48 - mmengine - INFO - Epoch(val) [4][2600/4952]    eta: 0:03:09  time: 0.0801  data_time: 0.0021  memory: 684
# 12/27 12:46:52 - mmengine - INFO - Epoch(val) [4][2650/4952]    eta: 0:03:05  time: 0.0817  data_time: 0.0021  memory: 684
# 12/27 12:46:56 - mmengine - INFO - Epoch(val) [4][2700/4952]    eta: 0:03:01  time: 0.0812  data_time: 0.0023  memory: 691
# 12/27 12:47:00 - mmengine - INFO - Epoch(val) [4][2750/4952]    eta: 0:02:57  time: 0.0813  data_time: 0.0021  memory: 680
# 12/27 12:47:04 - mmengine - INFO - Epoch(val) [4][2800/4952]    eta: 0:02:53  time: 0.0797  data_time: 0.0023  memory: 680
# 12/27 12:47:08 - mmengine - INFO - Epoch(val) [4][2850/4952]    eta: 0:02:49  time: 0.0808  data_time: 0.0027  memory: 680
# 12/27 12:47:12 - mmengine - INFO - Epoch(val) [4][2900/4952]    eta: 0:02:45  time: 0.0788  data_time: 0.0025  memory: 684
# 12/27 12:47:16 - mmengine - INFO - Epoch(val) [4][2950/4952]    eta: 0:02:41  time: 0.0803  data_time: 0.0022  memory: 691
# 12/27 12:47:20 - mmengine - INFO - Epoch(val) [4][3000/4952]    eta: 0:02:37  time: 0.0810  data_time: 0.0024  memory: 672
# 12/27 12:47:24 - mmengine - INFO - Epoch(val) [4][3050/4952]    eta: 0:02:33  time: 0.0795  data_time: 0.0022  memory: 680
# 12/27 12:47:28 - mmengine - INFO - Epoch(val) [4][3100/4952]    eta: 0:02:29  time: 0.0810  data_time: 0.0021  memory: 691
# 12/27 12:47:32 - mmengine - INFO - Epoch(val) [4][3150/4952]    eta: 0:02:25  time: 0.0804  data_time: 0.0023  memory: 680
# 12/27 12:47:36 - mmengine - INFO - Epoch(val) [4][3200/4952]    eta: 0:02:21  time: 0.0814  data_time: 0.0023  memory: 680
# 12/27 12:47:40 - mmengine - INFO - Epoch(val) [4][3250/4952]    eta: 0:02:17  time: 0.0797  data_time: 0.0023  memory: 680
# 12/27 12:47:44 - mmengine - INFO - Epoch(val) [4][3300/4952]    eta: 0:02:13  time: 0.0802  data_time: 0.0021  memory: 680
# 12/27 12:47:48 - mmengine - INFO - Epoch(val) [4][3350/4952]    eta: 0:02:09  time: 0.0808  data_time: 0.0020  memory: 680
# 12/27 12:47:52 - mmengine - INFO - Epoch(val) [4][3400/4952]    eta: 0:02:05  time: 0.0805  data_time: 0.0023  memory: 691
# 12/27 12:47:56 - mmengine - INFO - Epoch(val) [4][3450/4952]    eta: 0:02:00  time: 0.0792  data_time: 0.0023  memory: 680
# 12/27 12:48:00 - mmengine - INFO - Epoch(val) [4][3500/4952]    eta: 0:01:56  time: 0.0814  data_time: 0.0023  memory: 680
# 12/27 12:48:04 - mmengine - INFO - Epoch(val) [4][3550/4952]    eta: 0:01:52  time: 0.0807  data_time: 0.0023  memory: 672
# 12/27 12:48:08 - mmengine - INFO - Epoch(val) [4][3600/4952]    eta: 0:01:48  time: 0.0815  data_time: 0.0022  memory: 691
# 12/27 12:48:12 - mmengine - INFO - Epoch(val) [4][3650/4952]    eta: 0:01:44  time: 0.0805  data_time: 0.0024  memory: 691
# 12/27 12:48:16 - mmengine - INFO - Epoch(val) [4][3700/4952]    eta: 0:01:40  time: 0.0807  data_time: 0.0023  memory: 672
# 12/27 12:48:20 - mmengine - INFO - Epoch(val) [4][3750/4952]    eta: 0:01:36  time: 0.0793  data_time: 0.0022  memory: 680
# 12/27 12:48:24 - mmengine - INFO - Epoch(val) [4][3800/4952]    eta: 0:01:32  time: 0.0800  data_time: 0.0021  memory: 680
# 12/27 12:48:28 - mmengine - INFO - Epoch(val) [4][3850/4952]    eta: 0:01:28  time: 0.0802  data_time: 0.0022  memory: 680
# 12/27 12:48:33 - mmengine - INFO - Epoch(val) [4][3900/4952]    eta: 0:01:24  time: 0.0834  data_time: 0.0024  memory: 680
# 12/27 12:48:37 - mmengine - INFO - Epoch(val) [4][3950/4952]    eta: 0:01:20  time: 0.0805  data_time: 0.0023  memory: 680
# 12/27 12:48:41 - mmengine - INFO - Epoch(val) [4][4000/4952]    eta: 0:01:16  time: 0.0817  data_time: 0.0024  memory: 691
# 12/27 12:48:45 - mmengine - INFO - Epoch(val) [4][4050/4952]    eta: 0:01:12  time: 0.0818  data_time: 0.0024  memory: 684
# 12/27 12:48:49 - mmengine - INFO - Epoch(val) [4][4100/4952]    eta: 0:01:08  time: 0.0798  data_time: 0.0024  memory: 691
# 12/27 12:48:53 - mmengine - INFO - Epoch(val) [4][4150/4952]    eta: 0:01:04  time: 0.0801  data_time: 0.0022  memory: 691
# 12/27 12:48:57 - mmengine - INFO - Epoch(val) [4][4200/4952]    eta: 0:01:00  time: 0.0795  data_time: 0.0023  memory: 672
# 12/27 12:49:01 - mmengine - INFO - Epoch(val) [4][4250/4952]    eta: 0:00:56  time: 0.0809  data_time: 0.0023  memory: 691
# 12/27 12:49:05 - mmengine - INFO - Epoch(val) [4][4300/4952]    eta: 0:00:52  time: 0.0816  data_time: 0.0022  memory: 684
# 12/27 12:49:09 - mmengine - INFO - Epoch(val) [4][4350/4952]    eta: 0:00:48  time: 0.0812  data_time: 0.0021  memory: 691
# 12/27 12:49:13 - mmengine - INFO - Epoch(val) [4][4400/4952]    eta: 0:00:44  time: 0.0805  data_time: 0.0022  memory: 680
# 12/27 12:49:17 - mmengine - INFO - Epoch(val) [4][4450/4952]    eta: 0:00:40  time: 0.0801  data_time: 0.0024  memory: 680
# 12/27 12:49:21 - mmengine - INFO - Epoch(val) [4][4500/4952]    eta: 0:00:36  time: 0.0807  data_time: 0.0023  memory: 680
# 12/27 12:49:25 - mmengine - INFO - Epoch(val) [4][4550/4952]    eta: 0:00:32  time: 0.0810  data_time: 0.0022  memory: 684
# 12/27 12:49:29 - mmengine - INFO - Epoch(val) [4][4600/4952]    eta: 0:00:28  time: 0.0791  data_time: 0.0023  memory: 672
# 12/27 12:49:33 - mmengine - INFO - Epoch(val) [4][4650/4952]    eta: 0:00:24  time: 0.0798  data_time: 0.0021  memory: 680
# 12/27 12:49:37 - mmengine - INFO - Epoch(val) [4][4700/4952]    eta: 0:00:20  time: 0.0813  data_time: 0.0023  memory: 691
# 12/27 12:49:41 - mmengine - INFO - Epoch(val) [4][4750/4952]    eta: 0:00:16  time: 0.0806  data_time: 0.0027  memory: 680
# 12/27 12:49:45 - mmengine - INFO - Epoch(val) [4][4800/4952]    eta: 0:00:12  time: 0.0806  data_time: 0.0023  memory: 672
# 12/27 12:49:49 - mmengine - INFO - Epoch(val) [4][4850/4952]    eta: 0:00:08  time: 0.0809  data_time: 0.0022  memory: 684
# 12/27 12:49:53 - mmengine - INFO - Epoch(val) [4][4900/4952]    eta: 0:00:04  time: 0.0807  data_time: 0.0025  memory: 680
# 12/27 12:49:57 - mmengine - INFO - Epoch(val) [4][4950/4952]    eta: 0:00:00  time: 0.0815  data_time: 0.0024  memory: 684
# 12/27 12:49:57 - mmengine - INFO -
# ---------------iou_thr: 0.5---------------
# 12/27 12:50:01 - mmengine - INFO -
# +-------------+------+-------+--------+-------+
# | class       | gts  | dets  | recall | ap    |
# +-------------+------+-------+--------+-------+
# | aeroplane   | 285  | 1624  | 0.723  | 0.555 |
# | bicycle     | 337  | 1131  | 0.855  | 0.733 |
# | bird        | 459  | 6056  | 0.839  | 0.518 |
# | boat        | 263  | 2807  | 0.745  | 0.470 |
# | bottle      | 469  | 3453  | 0.595  | 0.421 |
# | bus         | 213  | 1978  | 0.897  | 0.606 |
# | car         | 1201 | 4342  | 0.824  | 0.730 |
# | cat         | 358  | 1861  | 0.911  | 0.737 |
# | chair       | 756  | 13529 | 0.857  | 0.500 |
# | cow         | 244  | 423   | 0.639  | 0.472 |
# | diningtable | 206  | 3635  | 0.908  | 0.690 |
# | dog         | 489  | 2183  | 0.865  | 0.565 |
# | horse       | 348  | 802   | 0.802  | 0.624 |
# | motorbike   | 325  | 2100  | 0.892  | 0.715 |
# | person      | 4528 | 13165 | 0.848  | 0.730 |
# | pottedplant | 480  | 2969  | 0.704  | 0.436 |
# | sheep       | 242  | 1375  | 0.798  | 0.536 |
# | sofa        | 239  | 3770  | 0.941  | 0.639 |
# | train       | 282  | 2713  | 0.918  | 0.668 |
# | tvmonitor   | 308  | 1965  | 0.825  | 0.645 |
# +-------------+------+-------+--------+-------+
# | mAP         |      |       |        | 0.600 |
# +-------------+------+-------+--------+-------+
# 12/27 12:50:01 - mmengine - INFO - Epoch(val) [4][4952/4952]    pascal_voc/mAP: 0.5995  pascal_voc/AP50: 0.6000  data_time: 0.0023  time: 0.0806
