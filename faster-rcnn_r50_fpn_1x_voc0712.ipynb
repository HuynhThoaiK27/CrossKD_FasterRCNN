# %% [markdown]
# <a href="https://www.kaggle.com/code/thoihunhvn/crosskd?scriptVersionId=222393584" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Cài đặt

# %%
# !pip install torch==1.12.1 torchvision==0.13.1 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113

# !pip install -U openmim

# !mim install "mmengine==0.7.3"

# !mim install "mmcv==2.0.0rc4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 437.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 55.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 84.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0
#     Uninstalling torchaudio-2.4.0:
#       Successfully uninstalled torchaudio-2.4.0
# ...

# %%
# !git clone https://github.com/jbwang1997/CrossKD
# %cd CrossKD
# Out:
# Cloning into 'CrossKD'...
# remote: Enumerating objects: 34364, done.
# remote: Counting objects: 100% (1696/1696), done.
# remote: Compressing objects: 100% (273/273), done.
# remote: Total 34364 (delta 1554), reused 1423 (delta 1423), pack-reused 32668 (from 2)
# Receiving objects: 100% (34364/34364), 32.17 MiB | 19.59 MiB/s, done.
# Resolving deltas: 100% (26898/26898), done.
# /kaggle/working/CrossKD

# %%
# !pip install -v -e .
# "-v" means verbose, or more output
# "-e" means installing a project in editable mode,
# thus any local modifications made to the code will take effect without reinstallation.

# !pip install yapf==0.32.0
# Out:
# Using pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///kaggle/working/CrossKD
#   Running command python setup.py egg_info
#   /opt/conda/lib/python3.10/site-packages/setuptools_scm/_integration/setuptools.py:31: RuntimeWarning:
#   ERROR: setuptools==60.2.0 is used in combination with setuptools_scm>=8.x
#
#   Your build configuration is incomplete and previously worked by accident!
#   setuptools_scm requires setuptools>=61
#
#   Suggested workaround if applicable:
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running egg_info
#   creating /tmp/pip-pip-egg-info-6eebv4he/mmdet.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-6eebv4he/mmdet.egg-info/SOURCES.txt'
# ...

# %% [markdown]
# # Thực hiện các bước di chuyển và cài đặt cấu hình

# %%
# !ls configs/
# Out:
# _base_	atss  centernet  crosskd  crosskd+pkd  fcos  gfl  ld  retinanet

# %%
# !cp /kaggle/input/voc-fasterrcnn/voc0712_faster_rcnn.py configs/_base_/datasets/voc0712.py

# %%
# !python tools/train.py configs/pascal_voc/faster-rcnn_r50_fpn_1x_voc0712.py --work-dir /kaggle/working/weights_FasterRCNN_r50
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/CrossKD/tools/train.py", line 124, in <module>
#     main()
#   File "/kaggle/working/CrossKD/tools/train.py", line 61, in main
#     cfg = Config.fromfile(args.config)
#   File "/opt/conda/lib/python3.10/site-packages/mmengine/config/config.py", line 178, in fromfile
#     cfg_dict, cfg_text, env_variables = Config._file2dict(
#   File "/opt/conda/lib/python3.10/site-packages/mmengine/config/config.py", line 458, in _file2dict
#     check_file_exist(filename)
#   File "/opt/conda/lib/python3.10/site-packages/mmengine/utils/path.py", line 23, in check_file_exist
#     raise FileNotFoundError(msg_tmpl.format(filename))
# FileNotFoundError: file "/kaggle/working/CrossKD/configs/pascal_voc/faster-rcnn_r50_fpn_1x_voc0712.py" does not exist
